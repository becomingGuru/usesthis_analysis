# %%
import pandas as pd
import os, markdown, glob, yaml
from re import match, findall, DOTALL
base_dir = '/Users/lpd/gh/usesthis/'

# %%
wares = glob.glob('%s/wares/*'%base_dir)
all_wares = []
for el in wares:
    desc = yaml.load(open(el))
    desc['title'] = os.path.splitext(os.path.basename(el))[0]
    all_wares.append(desc)
p_wares = pd.DataFrame(all_wares)

# %%
p_wares.describe()
# Out:
#                 description   name                       title      type  \
# count                  3230   3230                        3230      3230
# unique                 2807   3221                        3230         2
# top     An electric guitar.  Unity  apex-model-edge-pro-system  software
# freq                     12      2                           1      1883
#
#                                url
# count                         3230
# unique                        3215
# top     http://www.apple.com/ipad/
# freq                             4

# %%
interview_files = glob.glob('%s/_posts/*'%base_dir)

# %%
all_interviews = []
for interview_file_name in interview_files:
    with open(interview_file_name,'r') as interview_file:
        md_string = interview_file.read()
        yml_header = match('(?P<yml>^---.*)\n---', md_string, DOTALL).groupdict()['yml']
        interview = yaml.load(yml_header)
        interview['wares'] = [wares[1] for wares in findall('\[([^\[\(\)]+)\]\[([a-z0-9\.\-]+)?\]', md_string) if wares[1]]
        all_interviews.append(interview)
interview_frame = pd.DataFrame(all_interviews)

# %%
interview_frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353 entries, 0 to 352
# Data columns (total 7 columns):
# categories    353  non-null values
# credits       38  non-null values
# layout        353  non-null values
# slug          353  non-null values
# summary       353  non-null values
# title         353  non-null values
# wares         353  non-null values
# dtypes: object(7)

# %%
del interview_frame['layout']
del interview_frame['credits']
del interview_frame['summary']
del interview_frame['title']

# %%
each_used_ware = []
for person_ware in interview_frame.wares:
    each_used_ware+=person_ware
ps_wares = pd.Series((each_used_ware))

# %%
ps_wares.value_counts()
# Out:
# macbook-pro       181
# macbook-air       107
# cinema-display     78
# google-docs        69
# iphone-4           67
# mac-os-x           57
# mac-pro            56
# windows-7          47
# photoshop          44
# keyboard           40
# ipad-2             39
# mac-mini           34
# google-reader      33
# magic-mouse        33
# iphone-4s          33
# ...
# c-2000-b                      1
# vaio-eb46fx-wi                1
# server-density                1
# hudzee                        1
# corona                        1
# gesundheit-ios                1
# stylus-sx218                  1
# beta-52a                      1
# standard-field-telescopes     1
# towerraid-tr5m-b              1
# syncmaster-730mp              1
# brainport-v100                1
# my-passport-mac               1
# weatherpro-ios                1
# apex-model-edge-pro-system    1
# Length: 2177, dtype: int64

# %%
ps_wares.value_counts()[:15].plot(kind='bar')

# %%
interview_frame.to_csv('/tmp/test_file.csv')

# %%
unique_wares = set(ps_wares.values)

# %%
wares_frame = pd.DataFrame(np.zeros((len(interview_frame), len(unique_wares))), columns=unique_wares)

# %%
for i,person_wares in enumerate(interview_frame.wares):
    wares_frame.ix[i,person_wares]=1

# %%
wares_frame.columns
# Out:
# Index([apex-model-edge-pro-system, precision-bass, verticalmouse, ..., m9-vi1000, d2-quadra, path-finder], dtype=object)

# %%
all_cats = []
for cat in interview_frame.categories:
    all_cats.extend(cat)

# %%
unique_cats = set(all_cats)

# %%
unique_cats
# Out:
# set(['crafter',
#      'biker',
#      'fashion',
#      'producer',
#      'researcher',
#      'blogger',
#      'community',
#      'sex',
#      'hardware',
#      'entrepreneur',
#      'manager',
#      'scientist',
#      'comedian',
#      'philosopher',
#      'lawyer',
#      'linux',
#      'politics',
#      'technologist',
#      'film',
#      'developer',
#      'hacker',
#      'web',
#      'video',
#      'cosplay',
#      'service',
#      'space',
#      'photographer',
#      'writer',
#      'actor',
#      'beer',
#      'music',
#      'editor',
#      'suit',
#      'poet',
#      'engineer',
#      'type',
#      'systems',
#      'coffee',
#      'designer',
#      'reporter',
#      'food',
#      'musician',
#      'animator',
#      'game',
#      'modder',
#      'student',
#      'interface',
#      'librarian',
#      'chef',
#      'data',
#      'teacher',
#      'icon',
#      'sysadmin',
#      'beekeeper',
#      'audio',
#      'illustrator',
#      'astrologer',
#      'artist',
#      'windows',
#      'professor',
#      'mac',
#      'podcaster',
#      'bsd',
#      'journalist',
#      'social',
#      'puppet',
#      'security',
#      'software',
#      'baker',
#      'usability'])

# %%
cats_frame = pd.DataFrame(np.zeros((len(interview_frame), len(unique_cats))), columns=unique_cats)

# %%
cats_frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353 entries, 0 to 352
# Data columns (total 70 columns):
# crafter         353  non-null values
# biker           353  non-null values
# fashion         353  non-null values
# producer        353  non-null values
# researcher      353  non-null values
# blogger         353  non-null values
# community       353  non-null values
# sex             353  non-null values
# hardware        353  non-null values
# entrepreneur    353  non-null values
# manager         353  non-null values
# scientist       353  non-null values
# comedian        353  non-null values
# philosopher     353  non-null values
# lawyer          353  non-null values
# linux           353  non-null values
# politics        353  non-null values
# technologist    353  non-null values
# film            353  non-null values
# developer       353  non-null values
# hacker          353  non-null values
# web             353  non-null values
# video           353  non-null values
# cosplay         353  non-null values
# service         353  non-null values
# space           353  non-null values
# photographer    353  non-null values
# writer          353  non-null values
# actor           353  non-null values
# beer            353  non-null values
# music           353  non-null values
# editor          353  non-null values
# suit            353  non-null values
# poet            353  non-null values
# engineer        353  non-null values
# type            353  non-null values
# systems         353  non-null values
# coffee          353  non-null values
# designer        353  non-null values
# reporter        353  non-null values
# food            353  non-null values
# musician        353  non-null values
# animator        353  non-null values
# game            353  non-null values
# modder          353  non-null values
# student         353  non-null values
# interface       353  non-null values
# librarian       353  non-null values
# chef            353  non-null values
# data            353  non-null values
# teacher         353  non-null values
# icon            353  non-null values
# sysadmin        353  non-null values
# beekeeper       353  non-null values
# audio           353  non-null values
# illustrator     353  non-null values
# astrologer      353  non-null values
# artist          353  non-null values
# windows         353  non-null values
# professor       353  non-null values
# mac             353  non-null values
# podcaster       353  non-null values
# bsd             353  non-null values
# journalist      353  non-null values
# social          353  non-null values
# puppet          353  non-null values
# security        353  non-null values
# software        353  non-null values
# baker           353  non-null values
# usability       353  non-null values
# dtypes: float64(70)

# %%
for i,person_categories in enumerate(interview_frame.categories):
    cats_frame.ix[i,person_categories]=1

# %%
len(cats_frame.columns)
# Out:
# 70

# %%
whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# DOTALL                int          16
# all_cats              list         n=1190
# all_interviews        list         n=353
# all_wares             list         n=3230
# base_dir              str          /Users/lpd/gh/usesthis/
# cat                   list         n=2
# cats_frame            DataFrame    <class 'pandas.core.frame<...>lues\ndtypes: float64(70)
# desc                  dict         n=5
# each_used_ware        list         n=4878
# el                    str          /Users/lpd/gh/usesthis//wares/zwoptex.yml
# findall               function     <function findall at 0x100466f50>
# glob                  module       <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# i                     int          352
# interview             dict         n=6
# interview_file        file         <closed file '/Users/lpd/<...> mode 'r' at 0x108eb3f60>
# interview_file_name   str          /Users/lpd/gh/usesthis//_<...>cameron.walters.interview
# interview_files       list         n=353
# interview_frame       DataFrame    <class 'pandas.core.frame<...>values\ndtypes: object(3)
# markdown              module       <module 'markdown' from '<...>s/markdown/__init__.pyc'>
# match                 function     <function match at 0x100466cf8>
# md_string             str          ---\nlayout: interview\ns<...>M, please? VMs use a lot.
# os                    module       <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# p_wares               DataFrame    <class 'pandas.core.frame<...>values\ndtypes: object(5)
# pd                    module       <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# person_categories     list         n=2
# person_ware           list         n=12
# person_wares          list         n=12
# ps_wares              Series       0          macbook-pro\n1<...>ngth: 4878, dtype: object
# unique_cats           set          set(['crafter', 'biker', <...>', 'baker', 'usability'])
# unique_wares          set          set(['apex-model-edge-pro<...>-quadra', 'path-finder'])
# wares                 tuple        n=2
# wares_frame           DataFrame    <class 'pandas.core.frame<...>er\ndtypes: float64(2177)
# wf                    DataFrame    <class 'pandas.core.frame<...>er\ndtypes: float64(2177)
# yaml                  module       <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>
# yml_header            str          ---\nlayout: interview\ns<...>egories: [developer, mac]

# %%
cats_frame.join(wares_frame)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-48-f80865c61793> in <module>()
# ----> 1 cats_frame.join(wares_frame)
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in join(self, other, on, how, lsuffix, rsuffix, sort)
#    4357         # For SparseDataFrame's benefit
#    4358         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 4359                                  rsuffix=rsuffix, sort=sort)
#    4360
#    4361     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    4371             return merge(self, other, left_on=on, how=how,
#    4372                          left_index=on is None, right_index=True,
# -> 4373                          suffixes=(lsuffix, rsuffix), sort=sort)
#    4374         else:
#    4375             if on is not None:
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy)
#      35                          right_index=right_index, sort=sort, suffixes=suffixes,
#      36                          copy=copy)
# ---> 37     return op.get_result()
#      38 if __debug__:
#      39     merge.__doc__ = _merge_doc % '\nleft : DataFrame'
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in get_result(self)
#     184
#     185         # this is a bit kludgy
# --> 186         ldata, rdata = self._get_merge_data()
#     187
#     188         # TODO: more efficiently handle group keys to avoid extra
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in _get_merge_data(self)
#     279         lsuf, rsuf = self.suffixes
#     280         ldata, rdata = ldata._maybe_rename_join(rdata, lsuf, rsuf,
# --> 281                                                 copydata=False)
#     282         return ldata, rdata
#     283
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in _maybe_rename_join(self, other, lsuffix, rsuffix, copydata)
#    1697         if len(to_rename) > 0:
#    1698             if not lsuffix and not rsuffix:
# -> 1699                 raise Exception('columns overlap: %s' % to_rename)
#    1700
#    1701             def lrenamer(x):
#
# Exception: columns overlap: Index([illustrator], dtype=object)

# %%
cf = cats_frame.add_prefix('cat_')

# %%
cw_frame = cf.join(wares_frame)

# %%
ff = cw_frame.join(interview_frame)

# %%
ff.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Columns: 2247 entries, cat_crafter to path-finder
# dtypes: float64(2247)

# %%
ff.pivot_table(rows=['macbook-pro',],cols=['cat_designer'],aggfunc=sum)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 0.0 to 1.0
# Columns: 4490 entries, (cat_crafter, 0.0) to (path-finder, 1.0)
# dtypes: float64(4490)

# %%
list(ff.columns)
# Out:
# ['cat_crafter',
#  'cat_biker',
#  'cat_fashion',
#  'cat_producer',
#  'cat_researcher',
#  'cat_blogger',
#  'cat_community',
#  'cat_sex',
#  'cat_hardware',
#  'cat_entrepreneur',
#  'cat_manager',
#  'cat_scientist',
#  'cat_comedian',
#  'cat_philosopher',
#  'cat_lawyer',
#  'cat_linux',
#  'cat_politics',
#  'cat_technologist',
#  'cat_film',
#  'cat_developer',
#  'cat_hacker',
#  'cat_web',
#  'cat_video',
#  'cat_cosplay',
#  'cat_service',
#  'cat_space',
#  'cat_photographer',
#  'cat_writer',
#  'cat_actor',
#  'cat_beer',
#  'cat_music',
#  'cat_editor',
#  'cat_suit',
#  'cat_poet',
#  'cat_engineer',
#  'cat_type',
#  'cat_systems',
#  'cat_coffee',
#  'cat_designer',
#  'cat_reporter',
#  'cat_food',
#  'cat_musician',
#  'cat_animator',
#  'cat_game',
#  'cat_modder',
#  'cat_student',
#  'cat_interface',
#  'cat_librarian',
#  'cat_chef',
#  'cat_data',
#  'cat_teacher',
#  'cat_icon',
#  'cat_sysadmin',
#  'cat_beekeeper',
#  'cat_audio',
#  'cat_illustrator',
#  'cat_astrologer',
#  'cat_artist',
#  'cat_windows',
#  'cat_professor',
#  'cat_mac',
#  'cat_podcaster',
#  'cat_bsd',
#  'cat_journalist',
#  'cat_social',
#  'cat_puppet',
#  'cat_security',
#  'cat_software',
#  'cat_baker',
#  'cat_usability',
#  'apex-model-edge-pro-system',
#  'precision-bass',
#  'verticalmouse',
#  'mac-app-store',
#  'mirage',
#  'thinkpad-w701',
#  'qck-heavy',
#  'scorpio-blue',
#  'm555b',
#  '20th-anniversary-macintosh',
#  'qb-1-plus',
#  'google-places',
#  'cm5',
#  'retro-duo',
#  'seamax-m-22',
#  'bass-terror-1000',
#  'pages',
#  'pinball-fx-2',
#  'omnigraffle-pro',
#  'cr-1020',
#  'ia-writer-ios',
#  'f3ja',
#  'precise-v5',
#  'bricxcc',
#  'p5',
#  'todo.sh',
#  '3160qdc',
#  'ksm32',
#  'netbeans',
#  'g2-pro',
#  'dt-400w',
#  'h340',
#  'ts-7260',
#  'gnome-power-manager',
#  'prompa-ii',
#  'aspire-one-d250',
#  'front-roller-plus',
#  'hudzee',
#  'keystation-61es',
#  '10s',
#  'merkur-34c',
#  'might-and-magic-clash-of-heroes',
#  'g2-7600',
#  'liberty',
#  'processing.js',
#  'world-of-goo-ios',
#  'sauce-labs',
#  'af-s-nikkor-16-35mm-f4g-ed-vr',
#  'aria',
#  'giffun',
#  'windows-8',
#  'prs-505',
#  'xo-1',
#  'superior-drummer',
#  'mindmeister-ios',
#  'moccamaster-kb-741',
#  'natural-keyboard',
#  'ml-1630',
#  'itunes',
#  'spotify-android',
#  'dra-f101',
#  'audio-470-usb',
#  'instapaper-ios',
#  '8020a',
#  'ego-ios',
#  'axiom-49',
#  'ultravac-225',
#  'google-plus',
#  'more-real',
#  'strat',
#  'fata1ity-hs-1000',
#  'roubaix-elite',
#  'dslr-a200',
#  'performa-6110cd',
#  'rebel-t1i',
#  'aws-scale',
#  'm5',
#  'integra-7',
#  'm6',
#  'nerdcommenter',
#  'enviro-bear-2010-ios',
#  'm3',
#  'sc-880',
#  'm9',
#  'touchosc-ios',
#  'dm1-ios',
#  'modbook-pro',
#  '1905fp',
#  'grip-0.7mm',
#  'hurd',
#  'word',
#  'wifi-body-scale',
#  'powershot-elph-300-hs',
#  'wake-up-light',
#  'droid-incredible',
#  'erc',
#  'k2-hf',
#  'alto-connect',
#  'ef-50mm-f1.4-usm',
#  'm11x',
#  'astrid-android',
#  'sixty-four',
#  'paparazzi',
#  'ubuntu-server',
#  'review-board',
#  'ispell',
#  'photo-paint',
#  'foursquare-android',
#  'things-ios',
#  'pmd620',
#  'yas-875ex',
#  'me8erglo',
#  're20',
#  'md-421',
#  'gimp',
#  'pcm-d50',
#  'z3ta',
#  'eos-20d',
#  'juno-60',
#  'easyshare-dx6490',
#  'studio-xps-1647',
#  'parallel',
#  'keeley-compressor',
#  'marathon-m705',
#  'indisliderpro',
#  'think',
#  'noctilux-m',
#  'lumix-dmc-fz50',
#  'lumix-dmc-gf1',
#  'video-capture',
#  'wave-desk',
#  'lumix-dmc-gf2',
#  'the-wire-ios',
#  'g15',
#  'sibelius',
#  'horizon-mm226',
#  'office',
#  'numbers',
#  'isimulate-ios',
#  'true-home-image',
#  'sr325is',
#  'keyboard',
#  'gtk-plus',
#  'vita',
#  'istat-pro',
#  'coverity-static-analysis',
#  'm-160',
#  'photostudio',
#  'finepix-x100',
#  'axiom-pro-49',
#  'diablo-3',
#  'ef-85mm-f1.2l-ii-usm',
#  'mp-2',
#  'hd-429',
#  'hd-600',
#  'ds-lite',
#  'mm-1',
#  'mx500',
#  'editplus',
#  'camano',
#  'dinovo-edge',
#  'hundreds-ios',
#  'rocky',
#  'acme',
#  'thunderbolt-display',
#  'ef-100mm-f2.8l-is-usm',
#  'horror-vacui-ios',
#  'rd-700nx',
#  'roast',
#  'beeralchemy',
#  '370',
#  'google-analytics',
#  'd40',
#  'ef-135mm-f2.8-softfocus',
#  '376',
#  'af-vr-micro-nikkor-105mm-f-2.8g-if-ed',
#  'ext-js',
#  'smartgo-ios',
#  'soundtrack-pro',
#  'shp8500-00',
#  'multisync-2690',
#  'tulip-chair',
#  'verbs-ios',
#  'laboratory',
#  'workforce-545',
#  'vmware-server',
#  'skivvy-s',
#  'ipad-mini',
#  'dsi',
#  'big-muff',
#  'droid-incredible-2',
#  'ims-20-ios',
#  'eos-10d',
#  'm14500',
#  'windows-vista',
#  'animoog-ios',
#  'terragen',
#  'rb67',
#  'tweetie-ios',
#  'putty',
#  'urban-cowboy',
#  'acrobat',
#  'tags',
#  'youre-number-one-ios',
#  'switch2',
#  'ants-performance-profiler',
#  'ag-hpx170',
#  'diana-f-plus',
#  'lumia-900',
#  'vmware-workstation',
#  'chrome-os',
#  'windows-98',
#  'quietcomfort-15',
#  'adobe-ideas-ios',
#  'comics-ios',
#  'the-economist-ios',
#  'how-to-cook-everything-ios',
#  'final-draft',
#  'delicious',
#  'sketchup-pro',
#  'powershot-s100',
#  'stylus-tough-6020',
#  'surface-pro',
#  'byobu',
#  'human-japanese-android',
#  'elevator',
#  'outlook-express',
#  'z750i',
#  '1975-scale-loupe-7x',
#  'vx-nano',
#  'wiscale-ios',
#  'a30',
#  'eye-fi',
#  'droid-2',
#  'quattro',
#  'gn-twin',
#  'xel-1',
#  'fuelband',
#  'captio-ios',
#  'canoscan-8800f',
#  'af-vr-nikkor-80-400mm-f4.5-5.6d-ed',
#  'roll-up-iii',
#  'cubase-le',
#  'aether',
#  'gnupg',
#  'dexiq-ios',
#  'xv-88',
#  'data-doubler',
#  'fudada-hd-ios',
#  'ceramic-dripper',
#  'premier-soft-core',
#  'xacti-vpc-hd1000',
#  'blackwing-602',
#  'movie-maker',
#  'emacs-for-mac-os-x',
#  'mousepose',
#  '3007wfp',
#  'slideshowpro-player',
#  'due-ios',
#  'extended-keyboard-ii',
#  'beyond-tv',
#  'actionsampler',
#  'edge',
#  'moka-express',
#  'transmit',
#  'px-10',
#  'visual-studio',
#  'avast-free',
#  'sparrow-ios',
#  'steadicam-merlin',
#  'colormunki-photo',
#  'd7000',
#  'audition',
#  'livescribe-desktop',
#  'rp-htx7',
#  'remote-ios',
#  'macbook',
#  'fw-1884',
#  'pap2t',
#  'officejet-6210',
#  'twitterrific-ios',
#  'visualsvn-server',
#  'yahoo-pipes',
#  'gsl',
#  'graphire',
#  'evernote-ios',
#  'superpro-280u',
#  'the-waste-land-ios',
#  'quickcam-orbit-mp',
#  'net-station',
#  'evoke-3',
#  'aspire-revo',
#  'ideapad-v570',
#  'dock-gone',
#  'numbers-ios',
#  'pavilion-elite-m9000',
#  'mdr-v600',
#  'd3',
#  'eos-650d',
#  'scanexpress-a3-usb-1200-pro',
#  '744t',
#  'lumix-dmc-fs3',
#  'se315',
#  'buran',
#  'the-professional-ii',
#  'colour-lovers',
#  'windowshade-x',
#  'trillian-sip',
#  'spanning-sync',
#  'galaxy-tab',
#  'math-alarm-clock-android',
#  'lightroom',
#  'do',
#  'connect-x2',
#  'cp-1',
#  'lx-desk-mount-lcd-arm',
#  'fluid',
#  'carcassonne-ios',
#  'cello-fortress',
#  'stache-labbit-plush-7-inch',
#  'ds',
#  'custom-citizen',
#  'maverick',
#  'lc-wide',
#  'marathon-supreme-700x28',
#  'call-recorder',
#  'default-folder-x',
#  'kindle-touch',
#  'eames-desk',
#  'utby',
#  'vagabond-mini',
#  'nexus-one',
#  'byword',
#  'el-pino',
#  'porlex-grinder',
#  'tm-git-bundle',
#  'audio-recorder',
#  'galcon-ios',
#  'komplete',
#  'c325bee',
#  'standard-field-telescopes',
#  'martin-d-35',
#  'notebook-optical-mouse-plus',
#  '828mk3-hybrid',
#  'gnome-terminal',
#  'mac-os-x',
#  'mac-pro',
#  'u2410',
#  'quietcomfort-2',
#  'horror-vacui-2-ios',
#  'number-25-21mm-silver-tip-badger',
#  'flip-ultra',
#  'vmware-fusion',
#  'fieldrunners-ios',
#  'x-session-pro',
#  'pitt',
#  'atmos-50',
#  'pd-a530',
#  'coated-canvas-shoulder-bag',
#  'hdr-xrs500v',
#  'nex-5n',
#  'wired-keyboard-500',
#  'white-noise-ambience-ios',
#  'uad-1',
#  'fruityloops',
#  'sabnzbd-plus',
#  'chrome',
#  'carcharias',
#  'sl6',
#  'robo-defense-android',
#  'summizer-ios',
#  'network-manager',
#  'canoscan-9000f',
#  'dreamweaver',
#  'firewire-410',
#  'mc-385v1v',
#  'filemaker-pro',
#  'perfection-v700',
#  'wired-ios',
#  'happy-hacking-keyboard',
#  'sword-and-sworcery-ios',
#  'n600',
#  'super-crate-box-ios',
#  'hxrmc50u',
#  '2738',
#  'roubaix-3',
#  'd700',
#  'maya',
#  'kackel-dackel',
#  'byword-ios',
#  'pivotal-tracker',
#  'decaf-android',
#  'qgis',
#  'dead-space',
#  'make',
#  'google-apps-script',
#  'gforce-m-tron-pro',
#  'rebel-t3i',
#  'pixma-pro9500-mark-ii',
#  'stickies',
#  'km-iphone-mic2-ecm',
#  'esquire',
#  'b25b',
#  'evolve',
#  'sg-standard',
#  'pavilion-elite-180t',
#  'analytics-ios',
#  'kentucky-route-zero',
#  'ultra-wide-and-slim',
#  'remote-desktop',
#  'writing-kit-ios',
#  'le-pen',
#  'lc-a-plus',
#  'guardian-ios',
#  'ocean',
#  'presario-sr5648f',
#  'se115m-plus',
#  'galaxy-gio',
#  '800',
#  'k702',
#  'sound-forge',
#  'tripview-ios',
#  'bs100u',
#  'mopad',
#  'anti-social',
#  'thinkpad-t520',
#  'diabolika-ios',
#  'this-american-life-ios',
#  'sl-5500',
#  'cyber-shot-dsc-rx100',
#  'mc2kw',
#  'firefox-android',
#  'birdhouse-ios',
#  'airport-extreme',
#  'robodrill',
#  'mail-ios',
#  '20-20',
#  'programmers-notepad',
#  'syncmaster-2333hd',
#  'one-twenty-eight',
#  'natural-ergonomic-desktop-7000',
#  'summicron-m-35mm-f2-asph',
#  'fusion',
#  'd1-air-500',
#  'precision-t3500',
#  'usb-overdrive',
#  'helsings-fire-ios',
#  'keynote-kung-fu',
#  'paragraft-ios',
#  'zaggfolio-ipad-2',
#  'wtcpt',
#  'zeppelin-air',
#  'p3-pico',
#  'movable-type',
#  'ion.2',
#  'centos',
#  'icurve',
#  'vixia-hv20',
#  'maxim',
#  'flash-voyager',
#  'ta-da-list',
#  'usb-memory-watch',
#  'game-dev-story-android',
#  'atlas.ti',
#  '40001-zester',
#  'ef-50mm-f1.2l-usm',
#  'apple-tv',
#  'suitcase-fusion',
#  'monotron',
#  'hd555',
#  'ice',
#  'connect.2',
#  'bold',
#  'sketchbook-pro-ios',
#  'dg-one',
#  'sequel-pro',
#  'mdr-xd100',
#  'somafm',
#  'kingdom-rush-ios',
#  'graphics-360',
#  'xbox-live',
#  'g500',
#  'tough-tg-810',
#  'google-maps',
#  'kgs-go-client',
#  'aircard-598',
#  'etrex-vista-hcx',
#  'xfce',
#  'd60',
#  'facebook-ios',
#  'evernote-mac',
#  'explorer-mouse',
#  'connectbot-android',
#  'mocha',
#  'gel-ink-0.38mm',
#  'unity.2',
#  'customizer-104-105',
#  'cloudapp',
#  'mamba',
#  'mapattack',
#  'wop-35',
#  'eee-pc-s101',
#  'n95-8g',
#  'v-20',
#  'tyler-wm',
#  'p6245',
#  'latitude-d830',
#  'nova',
#  'porta-pro',
#  'pigment-liner-308',
#  'wordpress',
#  'optimod-pc-1100',
#  'optimod-pc-1101',
#  'the-hotcake',
#  'playstation-home',
#  'update-notifier',
#  'rd-500',
#  'ramp-champ-ios',
#  'fireworks',
#  'eee-slate-ep121',
#  'mju-ii',
#  'taxi-magic-ios',
#  'radeon-hd-4850',
#  'rnc1773',
#  '1510-carry-on-case',
#  'm3000-ios',
#  '2across-ios',
#  'ristretto-13-inch',
#  'torch-9800',
#  'af-nikkor-50mm-f1.4d',
#  'v-razor-point',
#  'paint-shop-pro',
#  'ministack-v2.5',
#  'steermouse',
#  'rollermouse-pro',
#  'cs-104',
#  'data-miner',
#  'saffire-6-usb',
#  'imo-ios',
#  'penultimate-ios',
#  'ef-24-70mm-f2.8l-usm',
#  'folio-cherry',
#  'excel',
#  'air-android',
#  'nx',
#  'independent-75',
#  'pod-pro',
#  'papers',
#  'ug22',
#  'buster-ios',
#  'h-100',
#  'designjet-z3200',
#  'macbook-air-wallet',
#  'perfection-v600',
#  'loopmasters',
#  'ath-m50',
#  'dropbox-ios',
#  'pearl-8100',
#  'digimax-d8',
#  'tunesremote-android',
#  'max.2',
#  'if-281dpb',
#  'sous-vide-professional',
#  'arch-linux',
#  'ef-s-10-22mm-f3.5-4.5-usm',
#  'n9',
#  'e2500',
#  'codeblocks',
#  'l4d2',
#  'w17e',
#  'inchworm-animation',
#  'mint.2',
#  '111-navy',
#  'focus',
#  'mindstorms',
#  'diet-coda-ios',
#  'cinema-display',
#  'my-passport-essential',
#  'eeg-neuroheadset',
#  'flash',
#  'lc-a',
#  'typepad-ios',
#  'usb-power-adapter',
#  'web-inspector',
#  'wt-duffel',
#  'dragonfly',
#  'thinkpad-t60p',
#  'rode-nt1-a',
#  'statusnet',
#  'enqueue',
#  'little-big-disk',
#  'thinkpad-t510',
#  'stylus-photo-r2000',
#  'af-dx-nikkor-10.5mm-f2.8g-ed',
#  'usb-retrobit-snes-pc-controller',
#  'mpeg-streamclip',
#  'lumix-dmc-fx01',
#  'rebel-t2i',
#  'gitapp-ios',
#  'nextstation',
#  'marcopolo',
#  'v4pro',
#  'ted-ios',
#  'calvetica-ios',
#  'mx-1000',
#  '12ay7',
#  'safari-fountain-pen',
#  'scanner-pro-ios',
#  'h2-handy-recorder',
#  'acer-ferrari-5000',
#  '206rb-5',
#  'mp-e-65mm-f2.8-1-5x',
#  'virtual-ii',
#  'af-s-dx-nikkor-12-24mm-f4g-if-ed',
#  'expert-mouse',
#  'z-5500',
#  'm00926-smoker',
#  'pro-tools-m-powered',
#  'stylus-pro-4000',
#  'canabalt-ios',
#  'apc20',
#  'time-cube',
#  'hd25sp',
#  'multimix-8',
#  'recorder-ios',
#  'v-synth-gt',
#  'tenori-on-ios',
#  'magma-pci',
#  'ae2',
#  'powermate',
#  'rdio',
#  'ns-10',
#  'windows-7',
#  'mx200',
#  'perfection-1660',
#  'frog-fractions',
#  'blacx',
#  'script-debugger',
#  'grooveshark',
#  'replay-telecorder',
#  'lightwave',
#  'tube-screamer',
#  'toneport-ux1',
#  'snapz-pro-x',
#  'speedlight-580ex',
#  'syncmaster-p2450h',
#  'laserjet-pro-cp1525nw',
#  'hs80m',
#  'escape-velocity-nova',
#  'taskk',
#  'intellij-idea',
#  'httpd',
#  'd70',
#  'remember-the-milk-ios',
#  'captivate',
#  'advantage-usb',
#  'mamp-pro',
#  'live',
#  'iphone',
#  'expressionengine',
#  'g-raid-mini',
#  'classic-s',
#  'pyosc',
#  'sketch-marker',
#  'laser-stars',
#  'cintiq',
#  'downcast-ios',
#  'nylon-compact-backpack',
#  'syd-5',
#  'ip4',
#  'pastebot-ios',
#  'postgresql',
#  'kenken-ios',
#  'window-maker',
#  'inspiron-4100',
#  'tv-b-gone',
#  've245tl',
#  'melody-maker',
#  'rdio-ios',
#  'game-maker',
#  'yashica-t4',
#  'foldingtext',
#  'sounddock',
#  'dac25.2',
#  'checkmark-ios',
#  'go-plus-wifi',
#  'streak',
#  'kdl-v40xbr1',
#  'gr-digital',
#  'oxygen-49',
#  'ks-wa-gyuto',
#  'tc-7520',
#  'fp10',
#  'jambox',
#  'turbo-assembler',
#  'neoprene-air',
#  'camtasia',
#  'f-301',
#  'drobo-5d',
#  's3',
#  'hdr-fx7',
#  'droid-3',
#  '2408wfp',
#  '140',
#  'fastmail',
#  'nvalt',
#  'max',
#  'cosmonaut',
#  'pavilion-dv2419us',
#  'jv-880',
#  '1621a',
#  'plants-vs-zombies-ios',
#  'left-4-dead-2',
#  'soundcloud-mac',
#  'studio-display',
#  'hero-academy-ios',
#  'znc',
#  'google-apps',
#  'vaio-eb46fx-wi',
#  'a-2340r',
#  'server-density',
#  'corona',
#  'inform',
#  'aspire-one-zg5',
#  'photo-booth',
#  'towerraid-tr5m-b',
#  'epic-mickey',
#  'brainport-v100',
#  'thinkpad-t61p',
#  'cut-the-rope-ios',
#  'kone',
#  'hex-workshop',
#  'google-earth',
#  'recco-ios',
#  'ath-anc7b',
#  'parallels-desktop',
#  'arduino',
#  'icon-udac-2',
#  'angry-birds-ios',
#  'weathereye-ios',
#  '324i',
#  '22-802',
#  'igroove',
#  'mail',
#  'duckduckgo',
#  'funtoo',
#  'soundbooth',
#  'emailer',
#  'thing-o-matic',
#  'instagram-ios',
#  'safari',
#  'macvim',
#  'charge-tti',
#  'ia-writer-mac',
#  'beolab-4000',
#  'lebistro-pet-feeder',
#  'dm-300',
#  'play-360',
#  'ntlk',
#  'lp3065',
#  'langstroth-hive',
#  'myx-2',
#  'x-chat-aqua',
#  'stylus-photo-r1900',
#  'system-6',
#  'system-7',
#  'mx-lcd-arm',
#  'square',
#  'bloglines',
#  'ed',
#  'super-meat-boy',
#  'mstand',
#  'eames-side-chair',
#  'notify-io',
#  'af-zoom-nikkor-18-35mm-f3.5-4.5d-if-ed',
#  'gmail-android',
#  'yojimbo',
#  'napolitana',
#  'sp88x',
#  'scpaste',
#  'series-7-slate',
#  'cr-48',
#  'eagle',
#  'long-haul-trucker-complete',
#  'tma-1',
#  'ocean-2',
#  'hz281hpb',
#  'dub-h7',
#  'cyber-shot-dsct-10',
#  'tripit',
#  'sl-1200',
#  'ef-24-105mm-f4l-is-usm',
#  'mlb-at-bat-ios',
#  'digitalcolor-meter',
#  'thinkpad-x24',
#  'motion',
#  'ignition-ios',
#  'thinkcentre-m57p',
#  'sb-800-af-speedlight',
#  'xo',
#  'se115m',
#  '2000-dmm',
#  'xa',
#  'mx-400',
#  'z400',
#  'kenaf-filters',
#  'gimme-bar',
#  'replicator',
#  'pinyin-tooklit',
#  'photosmart-375',
#  'powershot-sd800',
#  'cushtop',
#  'pcalc-ios',
#  'vx2233wm',
#  'relax.el',
#  'nebulous-notes-ios',
#  'suite-8',
#  'g62-225dx',
#  'fontexplorer-x',
#  'chrome-ios',
#  'rx-4109',
#  'newplast',
#  '850b',
#  'xacti-vpc-fh1',
#  'wunderlist',
#  'se310',
#  'atr-1a',
#  'hd-hero2',
#  'realm-of-the-mad-god',
#  'flashdevelop',
#  'iphone-3g',
#  'rugged',
#  'my-book-for-mac',
#  'asciidoc-textmate',
#  'tripit-ios',
#  'windows-live-messenger',
#  'r',
#  'otsav-radio',
#  'sam',
#  'wireless-presenter-laser',
#  'flipboard-ios',
#  'at4050-cm5',
#  'n51vn',
#  'blood-pressure-monitor',
#  'opera-mobile-android',
#  'canoscan-lide-700f',
#  'goodreader-ios',
#  'readynas-pro',
#  'stylus-1050-sw',
#  'boot-camp',
#  'iteleport-ios',
#  'time-machine',
#  'fl-studio',
#  'blogsy-ios',
#  'b2230',
#  'bloom-ios',
#  'silvern-castle',
#  'showwx',
#  'trillian',
#  'runkeeper-ios',
#  'accuplot-320',
#  'stylus-nx515',
#  'i9900',
#  'lpb-2ube',
#  'creative-suite',
#  'cpanminus',
#  'mark-of-the-ninja',
#  'ef-50mm-f1.8-ii',
#  'tactile-pro',
#  'gourmet-live-ios',
#  'bhm-jl',
#  'wurdle-ios',
#  'poweredge-r710',
#  'pixie-plus',
#  'inspiron-mini-9',
#  'aroundme-ios',
#  'micro-q-phoenix',
#  'sb-900-af',
#  'netnewswire-ios',
#  'scanjet-professional-1000',
#  'ipod-nano',
#  'waze-ios',
#  'twitter-mac',
#  '3008wfp',
#  'honey-super',
#  'mavis-beacon',
#  '2-port-ps-2-kvm',
#  'readynas-ultra',
#  'ef-600mm-f4l-is-usm',
#  'bvu160',
#  'met-office-weather-ios',
#  'seq-315',
#  'address-book',
#  'reeder-ios',
#  'xfree86',
#  'sonar',
#  'robur',
#  'comanche',
#  'srh840',
#  'vignette-android',
#  'ud-01',
#  'pro-tt2',
#  '10000xl',
#  'rosetta-stone',
#  'nuvi-1300',
#  'giant-beat',
#  'reading',
#  'stereo96',
#  'screen',
#  'dog-park-finder-ios',
#  'summilux-m',
#  'wolfram-tones',
#  'latitude-x1',
#  'gasketball-ios',
#  'mindnode-pro',
#  'clay-shapers',
#  'impressa-f9',
#  'ew-100-g3',
#  'prizmo-ios',
#  'google-docs',
#  'op-1',
#  'screenshot-plus',
#  'avr-studio',
#  'geekdesk',
#  'psp-3000',
#  'edge-inspect',
#  'after-effects',
#  'glympse-ios',
#  'compaq-2510p',
#  'ef-28mm-f2.8',
#  'ida-pro',
#  'mindmanager-mac',
#  'hd2',
#  'vegas-pro',
#  'performance-mouse-mx',
#  's2409w',
#  'kometen-ios',
#  'm305',
#  'slackware',
#  'time-out',
#  'convore-ios',
#  'prototype',
#  'plancast-ios',
#  'menucalendarclock',
#  'realforce-105uk',
#  'powershot-g15',
#  'powershot-g11',
#  'powershot-g10',
#  'thinkpad-x301',
#  'ranger-a',
#  'tri-star',
#  'er4-micropro',
#  'the-skinny-sleeve-macbook-air',
#  'dac1-usb',
#  'cmf-1200',
#  'messagepad-2000',
#  'scooba-230',
#  'squirt-e4',
#  'mediamate',
#  'huckster',
#  'ulysses',
#  'ksc75',
#  'e-p1',
#  'digi-002',
#  'flextt5-nikon',
#  'fridgepad',
#  'visual-studio-express',
#  'aeon-timeline',
#  'mx310',
#  'eternal-daughter',
#  'xps-m1330',
#  'folding-at-home',
#  'nest',
#  'dr-100',
#  'uber-ios',
#  'weave',
#  'zr24w',
#  'spotify-ios',
#  'wolfram-alpha',
#  '500-cm',
#  'etherpad',
#  'whole-disk-encryption',
#  'stylus-pro-7800',
#  'hampshire-air',
#  'commodore-64',
#  'f-dick-multicut',
#  'neon',
#  'nike-plus',
#  'drop7-ios',
#  'ps2',
#  'ps3',
#  'wayback-machine',
#  'ipod-classic',
#  'beagle-usb-480',
#  'vibe-duo',
#  'scansnap-s1300',
#  'cloudreaders-ios',
#  'mactex',
#  'xacti-vpc-wh1',
#  'ipad-3g',
#  '3d-coat',
#  'camera-plus-ios',
#  'mp-60',
#  'simplenote-ios',
#  'ibeat-ios',
#  'touchpad',
#  'psp',
#  'mog',
#  '4104-commentators',
#  'readynas-nv-plus',
#  'pipe-earphones',
#  'scharger-5',
#  'verner',
#  'gnome-settings-daemon',
#  'laserjet-cp1210',
#  'living-lv2',
#  'af-s-nikkor-24mm-f1.4g-ed',
#  'h16-el',
#  'prompt-ios',
#  'thinkpad-t400',
#  'hot-rails',
#  'm8.2',
#  'traktor-pro',
#  'oculus-rift',
#  'bass-vi',
#  'coffee-mode',
#  'orbital-ios',
#  'exit-strategy-nyc-ios',
#  'google-talk',
#  'ddr',
#  'nook',
#  'goodsync-mac',
#  'laserjet-1300',
#  'mdr-ex10lp',
#  'lumix-dmc-g3',
#  'sparc-t2000',
#  'ag-hvx200a',
#  'drum-rocker-xbox',
#  'weather-channel-ios',
#  'envy-13t-1000',
#  'u-47',
#  'counter-strike-global-offensive',
#  'filter-forge',
#  'nb205',
#  'workfit-s',
#  'travel-battery-pack',
#  'jungle-disk',
#  'coolpix-aw100',
#  'cyber-shot-w120',
#  'alpha-flap',
#  'vintage-47',
#  'big-knob',
#  'messagepad-120',
#  'picoscope-2204',
#  'accolade-vx5600',
#  'tweetie',
#  'djm-800',
#  'battleheart-ios',
#  'fvwm',
#  'c03u',
#  'nord-lead-2',
#  'peggle-ios',
#  'e207wfp',
#  'everyday-ios',
#  'macbook-air',
#  'bbc-news-ios',
#  'seethru-macbook-air',
#  'emacs',
#  'slimtype-mac',
#  'optiplex-755',
#  'caviar-black',
#  'puzzlejuice-ios',
#  'worblas-finest-art',
#  'notebook-mac',
#  'mx-revolution',
#  'ladybug-portable-speaker',
#  'thinkpad-x40',
#  'shared-shell',
#  'illustrator',
#  'visual-foxpro',
#  'uad-2-quad',
#  'instantshot',
#  'bessa',
#  'words-with-friends-ios',
#  '2443bw',
#  'digital-timer-remote',
#  '1208',
#  'lp2475w',
#  '2x1-dvikvm-dl',
#  'elitebook-8530w',
#  'objective-c-plusplus',
#  'uim',
#  'objective-c',
#  'firebug',
#  'icon-udac',
#  'lumix-dmc-gh2',
#  'quickbooks',
#  'elements-ios',
#  'printrun',
#  'windows-xp',
#  'thinkpad-t40',
#  'thinkpad-t41',
#  'scansnap-s1500m',
#  'scroll-kit',
#  'eliss-ios',
#  'heil-sound-pl2t',
#  'fuelband-ios',
#  'noiseless-portable',
#  'atr-3350',
#  'path-ios',
#  'iclone-for-eve-online-ios',
#  'dropbox',
#  'pdfpenpro',
#  'renaissance-vox',
#  'remote',
#  '2m-red',
#  'icd-sx750',
#  'myspell',
#  'pro-motion',
#  'smc-da-16-50mm',
#  'tumblr-ios',
#  'satellite-l645d-s4100',
#  'identi.ca',
#  'e3c',
#  'on-ear',
#  'sk-1',
#  'henge-dock',
#  'air-sharing-ios',
#  'laserjet-2100tn',
#  'script.aculo.us',
#  'advantage-pro-usb',
#  'nytimes-ios',
#  'seesmic-desktop',
#  'vintage-warmer',
#  'clariphonic',
#  'remember-the-milk',
#  'happylight-deluxe',
#  'sj-xw44s',
#  'peekaboo-clear-console',
#  'vanishing-point',
#  'sk-10',
#  'native-client',
#  'media-composer',
#  'power-mac-g5',
#  'power-mac-g4',
#  'dj-1-pro',
#  'airport-express',
#  'mpd',
#  '2.4-ghz-cordless-presenter',
#  'ical',
#  'storejet-25',
#  'ts-e-90mm',
#  'eos-500d',
#  'iphone-4',
#  'iphone-5',
#  '382213',
#  'lisp',
#  '2big-quadra',
#  'sharpwriter',
#  'visual-thesaurus',
#  't2',
#  'vision-fine-0.7',
#  'af-nikkor-85mm-f1.8d',
#  'syncmaster-1100df',
#  'textmate-el',
#  'eos-60d',
#  'pbworks',
#  'groceries-ios',
#  'dungeon-raid-ios',
#  'galaxy-s-ii',
#  'id-500',
#  'brief',
#  'dotnet-memory-profiler',
#  'compuprimus-aw',
#  'stylus-cx7800',
#  'epiphone-les-paul-special-ii',
#  'laserjet-1200',
#  'iphone-3gs',
#  'org-mode',
#  'mule',
#  'omnifocus-ios',
#  'dr-web-windows',
#  'birdbrain-ios',
#  'u2711',
#  'app-engine-launcher',
#  'ca-2022r',
#  'arena',
#  'google-music',
#  '906',
#  'beta-52a',
#  'reason',
#  'github-for-mac',
#  'pma-1315r',
#  'pico',
#  'pcr-m80',
#  'superduper',
#  'optiplex-380',
#  'super-sculpey',
#  'vim',
#  'powertower-pro-250',
#  'glitch',
#  '5139',
#  'colorschemer-studio',
#  'google-voice-android',
#  'emperor-200',
#  'sketchbook-pro',
#  'mw600',
#  'rhel',
#  'aperture',
#  'cx-300-ii',
#  'quickbooks-online',
#  'pocket-mbta-ios',
#  'memeo-backup',
#  'stylus-pro-3800',
#  'openframeworks',
#  'lide-30',
#  'source-connect',
#  'cool-edit-pro',
#  'webkit',
#  'grendel-scan',
#  'gnus',
#  'evolver',
#  'mx-300',
#  'gps-3303',
#  '424-mkii',
#  'pandora-ios',
#  'optiplex-745',
#  'bit-pilot-ios',
#  'zite-ios',
#  'neoprene-sleeve-air',
#  'ro-80',
#  'squeezebox',
#  'v450-nano',
#  'xbox-360-controller-for-windows',
#  'fontlab-studio',
#  'flip-ultra-hd',
#  'freckle',
#  'neo-geo-mvs',
#  'windows-media-player',
#  'hf5',
#  'carbon-emacs',
#  'mill-colour-ios',
#  'ef-70-200mm-f2.8l-is-ii-usm',
#  'writeroom-ios',
#  'af-s-dx-nikkor-18-200mm-f3.5-5.6g-ed-vr-ii',
#  'sr80i',
#  'keyboard-maestro',
#  'mp-2nv',
#  'm500',
#  'intuos',
#  'voyager-q',
#  'wireless-presenter-r400',
#  'dm601-s3',
#  'compaq-6535b',
#  'h2a-xlr',
#  'noejectdelay',
#  'bookarc-ipad',
#  'audio-kontrol-1',
#  'macintosh-plus',
#  'dgs-2205',
#  'get-satisfaction',
#  'black-kbcover-apple-keyboard',
#  'photoshop',
#  'xperia-ray',
#  'air-video',
#  'iterm2',
#  'sublime-text-2',
#  'silver-river-duo',
#  'e250',
#  'express-xt',
#  'total-commander',
#  'px2370',
#  'quadcamera-ios',
#  'hario-v60',
#  'classic-30-112',
#  'serverlove',
#  'no-kahuna',
#  'icab-ios',
#  'ln40a550',
#  'chemex-6-cup',
#  'mk-8',
#  'gesshin-ginga-wa-gyuto',
#  'escalade-7850',
#  'mk-4',
#  'internet-explorer',
#  'powershot-s90',
#  'snowball',
#  'lx550',
#  'camerabag-ios',
#  'aego-m',
#  'mc1.0',
#  'oh-my-zsh',
#  'color-laserjet-cp2025',
#  'pac-man-ce-dx',
#  'nm705i',
#  'd3s',
#  'g-raid',
#  '1password',
#  'rokit-5',
#  'expert-variable-heat-hot-air-gun-kit',
#  'windows-phone',
#  'battery-3',
#  'keynote-ios',
#  '2001fp',
#  'quicktime-pro',
#  'companion-5',
#  'companion-3',
#  'generation',
#  'twitter-android',
#  'connect',
#  'me-52w',
#  'ristretto-ipad',
#  'fast-track-pro',
#  'spacemouse-pro',
#  'shapeways',
#  'nb505',
#  'tweetdeck',
#  'quartz-composer',
#  'microkorg-xl',
#  'spss-statistics',
#  'boxee-box',
#  'ef-100-400mm-f4.5-5.6l-is-usm',
#  'farmville-ios',
#  'radeon-hd-4870-mac',
#  'myhabit-ios',
#  'pro-tools-hd',
#  'masstransit-ios',
#  'photosmart-c4280',
#  'td-4kx2',
#  'bash',
#  'cub-01',
#  'grocery-iq-ios',
#  'chess-with-friends-ios',
#  'kuler',
#  'slimblade',
#  'html5-boilerplate',
#  'thunder-horn',
#  '85m-p-85mm-f1.4',
#  'x-pro1',
#  'scansnap-s510m',
#  'u3011',
#  'e2220hd',
#  'me-66',
#  'the-levelator',
#  '3ds',
#  'back-roller-plus',
#  'tf2',
#  'af-nikkor-28mm-f2.8d',
#  'laserjet-1320',
#  'delicious-library',
#  'aero-city',
#  '2407wfp',
#  'rails',
#  'vls-platform',
#  'wordpress-ios',
#  'paint',
#  'ken-onion-chive',
#  'music-streamer-ii',
#  'n770',
#  'shakeitphoto-ios',
#  'addictive-drums',
#  'pro-tools',
#  'easynews',
#  'tweetdeck-android',
#  'etsy',
#  'pandora-one',
#  'pro-reverb',
#  'colloquy-ios',
#  'ultimate5-plus',
#  'touchdraw-ios',
#  'manga-studio-ex',
#  'mdr-7506',
#  'a40',
#  'kindle',
#  'ibaby-feed-timer-ios',
#  'cyber-shot-hx5v',
#  'notational-velocity',
#  'spaceexplorer',
#  'pages-ios',
#  'mk-41',
#  'numberkey-ios',
#  'soundcloud-ios',
#  'c01u',
#  'capacitive-stylus',
#  'code-swarm',
#  'af-nikkor-14mm-f2.8d-ed',
#  'virtuoso-piano-free-2-hd-ios',
#  'ishowu-hd',
#  'tweetbot-ios',
#  'final-cut-pro',
#  'fisheye-2',
#  'raspberry-pi',
#  'confluence',
#  'promedia-2.1',
#  'thinkpad-x60',
#  'thinkpad-x61',
#  'lumix-g-20mm-f1.7-asph',
#  'eos-5d',
#  'softimage',
#  'd3.js',
#  'weightbot-ios',
#  'black-cat-classic',
#  'nexus-7',
#  'logic-pro',
#  'thinkpad-x220',
#  'readmill-ios',
#  'm510',
#  'gentoo',
#  'sql-developer',
#  'xcode',
#  'messages-ios',
#  'rock-block',
#  'ef-70-200mm-f2.8l-is-usm',
#  'convert-ios',
#  'blender',
#  'summicron-m-50mm-f2',
#  'mkh-30',
#  'rebel-xt',
#  'thinkpad-t61',
#  'kmr-81-i',
#  'taco-html-edit',
#  'cloud2go-ios',
#  'perfection-v30',
#  'royal-render',
#  'xmonad',
#  'k-701',
#  'silo',
#  'drobo-fs',
#  'marble-mouse',
#  'pacifica-312',
#  'cmc-5-ug',
#  'smugfolio-android',
#  'appdetectivepro',
#  'vaio-f-series',
#  'hf3',
#  'kindle-android',
#  'hd-201',
#  'last.fm',
#  'macbook-pro',
#  'wordpress-mu',
#  'ipod-touch',
#  'arc',
#  'rane-sl-4',
#  'atom-monitor',
#  'hi-tec-c',
#  'hautelook-ios',
#  'urbanspoon-ios',
#  'wow',
#  'bluetooth-sliding-keyboard-case',
#  'dreamcolor-lp2480zx',
#  'skype-ios',
#  'steambirds-survival',
#  'mytouch-3g-slide',
#  'w500',
#  'mimeo-ios',
#  'solo',
#  'toolbag',
#  '104ab',
#  'sm58',
#  'sm57',
#  'mint-ios',
#  'mie2i',
#  'powershot-sd1100-is',
#  'the-incident-ios',
#  'powercurl',
#  'cloud-player',
#  'eee-pad-transformer-tf101',
#  'small-business',
#  'svpply-ios',
#  'kindle-fire',
#  'af-s-nikkor-24-70mm-f2.8g-ed',
#  'markdown',
#  'battery',
#  'thinkpad-usb-keyboard',
#  'sp2309w',
#  'crazybump',
#  'polychord-ios',
#  'hex-fiend',
#  'scorpio-black',
#  'crashplan',
#  'jp-8080',
#  '3g-microcell',
#  'n300',
#  'boa-squeeze',
#  'opera-mini-android',
#  'jot-touch',
#  'spyder4-express',
#  'adventure-game-studio',
#  'kobracast-art',
#  'convertbot-ios',
#  'poang',
#  'imac',
#  'optical-mouse',
#  'ml-1750',
#  'applesoft-basic',
#  'magic-sculp',
#  'c-lux-3',
#  'c-lux-2',
#  'tigr',
#  'se-94',
#  'xa2',
#  'd5100',
#  'klocwork-insight',
#  'writeboard',
#  'mbox',
#  'lx7',
#  'gigaworks-t40',
#  'rx-320d',
#  'skype',
#  'ef-24mm-f1.4l-ii-usm',
#  'fedora',
#  'ibis-reader',
#  'electric-sheep',
#  'portege-r700',
#  'issh-ios',
#  'yeti',
#  'soulver-ios',
#  'leopard',
#  'strategery-ios',
#  '7ii',
#  'moment',
#  'time-capsule',
#  'magiscope-70',
#  'comic-zeal-ios',
#  'viveza',
#  'flixter-ios',
#  'optiplex-760',
#  'audio-overload',
#  'twist-erase',
#  'mandriva',
#  'ef-35mm-f1.4l-usm',
#  'nexus-s',
#  'things',
#  'cubase',
#  'bettertouchtool',
#  'mdr-cd180',
#  'itunes-remote',
#  'mysql',
#  'maschine',
#  'hd70',
#  'hd72',
#  'sr-225i',
#  'geodefense-swarm-ios',
#  'liveview-ios',
#  'foursquare-ios',
#  'skyquest-xt8i',
#  'omnigraffle-ios',
#  'cdj-1000',
#  'kinect',
#  'ecm77b',
#  'imageingester',
#  'ef-100mm-f2.8-macro-usm',
#  'eod-utility',
#  'imovie',
#  'apt',
#  'yashica-samurai',
#  'jerker',
#  'bip',
#  'd7000y',
#  'omnioutliner-pro',
#  'mifi',
#  'o-300',
#  'atv-flash',
#  'bamboo',
#  'glitch.2',
#  'boomerang-iii',
#  'google-reader',
#  'zub-zot-20',
#  'hanging-with-friends-ios',
#  'headspace-ios',
#  'k800i',
#  'razor-point',
#  'methode',
#  'iview-mediapro',
#  'mustang',
#  'pomodoro',
#  'integrated-225',
#  'x223w',
#  'on-the-job',
#  'stylus-photo-1280',
#  'marc-8-midi',
#  'speedlight-430ex',
#  'eshell',
#  'htcondor',
#  'schism-tracker',
#  'fireface-ucx',
#  'field-notes',
#  'col-erase',
#  'internet-tv-blu-ray',
#  'sr60i',
#  'intensity-pro',
#  'audio-hijack-pro',
#  '33xr',
#  'notepad-plusplus',
#  'artrage-studio',
#  'at4040',
#  'spotify-mac',
#  'gnome',
#  'displaywriter',
#  'smt-60a',
#  'feedler-ios',
#  'oa-desk',
#  'thinkpad-t530',
#  'swank-clojure',
#  'hd-650',
#  'the-hit-list-ios',
#  'subversion',
#  'vl600',
#  '4060',
#  'mkh-40',
#  'commodore-128',
#  'little-snitch',
#  'skycatcher',
#  'yelp-ios',
#  'mk-249c',
#  'visual-c-plusplus',
#  'ranger-quadra',
#  'fx-901',
#  'nytimes-crosswords-ios',
#  'sketchup',
#  'syncback',
#  'mendeley-ios',
#  'jbuds-j2',
#  'dns-323',
#  'telecaster',
#  'presario-sr1726nx',
#  'up',
#  'habit-list-ios',
#  'desire-hd',
#  'ua-101',
#  'tu-2',
#  'back-ups-pro-650va',
#  'qlmarkdown',
#  'satellite-110cs',
#  'rss5000-ios',
#  'configurable-usb-loader',
#  'super-jolly',
#  'mymoodtracker-ios',
#  'xb-14',
#  'st-v',
#  'scarlet',
#  'studiophile-bx5a',
#  'app-engine',
#  'ufo-enemy-unknown',
#  'benchtop-blast',
#  'podcast-maker',
#  'ipod-mini',
#  'tara',
#  'irccloud',
#  'worldwide-telescope',
#  'eos-5d-mark-iii',
#  'evolines',
#  'unreal-engine',
#  'mx-518',
#  'rememberance-agent',
#  'syncmaster-2343bwx-plus',
#  'lumix-dmc-tz4',
#  'lumix-dmc-tz3',
#  'google-calendar',
#  'kango-930',
#  'precision-470',
#  'mtv-music-generator',
#  'dividends-messenger',
#  '2000',
#  'the-unarchiver',
#  'textmate',
#  'marsedit',
#  'instacast-ios',
#  'km-184',
#  'albion',
#  'super-coolscan-9000-ed',
#  'coda',
#  'facebook-messenger-ios',
#  'creative-cloud',
#  'perfection-v500',
#  'google-drive',
#  'kindle-ios',
#  'la-tortuga',
#  'go',
#  'flash-builder',
#  'eos-7d',
#  'oh-chair',
#  'evo-shift-4g',
#  'screens-ios',
#  '150-series',
#  'take-five',
#  'plan-9-user-space',
#  'magic-lantern',
#  '960-grid-system',
#  'symphonic-instrument',
#  'g2',
#  'g1',
#  'h4n',
#  'whatsapp-ios',
#  'quora',
#  '645-pro-tl',
#  'blackwing',
#  'lytegem',
#  'wave',
#  'sensor-soap-pump',
#  'n5200',
#  'magic',
#  'plan-9',
#  'transmission',
#  'hive',
#  'magit',
#  'xacti-vpc-fh1a',
#  'thinkpad-x201',
#  'thinkpad-x200',
#  'garageband-ios',
#  'sensation',
#  'google-voice',
#  'tortoisesvn',
#  'pslx350h',
#  'espresso',
#  'nocs-ios',
#  'access',
#  'phantom-flex',
#  'vega',
#  'age-of-empires',
#  'inspiron-e1705',
#  'hn-7506',
#  'tlm-103',
#  'performance-p256',
#  'ubuntu',
#  'drobo',
#  'ef-800mm-f5.6l-is-usm',
#  'wheel-mouse-optical',
#  'casino',
#  'valve-junior',
#  'gaug.es',
#  'virtual-pc',
#  'firefox',
#  'latitude-z',
#  'activity-monitor',
#  'wii',
#  'd80',
#  'rebel-t3',
#  'gray-kunz-spoon',
#  'launchbar',
#  'websharing-android',
#  'natsulion-ios',
#  'copperhead',
#  'hydra',
#  'starcraft-2',
#  'katawa-shoujo',
#  'media-player-classic',
#  'eee-pc-701',
#  'ef-400mm-f2.8l-is-ii-usm',
#  'bitly',
#  'iie',
#  'rainmeter',
#  'iic',
#  'trackman-marble',
#  'titanico',
#  'movie-magic-screenwriter',
#  'firebird',
#  'zi6',
#  'elements-desktop',
#  'appledesign-powered-speakers',
#  'zeta-resource-editor',
#  'touchsmart-iq816',
#  'duet-2',
#  'latitude-e6430',
#  'fluke-170',
#  'concert-grand-model-d',
#  'takahiro.5',
#  'rocket-88',
#  'onion-8-inch',
#  'lala',
#  'wireless-presenter',
#  'gcc',
#  'tds2004b',
#  'promaster-2500edf-canon',
#  'tripit-android',
#  'flipnote-studio',
#  'bamboo.2',
#  'safari-4-reload-fix',
#  'clr-profiler',
#  'model-s-ultimate',
#  'safari-ios',
#  'perfection-v750-m-pro',
#  'pro-eq',
#  'notebook-cooler',
#  'sansa-clip',
#  'c-2000-b',
#  'ipod-shuffle',
#  'sm7b',
#  'zbrush',
#  'vjay-ios',
#  'noisees-ios',
#  'gesundheit-ios',
#  'stylus-sx218',
#  'syncmaster-730mp',
#  'my-passport-mac',
#  'weatherpro-ios',
#  'rockrider-5.0-men',
#  'elim',
#  'axiom-25',
#  'move',
#  'monster-fair-pinball',
#  'squier',
#  'puppet-cloud-provisioner',
#  'spotify',
#  'pro-keyboard',
#  'trials-hd',
#  'freeagent-go',
#  'sprocket-rocket',
#  'hpl-engine',
#  'camino',
#  'pango',
#  'slideshowpro-director',
#  'ecm-ds70p',
#  'aspell',
#  'stylus-photo-r2880',
#  'portable-puzzle-collection',
#  'ibooks-ios',
#  'merge',
#  'urx-p2',
#  'zooom',
#  'mikron',
#  'intellimouse',
#  'superior-platinum-double-edge',
#  'harbor-master-ios',
#  'ice-9',
#  'call-of-duty-world-at-war',
#  'cristal',
#  'spacenavigator-notebook',
#  'ec2',
#  'cinema-4d',
#  'gallant',
#  'powershot-a95',
#  'virt-manager',
#  'mobile-me',
#  'aeron',
#  'frontier',
#  'pullman',
#  'calcbot-ios',
#  'super-sonic-twin-combo',
#  'mighty-mouse',
#  'dr-880',
#  'cyanogen',
#  'robot-99-ios',
#  'ipod',
#  'day-one-ios',
#  'tweetdeck-ios',
#  'inspiron-mini-10',
#  'pitt-artist-pen',
#  'model-m',
#  'yeelong',
#  'gas-mask',
#  '4-color',
#  're2',
#  '2007fp',
#  'eve-online',
#  'xbox-360',
#  '450',
#  'optiplex-gx620',
#  'echo',
#  'thirty-3g',
#  'ef-85mm-f1.8-usm',
#  'dwarf-fortress',
#  'epresent',
#  'wikipanion-ios',
#  'attack',
#  'latitude-e4200',
#  'af-s-nikkor-24-120mm-f3.5-5.6g-if-ed',
#  'realforce-103u',
#  'iphone-4s',
#  'freeagent-goflex',
#  'pulse-smartpen',
#  'pinboard',
#  'logic-studio',
#  'droid-bionic',
#  'd90',
#  'dual-brush-pen-abt',
#  'deluxe-varitone',
#  '62-mini-infrared',
#  'ipad',
#  'dimension-2400',
#  'ipod-photo',
#  'wes51',
#  'paper-ios',
#  'ipad-3',
#  'ipad-2',
#  'embody',
#  'ufo-on-tape-ios',
#  'the-hit-list',
#  'ts-e-17mm',
#  'distortion-plus',
#  'magic-mouse',
#  'reeder',
#  'one-touch-tea-maker',
#  'perfection-2400-photo',
#  'natural-ergonomic-keyboard-4000',
#  'inspiron-6000',
#  'ds411slim',
#  'wave-radio-cd',
#  'galaxy-s-iii',
#  'babel',
#  'calendar-ios',
#  'pro-tools-le',
#  'af-nikkor-50mm-f1.8d',
#  'shooter-case',
#  'pa301w',
#  'safari-adblock',
#  'envoice',
#  'visor',
#  'xps-m1530',
#  'd6-elastomer',
#  'henry-xtra',
#  'red-hat-network',
#  'gallery',
#  'dark-room',
#  'kgs-go-server',
#  'v-ray',
#  'the-force-trainer',
#  'rx1000',
#  'uru',
#  'd300',
#  'ss-b1000',
#  'eee-pc-901',
#  'magic-trackpad',
#  'beyond-compare',
#  'eos-5d-mark-ii',
#  'teaboy-audio',
#  'naga',
#  'mdr-nc11',
#  'firewire-audiophile',
#  'velociraptor',
#  'paperless-field-guide',
#  'harmony-650',
#  'hp-c-plus',
#  'nms-350',
#  'mda-vst',
#  'ichat',
#  'terminal',
#  'p5.2',
#  'vgn-z690',
#  'mplab-ide',
#  'will-ray-signature',
#  'the-tread',
#  'starck',
#  '275t-plus',
#  'c-plusplus',
#  'buddha-machine-ios',
#  'google-authenticator-ios',
#  'echofon-ios',
#  'hyper-jump-android',
#  'cargo-bag',
#  'mplab-icd-3',
#  'big-sky-slt',
#  'istat-menus',
#  'px-100',
#  'fret-war',
#  'color-synthaxis',
#  'tipulator-ios',
#  'mahogany-ukulele',
#  'rebel-xti',
#  'inkling',
#  'travis',
#  'baby-log-ios',
#  'scansnap-s510',
#  'discovery-975',
#  'photo-mechanic',
#  'gmail',
#  'teuxdeux',
#  '1password-ios',
#  'the-scribbler',
#  'keynote',
#  'pigma-micron',
#  'aquamacs',
#  'at2020',
#  'littlesnapper',
#  'f-5xb',
#  'ultralite-mk3',
#  'classic-50',
#  'os-2',
#  'mongoliad-ios',
#  'quicken-deluxe',
#  'k10d',
#  'fast-track-ultra',
#  'studiophile-av-40',
#  'triple-town',
#  'ipm-tab1',
#  'the-last-rocket-ios',
#  'g-drive-mini',
#  'pre-2',
#  'fireface-800',
#  '3ds-max',
#  'sound-studio',
#  'dot-grid-book',
#  'sth-8bld-3',
#  'f.lux',
#  '645af',
#  'evo-3d',
#  'thinkpad-t400s',
#  '3d-slicer',
#  'ef-28-70mm-f2.8l-usm',
#  'jstalk',
#  'smartstor-ds4600',
#  'ld-3-mkii',
#  'rock-band',
#  'greplin-ios',
#  'painter',
#  'optime-105',
#  'eos-350d',
#  'lumix-dmc-lx5',
#  'lumix-dmc-lx2',
#  'lumix-dmc-lx3',
#  'fluke-179',
#  'g70',
#  '70-200mm-ex-dg',
#  'lumix-dmc-fz35',
#  'galaxy-nexus',
#  'ef-14mm-f2.8l-ii-usm',
#  'stanza-ios',
#  'procreate-ios',
#  'tds5104b',
#  'surface',
#  'ha-fxc51',
#  'solipskier-ios',
#  'dso-quad',
#  'spaceteam-ios',
#  'remote-desktop-client',
#  'xps-17',
#  'virb',
#  'soundprism-ios',
#  'v-studio-100',
#  'linode',
#  'listary-ios',
#  '2do-ios',
#  'unity',
#  'hipstamatic-ios',
#  'android',
#  'minohd',
#  'ball',
#  'beertools-pro',
#  'colorbind-ios',
#  'premiere',
#  'ios',
#  'envelope-for-ipad',
#  'g-301-gel',
#  'openoffice',
#  'eos-30d',
#  'audible-ios',
#  'the-hype-machine',
#  'v8',
#  'ws-ftp-pro',
#  'n-stalker',
#  'back-roller-classic',
#  'voxel-ios',
#  'waxed-canvas-messenger',
#  'picsay-pro',
#  'contax-t2',
#  'catch-notes-android',
#  'lotus-notes',
#  'kontakt',
#  '2510i',
#  'powershot-sd1200-is',
#  'd200',
#  'ef-135mm-f2l-usm',
#  'bm5a-mkii',
#  'c-sharp',
#  'syncmaster-244t',
#  'sprint-pro-ii',
#  'compass-597',
#  'reel-drums',
#  'osmos-ios',
#  'se530',
#  'crooked-house-ios',
#  'gnome-do',
#  'ptlens',
#  'fun-machine',
#  'powerbook-g4',
#  'pattern-design',
#  'mars-lumograph',
#  'mac-mini',
#  'photoshop-elements',
#  'google-test',
#  'k-240-studio',
#  'thinkpad-x201s',
#  '7700-half-mask',
#  'readynas-duo',
#  'labelwriter-twin-turbo',
#  'propeller',
#  'mail-act-on',
#  'roomba-550',
#  'twidroid-android',
#  'amazon-mobile-ios',
#  'webcam-notebook',
#  'ozone',
#  'solar-keyboard-folio',
#  'free-menstrual-calendar-ios',
#  'portal-2',
#  'l1d-ce',
#  'twitter',
#  'dt-770-pro',
#  'super-smartjoy',
#  'actius-rd3d',
#  'flasher-v7',
#  '7070a',
#  'esn40c',
#  'domehub',
#  'guitar-rig-pro',
#  'photosmart-c4580',
#  'nv24hd',
#  'c-lux-1',
#  'twitkitteh-ios',
#  'vaio-j11bfx',
#  'hl-2170w',
#  'hd-280-pro',
#  'myron',
#  'signo-gel-rt',
#  'tunein-radio-ios',
#  'psp-go',
#  'katamari-damacy',
#  'terra',
#  'clear-harmony',
#  'thinkpad-mini-dock',
#  'nook-color',
#  'mirra',
#  'w2452t',
#  'toon-boom-studio',
#  'powerbook-145b',
#  'powerpoint',
#  'powershot-sd1000',
#  'peak',
#  'gilt-ios',
#  'mono-regular',
#  'final-cut-studio',
#  'h1',
#  'autopano-pro',
#  'sigma-30mm-f1.4',
#  'atl-618evs',
#  'champ',
#  'kindle-for-mac',
#  'virtualbox',
#  'cocon',
#  'risom-desk',
#  'ef-16-35mm-f2.8l-ii-usm',
#  'radium-61',
#  'laserwriter-12-640',
#  'alexa',
#  'writeroom',
#  '635a',
#  'audiofire8',
#  'jtagice3',
#  'mkh-60',
#  'apollo',
#  'joes-goals',
#  'af-nikkor-16mm-f2.8d',
#  'stylus-pro-3880',
#  'twitter-ios',
#  'lync',
#  'cross-check-complete',
#  'chosera',
#  'soundsticks',
#  'hunspell',
#  'system-9098',
#  'micro-synthesizer',
#  'manga-studio-debut',
#  'red-hat-enterprise-desktop',
#  'altium-designer',
#  'ywriter',
#  'minitt1-nikon',
#  'resharper',
#  'nabaztag',
#  'nero-burning-rom',
#  'scim',
#  'vita-prep',
#  'devonthink',
#  'debian',
#  'byline-ios',
#  'm9-vi1000',
#  'd2-quadra',
#  'path-finder']

# %%
ff.ix[:,['macbook-pro','cat_designer']].sum()
# Out:
# macbook-pro     181
# cat_designer     74
# dtype: float64

# %%
designer_data = cw_frame.ix[ff.cat_designer==1].transpose()

# %%
designer_data.sum().order()[-10:].plot(kind='bar')

# %%
cats_frame.ix[:,225]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-146-7c614cd6dddb> in <module>()
# ----> 1 cats_frame.ix[:,225]
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      44                 pass
#      45
# ---> 46             return self._getitem_tuple(key)
#      47         else:
#      48             return self._getitem_axis(key, axis=0)
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     250     def _getitem_tuple(self, tup):
#     251         try:
# --> 252             return self._getitem_lowerdim(tup)
#     253         except IndexingError:
#     254             pass
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_lowerdim(self, tup)
#     359         for i, key in enumerate(tup):
#     360             if _is_label_like(key) or isinstance(key, tuple):
# --> 361                 section = self._getitem_axis(key, axis=i)
#     362
#     363                 # we have yielded a scalar ?
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     407
#     408                 if not _is_integer_index(labels):
# --> 409                     return self._get_loc(key, axis=axis)
#     410
#     411             return self._get_label(key, axis=axis)
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _get_loc(self, key, axis)
#      61
#      62     def _get_loc(self, key, axis=0):
# ---> 63         return self.obj._ixs(key, axis=axis)
#      64
#      65     def _slice(self, obj, axis=0, raise_on_error=False):
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _ixs(self, i, axis, copy)
#    1893             """
#    1894
# -> 1895             label = self.columns[i]
#    1896             if isinstance(i, slice):
#    1897                 # need to return view
#
# /Users/lpd/anaconda/lib/python2.7/site-packages/pandas/core/index.pyc in __getitem__(self, key)
#     373         arr_idx = self.view(np.ndarray)
#     374         if np.isscalar(key):
# --> 375             return arr_idx[key]
#     376         else:
#     377             if com._is_bool_indexer(key):
#
# IndexError: index 225 is out of bounds for axis 0 with size 70

# %%
len(unique_wares)
# Out:
# 2177

# %%
dd.index
# Out:
# Index([apex-model-edge-pro-system, precision-bass, verticalmouse, ..., m9-vi1000, d2-quadra, path-finder], dtype=object)

# %%
dd.sum().order()[-10:]
# Out:
# 255    25
# 271    25
# 179    30
# 238    30
# 152    32
# 211    32
# 282    37
# 121    38
# 234    39
# 225    46
# dtype: float64

# %%
whos
# Out:
# Variable              Type         Data/Info
# --------------------------------------------
# DOTALL                int          16
# all_cats              list         n=1190
# all_interviews        list         n=353
# all_wares             list         n=3230
# base_dir              str          /Users/lpd/gh/usesthis/
# cat                   list         n=2
# cats_frame            DataFrame    <class 'pandas.core.frame<...>lues\ndtypes: float64(70)
# cf                    DataFrame    <class 'pandas.core.frame<...>lues\ndtypes: float64(70)
# dd                    DataFrame    <class 'pandas.core.frame<...>lues\ndtypes: float64(74)
# desc                  dict         n=5
# designer_data         DataFrame    <class 'pandas.core.frame<...>lues\ndtypes: float64(74)
# each_used_ware        list         n=4878
# el                    str          /Users/lpd/gh/usesthis//wares/zwoptex.yml
# ff                    DataFrame    <class 'pandas.core.frame<...>er\ndtypes: float64(2247)
# findall               function     <function findall at 0x100466f50>
# glob                  module       <module 'glob' from '/Use<...>/lib/python2.7/glob.pyc'>
# i                     int          352
# interview             dict         n=6
# interview_file        file         <closed file '/Users/lpd/<...> mode 'r' at 0x108eb3f60>
# interview_file_name   str          /Users/lpd/gh/usesthis//_<...>cameron.walters.interview
# interview_files       list         n=353
# interview_frame       DataFrame    <class 'pandas.core.frame<...>values\ndtypes: object(3)
# markdown              module       <module 'markdown' from '<...>s/markdown/__init__.pyc'>
# match                 function     <function match at 0x100466cf8>
# md_string             str          ---\nlayout: interview\ns<...>M, please? VMs use a lot.
# os                    module       <module 'os' from '/Users<...>da/lib/python2.7/os.pyc'>
# p_wares               DataFrame    <class 'pandas.core.frame<...>values\ndtypes: object(5)
# pd                    module       <module 'pandas' from '/U<...>ges/pandas/__init__.pyc'>
# person_categories     list         n=2
# person_ware           list         n=12
# person_wares          list         n=12
# ps_wares              Series       0          macbook-pro\n1<...>ngth: 4878, dtype: object
# unique_cats           set          set(['crafter', 'biker', <...>', 'baker', 'usability'])
# unique_wares          set          set(['apex-model-edge-pro<...>-quadra', 'path-finder'])
# wares                 tuple        n=2
# wares_frame           DataFrame    <class 'pandas.core.frame<...>er\ndtypes: float64(2177)
# wf                    DataFrame    <class 'pandas.core.frame<...>er\ndtypes: float64(2177)
# yaml                  module       <module 'yaml' from '/Use<...>kages/yaml/__init__.pyc'>
# yml_header            str          ---\nlayout: interview\ns<...>egories: [developer, mac]

# %%
list(unique_wares)[255]
# Out:
# 'mousepose'

# %%
ff
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353 entries, 0 to 352
# Columns: 2250 entries, cat_crafter to wares
# dtypes: float64(2247), object(3)

# %%
dev_data = cats_frame.ix[ff.cat_developer==1,unique_wares].transpose()

# %%
dev_data.sum().sort()[-10:].plot(kind='barh')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-f8ba785c284e> in <module>()
# ----> 1 dev_data.sum().sort()[-10:].plot(kind='barh')
#
# TypeError: 'NoneType' object has no attribute '__getitem__'
