# %% [markdown]
# ### Analysis of the data from usesthis.com
#
# The Setup at usesthis.com finds out what people use to get their job done. This is an effort to try to read and analyze that data.
#
# The base dir is the location where the github url of the usesthis repo is checked out.

# %%
import pandas as pd
import os, markdown, glob, yaml
from re import match, findall, DOTALL
base_dir = '/Users/lpd/gh/usesthis/'

interview_files = glob.glob('%s/_posts/*'%base_dir)

all_interviews = []
for interview_file_name in interview_files:
    with open(interview_file_name,'r') as interview_file:
        md_string = interview_file.read()
        yml_header = match('(?P<yml>^---.*)\n---', md_string, DOTALL).groupdict()['yml']
        interview = yaml.load(yml_header)
        interview['wares'] = [wares[1] for wares in findall('\[([^\[\(\)]+)\]\[([a-z0-9\.\-]+)?\]', md_string) if wares[1]]
        all_interviews.append(interview)
interview_frame = pd.DataFrame(all_interviews)

del interview_frame['layout']
del interview_frame['credits']
del interview_frame['summary']
del interview_frame['title']

each_used_ware = []
for person_ware in interview_frame.wares:
    each_used_ware+=person_ware
ps_wares = pd.Series(each_used_ware)

ps_wares.value_counts()

ps_wares.value_counts()[:15].plot(kind='bar')

# %%
print interview_frame.ix[:59,]
# Out:
#                                  categories license                      slug  \
# 0                     [developer, mac, web]     NaN                alex.payne
# 1                           [mac, musician]     NaN             jona.bechtolt
# 2                     [game, suit, windows]     NaN               gabe.newell
# 3                [developer, mac, software]     NaN              steven.frank
# 4                             [mac, writer]     NaN               john.gruber
# 5                       [artist, icon, mac]     NaN              david.lanham
# 6                           [mac, musician]     NaN          jonathan.coulton
# 7            [developer, mac, web, windows]     NaN                       why
# 8    [developer, mac, web, windows, writer]     NaN              gina.trapani
# 9                     [developer, mac, web]     NaN               paul.graham
# 10               [developer, mac, software]     NaN             james.thomson
# 11                   [developer, game, mac]     NaN             steph.thirion
# 12         [developer, film, mac, software]     NaN            garrett.murray
# 13               [developer, mac, software]     NaN         sophia.teutschler
# 14               [developer, mac, software]     NaN            alex.kohlhofer
# 15               [developer, mac, software]     NaN               anselm.hook
# 16               [developer, mac, software]     NaN                   ben.fry
# 17           [designer, usability, windows]     NaN             jakob.nielsen
# 18               [developer, mac, software]     NaN                joe.hewitt
# 19       [developer, mac, software, writer]     NaN             john.siracusa
# 20                       [mac, sex, writer]     NaN               violet.blue
# 21                            [artist, mac]     NaN                 sam.brown
# 22                            [artist, mac]     NaN                john.martz
# 23                    [designer, game, mac]     NaN             steve.jackson
# 24                        [mac, researcher]     NaN                danah.boyd
# 25             [designer, linux, usability]     NaN              mairin.duffy
# 26            [designer, entrepreneur, mac]     NaN                amit.gupta
# 27    [developer, mac, podcaster, software]     NaN              dan.benjamin
# 28                     [designer, mac, web]     NaN                 khoi.vinh
# 29                     [designer, mac, web]     NaN                   amy.hoy
# 30               [developer, mac, software]     NaN             allan.odgaard
# 31                     [designer, mac, web]     NaN           jeffrey.zeldman
# 32           [developer, mac, web, windows]     NaN             cal.henderson
# 33               [developer, mac, software]     NaN            loren.brichter
# 34     [developer, hacker, linux, mac, web]     NaN              aaron.swartz
# 35                     [designer, mac, web]     NaN             dan.cederholm
# 36             [developer, linux, software]   by-nd          richard.stallman
# 37          [developer, linux, web, writer]     NaN              mark.pilgrim
# 38                    [designer, game, mac]     NaN             adam.saltsman
# 39        [developer, game, linux, windows]     NaN              jason.rohrer
# 40             [designer, mac, web, writer]     NaN             derek.powazek
# 41               [designer, interface, mac]     NaN              anne.halsall
# 42               [developer, mac, software]     NaN               bert.kersey
# 43                      [mac, suit, writer]     NaN              guy.kawasaki
# 44                    [developer, mac, web]     NaN  david.heinemeier.hansson
# 45                [journalist, mac, writer]     NaN            bobbie.johnson
# 46       [hacker, hardware, linux, windows]     NaN              andrew.huang
# 47                [developer, web, windows]     NaN     blaise.aguera.y.arcas
# 48               [developer, mac, software]     NaN                  tim.bray
# 49                  [artist, mac, sysadmin]     NaN              maggie.mcfee
# 50                   [mac, windows, writer]     NaN              joel.johnson
# 51          [developer, game, mac, windows]     NaN            american.mcgee
# 52                      [musician, windows]     NaN         christopher.leary
# 53                  [designer, mac, writer]     NaN                 craig.mod
# 54  [editor, journalist, mac, photographer]     NaN            ben.hammersley
# 55               [bsd, developer, software]     NaN            colin.percival
# 56                [poet, security, windows]     NaN               sue.allspaw
# 57                   [blogger, hacker, mac]     NaN              laura.khalil
# 58         [mac, manager, software, writer]     NaN              michael.lopp
# 59       [designer, interface, mac, writer]     NaN             dustin.curtis
#
#                                                 wares
# 0   [macbook-pro, cinema-display, readynas-nv-plus...
# 1   [audio-kontrol-1, powershot-sd1000, live, mda-...
# 2   [oa-desk, beyond-tv, windows-xp, office, visua...
# 3   [mac-pro, macbook-air, apple-tv, itunes, addre...
# 4   [macbook-pro, cinema-display, iphone-3g, gr-di...
# 5   [mac-pro, intuos, cintiq, illustrator, on-the-...
# 6   [mac-mini, digi-002, 376, pod-pro, mx200, ksm3...
# 7                                                  []
# 8   [macbook-pro, icurve, jerker, g1, windows-xp, ...
# 9   [macbook-air, cinema-display, google-calendar,...
# 10  [twitkitteh-ios, mac-pro, ipod-touch, filemake...
# 11  [eliss-ios, macbook-pro, ipod-touch, sk-10, ma...
# 12  [ego-ios, macbook-pro, cinema-display, keyboar...
# 13  [groceries-ios, tipulator-ios, macbook-pro, ti...
# 14  [no-kahuna, e207wfp, xbox-360, keyboard, eee-p...
# 15  [macbook-pro, mac-os-x, c-plusplus, c-sharp, y...
# 16  [macbook-pro, cinema-display, macbook-air, com...
# 17  [3007wfp, acer-ferrari-5000, ipod-touch, windo...
# 18  [mac-pro, cinema-display, macbook-air, iphone-...
# 19  [mac-pro, cinema-display, gigaworks-t40, mx-30...
# 20  [mac-mini, cinema-display, ipod-nano, lumix-dm...
# 21  [power-mac-g5, cintiq, intuos, powerbook-g4, m...
# 22  [mac-pro, studio-display, cintiq, time-capsule...
# 23  [macbook-pro, laserjet-cp1210, laserjet-1200, ...
# 24  [iphone-3g, mac-mini, mac-os-x, time-machine, ...
# 25  [thinkpad-x61, precision-470, rhel, power-mac-...
# 26  [macbook-pro, iphone-3gs, syncmaster-244t, adv...
# 27  [macbook-pro, cinema-display, keyboard, v450-n...
# 28  [macbook-air, seethru-macbook-air, black-kbcov...
# 29  [macbook-pro, cinema-display, pro-keyboard, ex...
# 30  [commodore-64, mac-pro, mighty-mouse, cinema-d...
# 31  [imac, eames-desk, macbook-pro, tweetie-ios, m...
# 32  [mac-pro, boot-camp, keyboard, 3008wfp, compan...
# 33  [mac-pro, macbook-pro, cinema-display, keyboar...
# 34  [macbook-pro, appledesign-powered-speakers, ml...
# 35  [macbook-pro, powerbook-g4, cinema-display, ke...
# 36                                 [yeelong, xfree86]
# 37  [thinkcentre-m57p, 2407wfp, 275t-plus, customi...
# 38  [wurdle-ios, canabalt-ios, time-machine, airpo...
# 39  [inspiron-4100, powertower-pro-250, mac-mini, ...
# 40  [iphone-3gs, macbook-pro, eos-5d, labelwriter-...
# 41  [macbook-pro, cinema-display, keyboard, mighty...
# 42  [macbook-pro, g-raid, powerbook-g4, hdr-fx7, i...
# 43  [macbook-pro, magic-mouse, mac-pro, cinema-dis...
# 44  [rails, cinema-display, macbook-pro, macbook-a...
# 45       [mac-pro, macbook-pro, powerbook-g4, chrome]
# 46  [thinkpad-t61p, thinkpad-mini-dock, w2452t, c3...
# 47  [vgn-z690, iphone-3gs, windows-7, office, visu...
# 48  [macbook-pro, mac-pro, windows-7, i9900, dac1-...
# 49  [ubuntu, mac-pro, macbook-air, readynas-nv-plu...
# 50  [macbook-pro, windows-7, l4d2, tf2, mac-mini, ...
# 51  [iphone-3g, dexiq-ios, crooked-house-ios, kind...
# 52  [windows-7, radeon-hd-4850, micro-q-phoenix, e...
# 53  [macbook-pro, cinema-display, time-capsule, ma...
# 54  [macbook-pro, macbook-air, weave, instapaper-i...
# 55  [xps-m1530, g1, httpd, twidroid-android, conne...
# 56  [iphone-3g, powershot-a95, word, excel, n-stal...
# 57  [moment, d40, powershot-sd1100-is, skyquest-xt...
# 58  [macbook-pro, macbook-air, dividends-messenger...
# 59  [macbook-pro, hd-600, se530, rebel-t1i, jungle...

# %%
interview_frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 372
# Data columns (total 4 columns):
# categories    373  non-null values
# license       1  non-null values
# slug          373  non-null values
# wares         373  non-null values
# dtypes: object(4)

# %%
len(ps_wares)
# Out:
# 5066

# %%
iv_cats = interview_frame.categories

# %%
all_cats = []
for el in iv_cats:
    all_cats+=el

# %%
all_cats
# Out:
# ['developer',
#  'mac',
#  'web',
#  'mac',
#  'musician',
#  'game',
#  'suit',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'mac',
#  'writer',
#  'artist',
#  'icon',
#  'mac',
#  'mac',
#  'musician',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'writer',
#  'developer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'game',
#  'mac',
#  'developer',
#  'film',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'designer',
#  'usability',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'writer',
#  'mac',
#  'sex',
#  'writer',
#  'artist',
#  'mac',
#  'artist',
#  'mac',
#  'designer',
#  'game',
#  'mac',
#  'mac',
#  'researcher',
#  'designer',
#  'linux',
#  'usability',
#  'designer',
#  'entrepreneur',
#  'mac',
#  'developer',
#  'mac',
#  'podcaster',
#  'software',
#  'designer',
#  'mac',
#  'web',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'hacker',
#  'linux',
#  'mac',
#  'web',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'linux',
#  'software',
#  'developer',
#  'linux',
#  'web',
#  'writer',
#  'designer',
#  'game',
#  'mac',
#  'developer',
#  'game',
#  'linux',
#  'windows',
#  'designer',
#  'mac',
#  'web',
#  'writer',
#  'designer',
#  'interface',
#  'mac',
#  'developer',
#  'mac',
#  'software',
#  'mac',
#  'suit',
#  'writer',
#  'developer',
#  'mac',
#  'web',
#  'journalist',
#  'mac',
#  'writer',
#  'hacker',
#  'hardware',
#  'linux',
#  'windows',
#  'developer',
#  'web',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'artist',
#  'mac',
#  'sysadmin',
#  'mac',
#  'windows',
#  'writer',
#  'developer',
#  'game',
#  'mac',
#  'windows',
#  'musician',
#  'windows',
#  'designer',
#  'mac',
#  'writer',
#  'editor',
#  'journalist',
#  'mac',
#  'photographer',
#  'bsd',
#  'developer',
#  'software',
#  'poet',
#  'security',
#  'windows',
#  'blogger',
#  'hacker',
#  'mac',
#  'mac',
#  'manager',
#  'software',
#  'writer',
#  'designer',
#  'interface',
#  'mac',
#  'writer',
#  'hacker',
#  'hardware',
#  'mac',
#  'windows',
#  'designer',
#  'developer',
#  'software',
#  'artist',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'scientist',
#  'software',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'designer',
#  'game',
#  'mac',
#  'mac',
#  'software',
#  'suit',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'designer',
#  'developer',
#  'mac',
#  'musician',
#  'software',
#  'designer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'software',
#  'writer',
#  'developer',
#  'mac',
#  'software',
#  'web',
#  'mac',
#  'professor',
#  'researcher',
#  'scientist',
#  'developer',
#  'game',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'writer',
#  'designer',
#  'editor',
#  'mac',
#  'writer',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'food',
#  'mac',
#  'writer',
#  'comedian',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'hacker',
#  'mac',
#  'software',
#  'musician',
#  'windows',
#  'developer',
#  'mac',
#  'suit',
#  'web',
#  'musician',
#  'windows',
#  'mac',
#  'software',
#  'suit',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'mac',
#  'photographer',
#  'software',
#  'developer',
#  'software',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'windows',
#  'artist',
#  'film',
#  'mac',
#  'developer',
#  'mac',
#  'web',
#  'artist',
#  'designer',
#  'mac',
#  'developer',
#  'game',
#  'mac',
#  'writer',
#  'artist',
#  'designer',
#  'developer',
#  'game',
#  'mac',
#  'game',
#  'mac',
#  'writer',
#  'developer',
#  'web',
#  'windows',
#  'designer',
#  'mac',
#  'type',
#  'web',
#  'game',
#  'suit',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'systems',
#  'windows',
#  'writer',
#  'developer',
#  'mac',
#  'web',
#  'writer',
#  'designer',
#  'developer',
#  'game',
#  'mac',
#  'web',
#  'artist',
#  'mac',
#  'developer',
#  'mac',
#  'web',
#  'game',
#  'suit',
#  'windows',
#  'developer',
#  'journalist',
#  'mac',
#  'web',
#  'mac',
#  'photographer',
#  'windows',
#  'designer',
#  'developer',
#  'mac',
#  'web',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'windows',
#  'artist',
#  'developer',
#  'mac',
#  'windows',
#  'hacker',
#  'mac',
#  'space',
#  'artist',
#  'designer',
#  'mac',
#  'writer',
#  'mac',
#  'writer',
#  'developer',
#  'mac',
#  'software',
#  'web',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'suit',
#  'web',
#  'developer',
#  'mac',
#  'suit',
#  'web',
#  'mac',
#  'photographer',
#  'artist',
#  'designer',
#  'developer',
#  'film',
#  'mac',
#  'musician',
#  'software',
#  'editor',
#  'mac',
#  'writer',
#  'designer',
#  'mac',
#  'software',
#  'web',
#  'developer',
#  'game',
#  'mac',
#  'actor',
#  'game',
#  'mac',
#  'musician',
#  'suit',
#  'developer',
#  'mac',
#  'web',
#  'developer',
#  'hacker',
#  'mac',
#  'software',
#  'designer',
#  'mac',
#  'software',
#  'web',
#  'biker',
#  'coffee',
#  'designer',
#  'mac',
#  'web',
#  'designer',
#  'mac',
#  'researcher',
#  'writer',
#  'editor',
#  'mac',
#  'writer',
#  'artist',
#  'mac',
#  'fashion',
#  'hacker',
#  'windows',
#  'coffee',
#  'mac',
#  'suit',
#  'designer',
#  'film',
#  'hacker',
#  'windows',
#  'developer',
#  'film',
#  'mac',
#  'software',
#  'windows',
#  'community',
#  'librarian',
#  'mac',
#  'writer',
#  'designer',
#  'editor',
#  'mac',
#  'mac',
#  'podcaster',
#  'writer',
#  'designer',
#  'interface',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'artist',
#  'hacker',
#  'hardware',
#  'linux',
#  'scientist',
#  'windows',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'data',
#  'mac',
#  'scientist',
#  'designer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'editor',
#  'mac',
#  'writer',
#  'designer',
#  'developer',
#  'game',
#  'mac',
#  'web',
#  'mac',
#  'photographer',
#  'mac',
#  'writer',
#  'developer',
#  'game',
#  'mac',
#  'developer',
#  'mac',
#  'software',
#  'biker',
#  'designer',
#  'developer',
#  'mac',
#  'web',
#  'designer',
#  'interface',
#  'mac',
#  'editor',
#  'mac',
#  'windows',
#  'writer',
#  'artist',
#  'designer',
#  'mac',
#  'artist',
#  'film',
#  'mac',
#  'windows',
#  'editor',
#  'mac',
#  'windows',
#  'writer',
#  'artist',
#  'mac',
#  'teacher',
#  'windows',
#  'designer',
#  'game',
#  'windows',
#  'designer',
#  'game',
#  'mac',
#  'windows',
#  'developer',
#  'linux',
#  'software',
#  'windows',
#  'mac',
#  'photographer',
#  'artist',
#  'developer',
#  'mac',
#  'web',
#  'developer',
#  'mac',
#  'web',
#  'artist',
#  'mac',
#  'artist',
#  'designer',
#  'game',
#  'windows',
#  'mac',
#  'scientist',
#  'software',
#  'mac',
#  'musician',
#  'technologist',
#  'engineer',
#  'mac',
#  'space',
#  'data',
#  'linux',
#  'mac',
#  'politics',
#  'scientist',
#  'mac',
#  'professor',
#  'scientist',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'artist',
#  'film',
#  'mac',
#  'windows',
#  'artist',
#  'icon',
#  'mac',
#  'developer',
#  'web',
#  'windows',
#  'engineer',
#  'mac',
#  'service',
#  'mac',
#  'writer',
#  'designer',
#  'developer',
#  'illustrator',
#  'mac',
#  'software',
#  'developer',
#  'linux',
#  'mac',
#  'musician',
#  'software',
#  'writer',
#  'mac',
#  'writer',
#  'artist',
#  'designer',
#  'mac',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'musician',
#  'web',
#  'developer',
#  'game',
#  'windows',
#  'artist',
#  'mac',
#  'photographer',
#  'designer',
#  'interface',
#  'mac',
#  'scientist',
#  'developer',
#  'mac',
#  'software',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'web',
#  'developer',
#  'mac',
#  'software',
#  'web',
#  'linux',
#  'suit',
#  'mac',
#  'photographer',
#  'sex',
#  'designer',
#  'mac',
#  'type',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'web',
#  'designer',
#  'developer',
#  'interface',
#  'mac',
#  'windows',
#  'designer',
#  'photographer',
#  'hacker',
#  'hardware',
#  'linux',
#  'mac',
#  'windows',
#  'linux',
#  'mac',
#  'professor',
#  'mac',
#  'software',
#  'web',
#  'developer',
#  'mac',
#  'musician',
#  'web',
#  'designer',
#  'mac',
#  'writer',
#  'designer',
#  'mac',
#  'suit',
#  'writer',
#  'mac',
#  'software',
#  'web',
#  'developer',
#  'linux',
#  'software',
#  'developer',
#  'mac',
#  'web',
#  'mac',
#  'scientist',
#  'web',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'designer',
#  'game',
#  'mac',
#  'writer',
#  'artist',
#  'developer',
#  'game',
#  'mac',
#  'teacher',
#  'windows',
#  'writer',
#  'artist',
#  'developer',
#  'game',
#  'mac',
#  'designer',
#  'game',
#  'scientist',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'writer',
#  'editor',
#  'mac',
#  'writer',
#  'developer',
#  'mac',
#  'software',
#  'web',
#  'artist',
#  'film',
#  'mac',
#  'musician',
#  'developer',
#  'mac',
#  'software',
#  'windows',
#  'data',
#  'linux',
#  'mac',
#  'scientist',
#  'developer',
#  'mac',
#  'software',
#  'writer',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'developer',
#  'mac',
#  'web',
#  'developer',
#  'game',
#  'mac',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'designer',
#  'developer',
#  'interface',
#  'linux',
#  'mac',
#  'software',
#  'animator',
#  'windows',
#  'designer',
#  'mac',
#  'photographer',
#  'technologist',
#  'interface',
#  'mac',
#  'researcher',
#  'designer',
#  'editor',
#  'mac',
#  'writer',
#  'entrepreneur',
#  'linux',
#  'politics',
#  'data',
#  'linux',
#  'mac',
#  'scientist',
#  'developer',
#  'mac',
#  'software',
#  'web',
#  'game',
#  'windows',
#  'writer',
#  'film',
#  'mac',
#  'film',
#  'mac',
#  'writer',
#  'designer',
#  'mac',
#  'designer',
#  'interface',
#  'mac',
#  'mac',
#  'researcher',
#  'scientist',
#  'hacker',
#  'linux',
#  'social',
#  'software',
#  'designer',
#  'mac',
#  'writer',
#  'comedian',
#  'mac',
#  'writer',
#  'mac',
#  'writer',
#  'artist',
#  'mac',
#  'windows',
#  'actor',
#  'game',
#  'windows',
#  'developer',
#  'linux',
#  'software',
#  'web',
#  'windows',
#  'mac',
#  'writer',
#  'journalist',
#  'mac',
#  'teacher',
#  'writer',
#  'journalist',
#  'mac',
#  'illustrator',
#  'mac',
#  'developer',
#  'game',
#  'modder',
#  'windows',
#  'mac',
#  'musician',
#  'producer',
#  'developer',
#  'linux',
#  'software',
#  'writer',
#  'actor',
#  'mac',
#  'writer',
#  'engineer',
#  'mac',
#  'space',
#  'linux',
#  'mac',
#  'researcher',
#  'scientist',
#  'mac',
#  'photographer',
#  'software',
#  'web',
#  'writer',
#  'designer',
#  'developer',
#  'linux',
#  'mac',
#  'developer',
#  'linux',
#  'mac',
#  'professor',
#  'software',
#  'developer',
#  'editor',
#  'linux',
#  'software',
#  'editor',
#  'mac',
#  'web',
#  'fashion',
#  'puppet',
#  'designer',
#  'interface',
#  'mac',
#  'windows',
#  'developer',
#  'mac',
#  'researcher',
#  'windows',
#  'crafter',
#  'illustrator',
#  'mac',
#  'writer',
#  'audio',
#  'developer',
#  'mac',
#  'suit',
#  'web',
#  'chef',
#  'food',
#  'mac',
#  'developer',
#  'linux',
#  'reporter',
#  'web',
#  'game',
#  'mac',
#  'writer',
#  'developer',
#  'linux',
#  'mac',
#  'suit',
#  'web',
#  'beer',
#  'mac',
#  'artist',
#  'musician',
#  'windows',
#  'mac',
#  'musician',
#  'windows',
#  'designer',
#  'mac',
#  'writer',
#  'developer',
#  'mac',
#  'web',
#  'game',
#  'journalist',
#  'mac',
#  'writer',
#  'data',
#  'developer',
#  'mac',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'windows',
#  'designer',
#  'mac',
#  'developer',
#  'mac',
#  'suit',
#  'web',
#  'developer',
#  'mac',
#  'web',
#  'windows',
#  'editor',
#  'mac',
#  'designer',
#  'mac',
#  'web',
#  'windows',
#  'animator',
#  'mac',
#  'designer',
#  'mac',
#  'suit',
#  'game',
#  'mac',
#  'philosopher',
#  'designer',
#  'mac',
#  'usability',
#  'designer',
#  'mac',
#  'mac',
#  'musician',
#  'developer',
#  'hacker',
#  'mac',
#  'software',
#  'artist',
#  'windows',
#  'writer',
#  'blogger',
#  'comedian',
#  'mac',
#  'podcaster',
#  'web',
#  'developer',
#  'linux',
#  'software',
#  'mac',
#  'musician',
#  'artist',
#  'designer',
#  'mac',
#  'developer',
#  'mac',
#  'web',
#  'animator',
#  'mac',
#  'artist',
#  'mac',
#  'photographer',
#  'windows',
#  'windows',
#  'writer',
#  'developer',
#  'mac',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'student',
#  'windows',
#  'designer',
#  'developer',
#  'game',
#  'windows',
#  'designer',
#  'mac',
#  'mac',
#  'musician',
#  'mac',
#  'writer',
#  'developer',
#  'linux',
#  'mac',
#  'baker',
#  'developer',
#  'linux',
#  'software',
#  'developer',
#  'mac',
#  'web',
#  'writer',
#  'data',
#  'developer',
#  'mac',
#  'artist',
#  'mac',
#  'professor',
#  'scientist',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'artist',
#  'designer',
#  'game',
#  'hacker',
#  'linux',
#  'mac',
#  'data',
#  'developer',
#  'linux',
#  'developer',
#  'game',
#  'windows',
#  'developer',
#  'librarian',
#  'mac',
#  'web',
#  'bsd',
#  'developer',
#  'linux',
#  'security',
#  'software',
#  'developer',
#  'web',
#  'mac',
#  'musician',
#  'designer',
#  'mac',
#  'suit',
#  'developer',
#  'hacker',
#  'mac',
#  'software',
#  'chef',
#  'developer',
#  'food',
#  'linux',
#  'software',
#  'audio',
#  'film',
#  'linux',
#  'podcaster',
#  'writer',
#  'developer',
#  'editor',
#  'software',
#  'writer',
#  'editor',
#  'mac',
#  'writer',
#  'artist',
#  'cosplay',
#  'audio',
#  'mac',
#  'mac',
#  'writer',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'writer',
#  'developer',
#  'mac',
#  'researcher',
#  'software',
#  'developer',
#  'game',
#  'musician',
#  'windows',
#  'developer',
#  'game',
#  'mac',
#  'designer',
#  'game',
#  'mac',
#  'astrologer',
#  'mac',
#  'musician',
#  'crafter',
#  'mac',
#  'professor',
#  'linux',
#  'mac',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'writer',
#  'lawyer',
#  'mac',
#  'photographer',
#  'windows',
#  'writer',
#  'game',
#  'software',
#  'developer',
#  'beekeeper',
#  'illustrator',
#  'mac',
#  'data',
#  'developer',
#  'mac',
#  'artist',
#  'game',
#  'windows',
#  'illustrator',
#  'mac',
#  'developer',
#  'game',
#  'mac',
#  'web',
#  'windows',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'designer',
#  'fashion',
#  'mac',
#  'suit',
#  'developer',
#  'food',
#  'mac',
#  'software',
#  'developer',
#  'game',
#  'windows',
#  'writer',
#  'designer',
#  'mac',
#  'web',
#  'coffee',
#  'linux',
#  'engineer',
#  'mac',
#  'music',
#  'video',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'editor',
#  'mac',
#  'writer',
#  'developer',
#  'mac',
#  'web',
#  'editor',
#  'journalist',
#  'mac',
#  'electrical',
#  'engineer',
#  'weblogger',
#  'developer',
#  'mac',
#  'software',
#  'editor',
#  'game',
#  'journalist',
#  'windows',
#  'artist',
#  'illustrator',
#  'windows',
#  'illustrator',
#  'designer',
#  'developer',
#  'game',
#  'windows',
#  'developer',
#  'mac',
#  'software',
#  'mac',
#  'scientist',
#  'writer',
#  'developer',
#  'mac',
#  'software',
#  'teacher',
#  'writer',
#  'developer',
#  'mac',
#  'musician',
#  'web',
#  'windows',
#  'writer',
#  'developer',
#  'linux',
#  'researcher',
#  'software',
#  'windows',
#  'designer',
#  'editor',
#  'mac',
#  'developer',
#  'linux',
#  'mac',
#  'web',
#  'producer',
#  'web',
#  'developer',
#  'linux',
#  'mac',
#  'software',
#  'windows',
#  'writer',
#  'designer',
#  'mac',
#  'writer']

# %%
set_cats = set(all_cats)

# %%
len(all_cats)
# Out:
# 1258

# %%
set_cats
# Out:
# {'actor',
#  'animator',
#  'artist',
#  'astrologer',
#  'audio',
#  'baker',
#  'beekeeper',
#  'beer',
#  'biker',
#  'blogger',
#  'bsd',
#  'chef',
#  'coffee',
#  'comedian',
#  'community',
#  'cosplay',
#  'crafter',
#  'data',
#  'designer',
#  'developer',
#  'editor',
#  'electrical',
#  'engineer',
#  'entrepreneur',
#  'fashion',
#  'film',
#  'food',
#  'game',
#  'hacker',
#  'hardware',
#  'icon',
#  'illustrator',
#  'interface',
#  'journalist',
#  'lawyer',
#  'librarian',
#  'linux',
#  'mac',
#  'manager',
#  'modder',
#  'music',
#  'musician',
#  'philosopher',
#  'photographer',
#  'podcaster',
#  'poet',
#  'politics',
#  'producer',
#  'professor',
#  'puppet',
#  'reporter',
#  'researcher',
#  'scientist',
#  'security',
#  'service',
#  'sex',
#  'social',
#  'software',
#  'space',
#  'student',
#  'suit',
#  'sysadmin',
#  'systems',
#  'teacher',
#  'technologist',
#  'type',
#  'usability',
#  'video',
#  'web',
#  'weblogger',
#  'windows',
#  'writer'}

# %%
len(set_cats)
# Out:
# 72

# %%
ps_all_cats = pd.Series(all_cats)

# %%
ps_all_cats.value_counts()[:10].plot(kind='barh')

# %%
ps_all_cats.value_counts()[-25:].plot(kind='barh')

# %%
set_wares = set(ps_wares)

# %%
len(set_wares)
# Out:
# 2236

# %%
wares = glob.glob('%s/wares/hardware/*'%base_dir)
hardware = []
for el in wares:
    desc = yaml.load(open(el))
    desc['title'] = os.path.splitext(os.path.basename(el))[0]
    hardware.append(desc)

# %%
wares = glob.glob('%s/wares/software/*'%base_dir)
software = []
for el in wares:
    desc = yaml.load(open(el))
    desc['title'] = os.path.splitext(os.path.basename(el))[0]
    software.append(desc)

# %%
ps_wares
# Out:
# 0          macbook-pro
# 1       cinema-display
# 2     readynas-nv-plus
# 3         time-machine
# 4      airport-express
# 5       safari-adblock
# 6      google-calendar
# 7            istat-pro
# 8          google-apps
# 9         review-board
# 10           bloom-ios
# 11       google-reader
# 12              plan-9
# 13     audio-kontrol-1
# 14    powershot-sd1000
# ...
# 5051         final-cut-pro
# 5052           macbook-pro
# 5053           macbook-air
# 5054                   27q
# 5055    expansion-portable
# 5056              mac-os-x
# 5057        thinkpad-t410s
# 5058         thinkpad-t410
# 5059              iphone-5
# 5060         vmware-fusion
# 5061                chrome
# 5062            subversion
# 5063           macbook-pro
# 5064           google-docs
# 5065          tweetbot-ios
# Length: 5066, dtype: object

# %%
pf_used_ware = pd.DataFrame(ps_wares)

# %%
pf_used_ware
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5066 entries, 0 to 5065
# Data columns (total 1 columns):
# 0    5066  non-null values
# dtypes: object(1)

# %%
pf_used_ware.columns = ['title']

# %%
pf_used_ware
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5066 entries, 0 to 5065
# Data columns (total 1 columns):
# title    5066  non-null values
# dtypes: object(1)

# %%
software
# Out:
# [{'description': 'An audio plugin that emulates the 1176 limiter.',
#   'name': '1176 (plugin)',
#   'title': '1176',
#   'url': 'http://www.uaudio.com/store/compressors-limiters/1176-collection.html'},
#  {'description': 'A web service for uploading videos from mobile phones or webcams.',
#   'name': '12seconds',
#   'title': '12seconds',
#   'url': 'http://12seconds.tv/'},
#  {'description': 'An audio plugin that emulates the 140 reverberator.',
#   'name': '140 (plugin)',
#   'title': '140',
#   'url': 'http://www.uaudio.com/store/reverbs/emt-140.html'},
#  {'description': 'Password storage software for the iPhone.',
#   'name': '1Password (iOS)',
#   'title': '1password-ios',
#   'url': 'http://agilewebsolutions.com/onepassword/iphone'},
#  {'description': 'Password management and automatic form filler software for OS X.',
#   'name': '1Password',
#   'title': '1password',
#   'url': 'http://agilewebsolutions.com/products/1Password'},
#  {'description': 'A crossword puzzle game for the iPhone',
#   'name': '2across (iOS)',
#   'title': '2across-ios',
#   'url': 'http://www.wordblock.net/2across/Home.html'},
#  {'description': 'A to-do application for iOS.',
#   'name': '2do (iOS)',
#   'title': '2do-ios',
#   'url': 'http://www.2doapp.com/'},
#  {'description': '3D digital sculpting software.',
#   'name': '3D Coat',
#   'title': '3d-coat',
#   'url': 'http://3d-coat.com/'},
#  {'description': 'Open-source software for viewing and visualising medical imagery.',
#   'name': '3D Slicer',
#   'title': '3d-slicer',
#   'url': 'http://www.slicer.org/'},
#  {'description': '3D modelling and animation software.',
#   'name': '3ds Max',
#   'title': '3ds-max',
#   'url': 'http://usa.autodesk.com/3ds-max/'},
#  {'description': "A Mac client for Amazon's S3.",
#   'name': '3Hub',
#   'title': '3hub',
#   'url': 'http://3hubapp.com/'},
#  {'description': 'A photo sharing website.',
#   'name': '500px',
#   'title': '500px',
#   'url': 'http://500px.com/'},
#  {'description': 'A design system for streamlining web design and prototyping.',
#   'name': '960 Grid System',
#   'title': '960-grid-system',
#   'url': 'http://960.gs/'},
#  {'description': 'An audio plugin that emulates the A800 tape machine.',
#   'name': 'A800 (plugin)',
#   'title': 'a800',
#   'url': 'http://www.uaudio.com/store/special-processing/studer-a800-tape-recorder.html'},
#  {'description': 'A synthesiser/audio effects plugin.',
#   'name': 'ABSYNTH',
#   'title': 'absynth',
#   'url': 'http://www.native-instruments.com/#/en/products/producer/absynth-5/'},
#  {'description': 'A database management system.',
#   'name': 'Access',
#   'title': 'access',
#   'url': 'https://office.microsoft.com/en-us/access/'},
#  {'description': 'A generator helper application for XCode.',
#   'name': 'Accessorizer',
#   'title': 'accessorizer',
#   'url': 'http://www.kevincallahan.org/software/accessorizer.html'},
#  {'description': 'An image and photo manager.',
#   'name': 'ACDSee',
#   'title': 'acdsee',
#   'url': 'http://www.acdsee.com/en/products/acdsee-14/'},
#  {'description': 'A command-line tool for searching text.',
#   'name': 'ack',
#   'title': 'ack',
#   'url': 'http://betterthangrep.com/'},
#  {'description': 'A TextMate plugin for running Ack.',
#   'name': 'AckMate',
#   'title': 'ackmate',
#   'url': 'http://github.com/protocool/AckMate'},
#  {'description': 'A text editor and graphical shell for Plan 9.',
#   'name': 'acme',
#   'title': 'acme',
#   'url': 'http://en.wikipedia.org/wiki/Acme_(text_editor)'},
#  {'description': 'An image editor for the Mac.',
#   'name': 'Acorn',
#   'title': 'acorn',
#   'url': 'http://flyingmeat.com/acorn/'},
#  {'description': 'Software for creating and editing PDF documents.',
#   'name': 'Acrobat',
#   'title': 'acrobat',
#   'url': 'http://www.adobe.com/products/acrobat/'},
#  {'description': 'A process monitor application included with OS X.',
#   'name': 'Activity Monitor',
#   'title': 'activity-monitor',
#   'url': 'http://en.wikipedia.org/wiki/Activity_Monitor'},
#  {'description': 'Drum kit software.',
#   'name': 'Addictive Drums',
#   'title': 'addictive-drums',
#   'url': 'http://www.xlnaudio.com/productline/1'},
#  {'description': 'The contacts application included with Mac OS X.',
#   'name': 'Address Book',
#   'title': 'address-book',
#   'url': 'http://www.apple.com/macosx/features/addressbook/'},
#  {'description': 'The excellent multi-chat-protocol Mac application.',
#   'name': 'Adium',
#   'title': 'adium',
#   'url': 'http://adiumx.com/'},
#  {'description': 'A digital sketchbook app for iOS.',
#   'name': 'Adobe Ideas (iOS)',
#   'title': 'adobe-ideas-ios',
#   'url': 'http://itunes.apple.com/us/app/adobe-ideas-1-0-for-ipad/id364617858'},
#  {'description': 'A GUI for creating point-and-click games.',
#   'name': 'Adventure Game Studio',
#   'title': 'adventure-game-studio',
#   'url': 'http://www.bigbluecup.com/ac.shtml'},
#  {'description': 'A Mac timeline app for writers.',
#   'name': 'Aeon Timeline',
#   'title': 'aeon-timeline',
#   'url': 'https://aeontimeline.wordpress.com/'},
#  {'description': 'A pressure-based coffee/espresso maker.',
#   'name': 'Aeropress',
#   'title': 'aeropress',
#   'url': 'http://aerobie.com/products/aeropress.htm'},
#  {'description': 'A reverb plugin.',
#   'name': 'Aether',
#   'title': 'aether',
#   'url': 'http://www.2caudio.com/products/aether/'},
#  {'description': 'A collection of tools for analysing MRI data.',
#   'name': 'AFNI',
#   'title': 'afni',
#   'url': 'http://afni.nimh.nih.gov/afni'},
#  {'description': 'A collaborative service for people who work with video.',
#   'name': 'Aframe',
#   'title': 'aframe',
#   'url': 'http://aframe.com/'},
#  {'description': 'Motion graphics and video editing software.',
#   'name': 'After Effects',
#   'title': 'after-effects',
#   'url': 'http://www.adobe.com/products/aftereffects/'},
#  {'description': "An X window manager inspired by NeXTStep's interface.",
#   'name': 'AfterStep',
#   'title': 'afterstep',
#   'url': 'http://www.afterstep.org/'},
#  {'description': 'A colour scheme generation program for GNOME.',
#   'name': 'Agave',
#   'title': 'agave',
#   'url': 'http://home.gna.org/colorscheme/'},
#  {'description': 'An RTS game spanning 10,000 years of history.',
#   'name': 'Age of Empires',
#   'title': 'age-of-empires',
#   'url': 'http://www.microsoft.com/games/empires/'},
#  {'description': 'A calendar app.',
#   'name': 'Agenda (iOS)',
#   'title': 'agenda-ios',
#   'url': 'http://savvyapps.com/agenda/'},
#  {'description': 'An instant messaging service.',
#   'name': 'AIM',
#   'title': 'aim',
#   'url': 'http://www.aim.com/'},
#  {'description': 'Software to convert ActionScript applications to Android apps.',
#   'name': 'AIR for Android',
#   'title': 'air-android',
#   'url': 'http://labs.adobe.com/technologies/air2/android/'},
#  {'description': 'An iOS app for using your iDevice as another screen.',
#   'name': 'Air Display (iOS)',
#   'title': 'air-display-ios',
#   'url': 'http://itunes.apple.com/us/app/air-display/id368158927'},
#  {'description': 'A file sharing app for the iPhone.',
#   'name': 'Air Sharing (iOS)',
#   'title': 'air-sharing-ios',
#   'url': 'http://avatron.com/apps/air-sharing/'},
#  {'description': 'Software to stream video to your iDevice.',
#   'name': 'Air Video',
#   'title': 'air-video',
#   'url': 'http://www.inmethod.com/air-video/'},
#  {'description': 'Send audio wherever you want it.',
#   'name': 'Airfoil',
#   'title': 'airfoil',
#   'url': 'http://www.rogueamoeba.com/airfoil/'},
#  {'description': 'A set of audio samples.',
#   'name': 'Albion',
#   'title': 'albion',
#   'url': 'http://www.spitfireaudio.com/albion.html'},
#  {'description': 'A launcher app for the Mac.',
#   'name': 'Alfred',
#   'title': 'alfred',
#   'url': 'http://www.alfredapp.com/'},
#  {'description': '2D and 3D design software.',
#   'name': 'Alias',
#   'title': 'alias',
#   'url': 'http://usa.autodesk.com/alias/'},
#  {'description': "A procrastinator's menubar clock for Mac OS X that purposely runs faster or slower.",
#   'name': 'Alltock',
#   'title': 'alltock',
#   'url': 'http://www.componentx.com/Alltock/'},
#  {'description': 'A terminal email client.',
#   'name': 'Alpine',
#   'title': 'alpine',
#   'url': 'http://www.washington.edu/alpine/'},
#  {'description': 'PCB/schematic capture design software.',
#   'name': 'Altium Designer',
#   'title': 'altium-designer',
#   'url': 'http://www.altium.com/products/altium-designer/en/altium-designer_home.cfm'},
#  {'description': 'The Amazon app for iOS.',
#   'name': 'Amazon Mobile (iOS)',
#   'title': 'amazon-mobile-ios',
#   'url': 'http://itunes.apple.com/us/app/amazon-mobile/id297606951'},
#  {'description': 'A queueing protocol.',
#   'name': 'AMQP',
#   'title': 'amqp',
#   'url': 'http://www.amqp.org/'},
#  {'description': 'A Google Analytics client app for the iPhone.',
#   'name': 'Analytics (iOS)',
#   'title': 'analytics-ios',
#   'url': 'http://analyticsapp.com/'},
#  {'description': 'A mobile phone platform.',
#   'name': 'Android',
#   'title': 'android',
#   'url': 'http://code.google.com/android/'},
#  {'description': 'A roguelike dungeon explorer game.',
#   'name': 'Angband',
#   'title': 'angband',
#   'url': 'http://rephial.org/'},
#  {'description': 'A popular game involving slingshots, birds and pigs.',
#   'name': 'Angry Birds (iOS)',
#   'title': 'angry-birds-ios',
#   'url': 'http://itunes.apple.com/us/app/angry-birds/id343200656'},
#  {'description': 'An old animation tool for Windows.',
#   'name': 'Animation Shop',
#   'title': 'animation-shop',
#   'url': 'http://www.softpedia.com/get/Multimedia/Graphic/Graphic-Editors/Animation-Shop.shtml'},
#  {'description': 'An animation package for R.',
#   'name': 'animation',
#   'title': 'animation',
#   'url': 'http://yihui.name/animation/'},
#  {'description': 'A synthesizer for iOS.',
#   'name': 'Animoog (iOS)',
#   'title': 'animoog-ios',
#   'url': 'http://moogmusic.com/products/apps/animoog'},
#  {'description': 'A flash-card based learning tool.',
#   'name': 'Anki',
#   'title': 'anki',
#   'url': 'http://www.ankisrs.net/'},
#  {'description': 'A build tool for developers.',
#   'name': 'Ant',
#   'title': 'ant',
#   'url': 'http://ant.apache.org/'},
#  {'description': 'Productivity software that locks you out of social networking sites.',
#   'name': 'Anti-Social',
#   'title': 'anti-social',
#   'url': 'http://anti-social.cc/'},
#  {'description': 'Performance testing software for .NET programs.',
#   'name': 'ANTS Performance Profiler',
#   'title': 'ants-performance-profiler',
#   'url': 'http://www.red-gate.com/products/dotnet-development/ants-performance-profiler/'},
#  {'description': 'Web server software.',
#   'name': 'Apache',
#   'title': 'apache',
#   'url': 'http://www.apache.org/'},
#  {'description': 'An OS X framework and system daemon for loading haxies.',
#   'name': 'Application Enhancer',
#   'title': 'ape',
#   'url': 'http://unsanity.com/haxies/ape'},
#  {'description': 'Photo editing and management software for OS X.',
#   'name': 'Aperture',
#   'title': 'aperture',
#   'url': 'http://www.apple.com/aperture/'},
#  {'description': 'The Astronomical Plotting Library in Python.',
#   'name': 'APLpy',
#   'title': 'aplpy',
#   'url': 'http://aplpy.github.com/'},
#  {'description': 'An SDK/launcher for the App Engine, for the Mac.',
#   'name': 'Google App Engine Launcher',
#   'title': 'app-engine-launcher',
#   'url': 'http://code.google.com/appengine/downloads.html'},
#  {'description': 'Hosting for web applications.',
#   'name': 'Google App Engine',
#   'title': 'app-engine',
#   'url': 'http://code.google.com/appengine/'},
#  {'description': 'A social network.',
#   'name': 'App.net',
#   'title': 'app.net',
#   'url': 'https://join.app.net/'},
#  {'description': 'A tool for uninstalling applications.',
#   'name': 'AppCleaner',
#   'title': 'appcleaner',
#   'url': 'http://www.freemacsoft.net/AppCleaner/'},
#  {'description': 'A Mac tool for designing buttons and other application controls.',
#   'name': 'AppControls',
#   'title': 'appcontrols',
#   'url': 'http://bluecrowbar.com/appcontrols/'},
#  {'description': 'Vulnerability scanner software for databases.',
#   'name': 'AppDetectivePro',
#   'title': 'appdetectivepro',
#   'url': 'http://www.appsecinc.com/products/appdetective/'},
#  {'description': 'The version of BASIC that came with Apple II computers.',
#   'name': 'Applesoft BASIC',
#   'title': 'applesoft-basic',
#   'url': 'http://en.wikipedia.org/wiki/Applesoft_BASIC'},
#  {'description': 'An old office suite for the Mac.',
#   'name': 'AppleWorks',
#   'title': 'appleworks',
#   'url': 'http://en.wikipedia.org/wiki/AppleWorks'},
#  {'description': 'A hotkey tool for the Mac.',
#   'name': 'Apptivate',
#   'title': 'apptivate',
#   'url': 'http://www.apptivateapp.com/'},
#  {'description': 'Software for uninstalling applications on the Mac.',
#   'name': 'AppZapper',
#   'title': 'appzapper',
#   'url': 'http://appzapper.com/'},
#  {'description': 'Package management software for Linux.',
#   'name': 'apt',
#   'title': 'apt',
#   'url': 'http://en.wikipedia.org/wiki/Advanced_Packaging_Tool'},
#  {'description': 'A web service for adding social-y media to weblogs.',
#   'name': 'Apture',
#   'title': 'apture',
#   'url': 'http://www.apture.com/'},
#  {'description': 'An OS X native version of Emacs.',
#   'name': 'Aquamacs',
#   'title': 'aquamacs',
#   'url': 'http://aquamacs.org/'},
#  {'description': 'A very pretty underwater adventure game.',
#   'name': 'Aquaria',
#   'title': 'aquaria',
#   'url': 'http://www.bit-blot.com/aquaria/'},
#  {'description': 'A Linux distro.',
#   'name': 'Arch Linux',
#   'title': 'arch-linux',
#   'url': 'http://www.archlinux.org/'},
#  {'description': 'Live video/audio instrument software and media server.',
#   'name': 'Arena',
#   'title': 'arena',
#   'url': 'http://resolume.com/software/'},
#  {'description': 'A GTK2 client for MPD.',
#   'name': 'Ario',
#   'title': 'ario',
#   'url': 'http://ario-player.sourceforge.net/'},
#  {'description': 'An iPhone app to give you information on your current surroundings.',
#   'name': 'AroundMe (iOS)',
#   'title': 'aroundme-ios',
#   'url': 'http://www.tweakersoft.com/mobile/aroundme.html'},
#  {'description': 'S3-based backup for the Mac.',
#   'name': 'Arq',
#   'title': 'arq',
#   'url': 'http://www.haystacksoftware.com/arq/'},
#  {'description': 'A contemporary art guide.',
#   'name': 'Artlog',
#   'title': 'artlog',
#   'url': 'http://artlog.com/'},
#  {'description': 'A drawing and painting tool.',
#   'name': 'ArtRage Studio',
#   'title': 'artrage-studio',
#   'url': 'http://www.artrage.com/artrage-studio.html'},
#  {'description': 'A TextMate bundle for working with AsciiDoc.',
#   'name': 'AsciiDoc TextMate Bundle',
#   'title': 'asciidoc-textmate',
#   'url': 'https://github.com/zuckschwerdt/asciidoc.tmbundle'},
#  {'description': "A text file format and software that's easily translated to other formats.",
#   'name': 'AsciiDoc',
#   'title': 'asciidoc',
#   'url': 'http://www.methods.co.nz/asciidoc/'},
#  {'description': 'A menu-based application switcher for OS X.',
#   'name': 'ASM',
#   'title': 'asm',
#   'url': 'http://vercruesse.de/software/asm'},
#  {'description': 'A server-side scripting language.',
#   'name': 'ASP',
#   'title': 'asp',
#   'url': 'https://en.wikipedia.org/wiki/Active_Server_Pages'},
#  {'description': 'A spell checking system.',
#   'name': 'Aspell',
#   'title': 'aspell',
#   'url': 'http://aspell.net/'},
#  {'description': 'A Python file-based web framework.',
#   'name': 'Aspen',
#   'title': 'aspen',
#   'url': 'http://aspen.io/'},
#  {'description': 'A task manager for Android phones.',
#   'name': 'Astrid (Android)',
#   'title': 'astrid-android',
#   'url': 'http://weloveastrid.com/'},
#  {'description': 'A qualitative analysis tool.',
#   'name': 'ATLAS.ti',
#   'title': 'atlas.ti',
#   'url': 'http://www.atlasti.com/'},
#  {'description': 'An audio plugin that emulates the ATR-102 tape machine.',
#   'name': 'ATR-102 (plugin)',
#   'title': 'atr-102',
#   'url': 'http://www.uaudio.com/store/special-processing/ampex-atr-102.html'},
#  {'description': 'Percussion synthesizer software.',
#   'name': 'Attack',
#   'title': 'attack',
#   'url': 'http://www.waldorfmusic.de/en/products/attack'},
#  {'description': 'Software for adding extra features to the original Apple TV.',
#   'name': 'aTV Flash',
#   'title': 'atv-flash',
#   'url': 'http://firecore.com/atvflash'},
#  {'description': 'An Emacs package for TeX support.',
#   'name': 'AUCTEX',
#   'title': 'auctex',
#   'url': 'http://www.gnu.org/software/auctex/'},
#  {'description': 'An open-source, cross-platform audio editor.',
#   'name': 'Audacity',
#   'title': 'audacity',
#   'url': 'http://audacity.sourceforge.net/'},
#  {'description': 'An app for the audio book service.',
#   'name': 'Audible (iOS)',
#   'title': 'audible-ios',
#   'url': 'http://itunes.apple.com/us/app/audible/id379693831'},
#  {'description': 'Mac software for recording audio from any source.',
#   'name': 'Audio Hijack Pro',
#   'title': 'audio-hijack-pro',
#   'url': 'http://www.rogueamoeba.com/audiohijackpro/'},
#  {'description': 'A Mac application for emulating sound hardware from old computers/consoles.',
#   'name': 'Audio Overload',
#   'title': 'audio-overload',
#   'url': 'http://www.bannister.org/software/ao.htm'},
#  {'description': 'Mac software for recording audio.',
#   'name': 'Audio Recorder',
#   'title': 'audio-recorder',
#   'url': 'http://www.macmusic.org/software/view.php/lang/en/id/493/Audio-Recorder'},
#  {'description': 'An audio editing software suite.',
#   'name': 'Audition',
#   'title': 'audition',
#   'url': 'http://www.adobe.com/products/audition.html'},
#  {'description': 'An audio processor that alters voice pitches.',
#   'name': 'Auto-Tune',
#   'title': 'auto-tune',
#   'url': 'https://en.wikipedia.org/wiki/Auto-Tune'},
#  {'description': 'A hotkey and keystroke program for Windows.',
#   'name': 'AutoHotKey',
#   'title': 'autohotkey',
#   'url': 'http://www.autohotkey.com/'},
#  {'description': 'Software included with Mac OS X for creating script-based workflows.',
#   'name': 'Automator',
#   'title': 'automator',
#   'url': 'http://en.wikipedia.org/wiki/Automator_(software)'},
#  {'description': 'Panorama stitching software.',
#   'name': 'Autopano Pro',
#   'title': 'autopano-pro',
#   'url': 'http://www.kolor.com/panorama-software-autopano-pro.html'},
#  {'description': 'Free anti-virus software for Windows.',
#   'name': 'Avast Free',
#   'title': 'avast-free',
#   'url': 'http://www.avast.com/free-antivirus-download/'},
#  {'description': 'Live video/audio instrument software.',
#   'name': 'Avenue',
#   'title': 'avenue',
#   'url': 'http://resolume.com/software/'},
#  {'description': 'An RPG series for the Mac and Windows.',
#   'name': 'Avernum',
#   'title': 'avernum',
#   'url': 'http://www.avernum.com/'},
#  {'description': 'A video editor and processor tool for Windows.',
#   'name': 'AviSynth',
#   'title': 'avisynth',
#   'url': 'http://avisynth.org/mediawiki/Main_Page'},
#  {'description': 'A gcc-based toolset for AVR microcontrollers.',
#   'name': 'avr-gcc',
#   'title': 'avr-gcc',
#   'url': 'https://github.com/epi/avr-gcc'},
#  {'description': 'An IDE for embedded software.',
#   'name': 'AVR Studio',
#   'title': 'avr-studio',
#   'url': 'http://www.atmel.com/microsite/avr_studio_5/default.aspx'},
#  {'description': 'A utility for changing the ROM and EEPROM of AVR microcontrollers.',
#   'name': 'avrdude',
#   'title': 'avrdude',
#   'url': 'https://github.com/piglop/avrdude'},
#  {'description': 'A window manager for X.',
#   'name': 'awesome',
#   'title': 'awesome',
#   'url': 'http://awesome.naquadah.org/'},
#  {'description': 'A 2D cartoony side-scrolling game.',
#   'name': 'Awesomenauts',
#   'title': 'awesomenauts',
#   'url': 'http://www.awesomenauts.com/'},
#  {'description': 'Data formatting language/software.',
#   'name': 'awk',
#   'title': 'awk',
#   'url': 'https://en.wikipedia.org/wiki/AWK'},
#  {'description': 'A part of Org-mode that allows code execution.',
#   'name': 'Babel',
#   'title': 'babel',
#   'url': 'http://orgmode.org/worg/org-contrib/babel/'},
#  {'description': 'A baby feeding and tracking app.',
#   'name': 'Baby Log (iOS)',
#   'title': 'baby-log-ios',
#   'url': 'http://itunes.apple.com/us/app/baby-log-activities-growth/id401112090'},
#  {'description': 'Online backup.',
#   'name': 'Backblaze',
#   'title': 'backblaze',
#   'url': 'http://backblaze.com/internet-backup.html'},
#  {'description': 'Mac software for filling the screen with an image or solid colour.',
#   'name': 'Backdrop',
#   'title': 'backdrop',
#   'url': 'http://johnhaney.com/backdrop/'},
#  {'description': 'Saves CSS changes you make in Firebug back to the server.',
#   'name': 'Backfire',
#   'title': 'backfire',
#   'url': 'http://code.google.com/p/backfire/'},
#  {'description': 'An intra-company web service for sharing calendars, documents and files.',
#   'name': 'Backpack',
#   'title': 'backpack',
#   'url': 'http://backpackit.com/'},
#  {'description': 'Continuous integration software.',
#   'name': 'Bamboo',
#   'title': 'bamboo.2',
#   'url': 'http://www.atlassian.com/software/bamboo/overview'},
#  {'description': 'A new banking service.',
#   'name': 'BankSimple',
#   'title': 'banksimple',
#   'url': 'https://www.banksimple.com/'},
#  {'description': 'A music player for GNOME.',
#   'name': 'Banshee',
#   'title': 'banshee',
#   'url': 'http://banshee.fm/'},
#  {'description': 'A Mac tool for organising menu bar apps.',
#   'name': 'Bartender',
#   'title': 'bartender',
#   'url': 'http://www.macbartender.com/'},
#  {'description': 'Web-based project management.',
#   'name': 'Basecamp',
#   'title': 'basecamp',
#   'url': 'http://basecamphq.com/'},
#  {'description': 'A popular terminal shell.',
#   'name': 'bash',
#   'title': 'bash',
#   'url': 'http://www.gnu.org/software/bash/'},
#  {'description': 'A pretty RPG.',
#   'name': 'Bastion',
#   'title': 'bastion',
#   'url': 'http://supergiantgames.com/?page_id=242'},
#  {'description': 'A drum and percussion sampler.',
#   'name': 'Battery 3',
#   'title': 'battery-3',
#   'url': 'http://www.native-instruments.com/index.php?id=battery3'},
#  {'description': 'Drum and percussion software.',
#   'name': 'Battery',
#   'title': 'battery',
#   'url': 'http://www.native-instruments.com/en/products/producer/battery-3/'},
#  {'description': 'An RPG/action hero game.',
#   'name': 'Battleheart (iOS)',
#   'title': 'battleheart-ios',
#   'url': 'http://itunes.apple.com/us/app/battleheart/id394057299'},
#  {'description': 'Breaking news app.',
#   'name': 'BBC News (iOS)',
#   'title': 'bbc-news-ios',
#   'url': 'http://itunes.apple.com/us/app/bbc-news/id364147881'},
#  {'description': 'A rather popular text editor for the Mac.',
#   'name': 'BBEdit',
#   'title': 'bbedit',
#   'url': 'http://barebones.com/products/bbedit/'},
#  {'description': 'A LaTeX class for creating presentations.',
#   'name': 'Beamer',
#   'title': 'beamer',
#   'url': 'https://bitbucket.org/rivanvx/beamer/wiki/Home'},
#  {'description': 'A word processor for the Mac.',
#   'name': 'Bean',
#   'title': 'bean',
#   'url': 'http://www.bean-osx.com/Bean.html'},
#  {'description': 'Beer brewing calculation software.',
#   'name': 'BeerAlchemy',
#   'title': 'beeralchemy',
#   'url': 'http://www.kentplacesoftware.com/products/BeerAlchemy.shtml'},
#  {'description': 'Beer brewing calculation software.',
#   'name': 'BeerTools Pro',
#   'title': 'beertools-pro',
#   'url': 'http://www.beertools.com/'},
#  {'description': 'Window management software for the Mac.',
#   'name': 'BetterSnapTool',
#   'title': 'bettersnaptool',
#   'url': 'http://itunes.apple.com/us/app/bettersnaptool/id417375580'},
#  {'description': 'Mac software to add custom multi-touch gestures.',
#   'name': 'BetterTouchTool',
#   'title': 'bettertouchtool',
#   'url': 'http://www.boastr.de/'},
#  {'description': 'File and folder comparison and syncing software for Windows.',
#   'name': 'Beyond Compare',
#   'title': 'beyond-compare',
#   'url': 'http://www.scootersoftware.com/moreinfo.php'},
#  {'description': 'Software for recording and watching TV.',
#   'name': 'Beyond TV',
#   'title': 'beyond-tv',
#   'url': 'http://snapstream.com/products/beyondtv/'},
#  {'description': "'Drum studio in a box' software.",
#   'name': 'BFD',
#   'title': 'bfd',
#   'url': 'http://fxpansion.com/index.php?page=53'},
#  {'description': 'An audio generator tool, often used for games.',
#   'name': 'Bfxr',
#   'title': 'bfxr',
#   'url': 'http://www.bfxr.net/'},
#  {'description': 'A Bollywood-themed Internet radio station.',
#   'name': 'Bhangra',
#   'title': 'bhangra',
#   'url': 'http://bhangra.fm/'},
#  {'description': 'A bibliography manager for Mac OS X.',
#   'name': 'BibDesk',
#   'title': 'bibdesk',
#   'url': 'http://bibdesk.sourceforge.net/'},
#  {'description': 'Software for supporting bibliographies in LaTeX.',
#   'name': 'biblatex',
#   'title': 'biblatex',
#   'url': 'http://www.ctan.org/tex-archive/help/Catalogue/entries/biblatex.html'},
#  {'description': 'LaTeX-related software for processing references.',
#   'name': 'BibTeX',
#   'title': 'bibtex',
#   'url': 'http://www.bibtex.org/'},
#  {'description': 'Time billing software for the Mac.',
#   'name': 'Billings',
#   'title': 'billings',
#   'url': 'http://www.billingsapp.com/'},
#  {'description': 'An online newsgroup search engine.',
#   'name': 'binsearch',
#   'title': 'binsearch',
#   'url': 'http://binsearch.info/'},
#  {'description': 'IRC proxy software.',
#   'name': 'Bip',
#   'title': 'bip',
#   'url': 'http://bip.milkypond.org/'},
#  {'description': 'An app that tracks changes in your Twitter account.',
#   'name': 'Birdbrain (iOS)',
#   'title': 'birdbrain-ios',
#   'url': 'http://birdbrainapp.com/'},
#  {'description': 'A Twitter notepad app for iOS.',
#   'name': 'Birdhouse (iOS)',
#   'title': 'birdhouse-ios',
#   'url': 'http://birdhouseapp.com/'},
#  {'description': 'A spaceship game.',
#   'name': 'Bit Pilot (iOS)',
#   'title': 'bit-pilot-ios',
#   'url': 'http://bitpilotgame.com/'},
#  {'description': 'A source code hosting service.',
#   'name': 'Bitbucket',
#   'title': 'bitbucket',
#   'url': 'https://bitbucket.org/'},
#  {'description': 'A cloud storage service.',
#   'name': 'Bitcasa',
#   'title': 'bitcasa',
#   'url': 'http://www.bitcasa.com/'},
#  {'description': 'A command-line IRC client.',
#   'name': 'BitchX',
#   'title': 'bitchx',
#   'url': 'http://www.bitchx.com/'},
#  {'description': 'A font editor.',
#   'name': 'BitFonter',
#   'title': 'bitfonter',
#   'url': 'http://www.fontlab.com/font-editor/bitfonter/'},
#  {'description': 'An IM to IRC proxy server.',
#   'name': 'Bitlbee',
#   'title': 'bitlbee',
#   'url': 'http://www.bitlbee.org/'},
#  {'description': 'A link shortening and tracking service.',
#   'name': 'bitly',
#   'title': 'bitly',
#   'url': 'http://bitly.com/'},
#  {'description': 'Distributed file sharing.',
#   'name': 'Bittorrent',
#   'title': 'bittorrent',
#   'url': 'http://www.bittorrent.com/'},
#  {'description': 'A blend of coffee.',
#   'name': 'Black Cat Classic',
#   'title': 'black-cat-classic',
#   'url': 'http://www.intelligentsiacoffee.com/store/product/id/137'},
#  {'description': 'A lightweight window manager for X.',
#   'name': 'Blackbox',
#   'title': 'blackbox',
#   'url': 'http://blackboxwm.sourceforge.net/'},
#  {'description': 'An MP3 encoder.',
#   'name': 'BlanceEnc',
#   'title': 'bladeenc',
#   'url': 'http://freecode.com/projects/bladeenc'},
#  {'description': 'A free, open-source 3D renderer.',
#   'name': 'Blender',
#   'title': 'blender',
#   'url': 'http://www.blender.org/'},
#  {'description': 'An invoicing service.',
#   'name': 'Blinksale',
#   'title': 'blinksale',
#   'url': 'http://blinksale.com/'},
#  {'description': 'A media sharing and distribution web service.',
#   'name': 'Blip.tv',
#   'title': 'blip.tv',
#   'url': 'http://blip.tv/'},
#  {'description': 'An API for uploading and controlling large objects to Google App Engine.',
#   'name': 'Blobstore',
#   'title': 'blobstore',
#   'url': 'https://developers.google.com/appengine/docs/java/blobstore/'},
#  {'description': 'A weblog publishing system.',
#   'name': 'Blogger',
#   'title': 'blogger',
#   'url': 'http://blogger.com/'},
#  {'description': 'A web-based feed reader.',
#   'name': 'Bloglines',
#   'title': 'bloglines',
#   'url': 'http://bloglines.com/'},
#  {'description': 'A blog-posting app for iOS.',
#   'name': 'Blogsy (iOS)',
#   'title': 'blogsy-ios',
#   'url': 'http://blogsyapp.com/'},
#  {'description': 'An ambient musician machine/artwork iPhone application.',
#   'name': 'Bloom (iOS)',
#   'title': 'bloom-ios',
#   'url': 'http://generativemusic.com/'},
#  {'description': 'A fresh Twitter client for the Mac.',
#   'name': 'Bluebird',
#   'title': 'bluebird',
#   'url': 'http://www.bluebirdapp.com/'},
#  {'description': 'A reference manager for the Mac.',
#   'name': 'Bookends',
#   'title': 'bookends',
#   'url': 'http://www.sonnysoftware.com/bookends/bookends.html'},
#  {'description': 'Software to allow Macs to run Windows natively.',
#   'name': 'Boot Camp',
#   'title': 'boot-camp',
#   'url': 'http://www.apple.com/macosx/what-is-macosx/compatibility.html'},
#  {'description': 'A front-end web framework.',
#   'name': 'Bootstrap',
#   'title': 'bootstrap',
#   'url': 'http://twitter.github.com/bootstrap/'},
#  {'description': 'A Mac app for controlling iTunes.',
#   'name': 'Bowtie',
#   'title': 'bowtie',
#   'url': 'http://bowtieapp.com/'},
#  {'description': 'A physics engine for games.',
#   'name': 'Box2D',
#   'title': 'box2d',
#   'url': 'http://box2d.org/'},
#  {'description': 'An application for watching and organising media.',
#   'name': 'Boxee',
#   'title': 'boxee',
#   'url': 'http://www.boxee.tv/'},
#  {'description': 'A clever puzzle/platformer game.',
#   'name': 'Braid',
#   'title': 'braid',
#   'url': 'http://braid-game.com'},
#  {'description': 'A minimalist programming language.',
#   'name': 'brainfuck',
#   'title': 'brainfuck',
#   'url': 'http://en.wikipedia.org/wiki/Brainfuck'},
#  {'description': 'An IDE for programming brick-based robots.',
#   'name': 'BricxCC',
#   'title': 'bricxcc',
#   'url': 'http://bricxcc.sourceforge.net/'},
#  {'description': 'A shared media manager for Adobe CS products.',
#   'name': 'Bridge',
#   'title': 'bridge',
#   'url': 'http://www.adobe.com/products/creativesuite/bridge/'},
#  {'description': "An old DOS programmer's text editor.",
#   'name': 'B.R.I.E.F',
#   'title': 'brief',
#   'url': 'http://en.wikipedia.org/wiki/Brief_(text_editor)'},
#  {'description': 'A third-party Twitter and Facebook web service.',
#   'name': 'Brizzly',
#   'title': 'brizzly',
#   'url': 'https://en.wikipedia.org/wiki/Brizzly'},
#  {'description': 'A service for testing a site live across a multitude of browsers.',
#   'name': 'BrowserStack',
#   'title': 'browserstack',
#   'url': 'http://www.browserstack.com/'},
#  {'description': 'An ambient noise generator app, based on real-world plastic devices.',
#   'name': 'Buddha Machine (iOS)',
#   'title': 'buddha-machine-ios',
#   'url': 'http://itunes.apple.com/gb/app/buddha-machine-ipad-edition/id394619578'},
#  {'description': 'An open-source bug tracking system.',
#   'name': 'Bugzilla',
#   'title': 'bugzilla',
#   'url': 'http://www.bugzilla.org/'},
#  {'description': 'A 3D desktop environment.',
#   'name': 'BumpTop',
#   'title': 'bumptop',
#   'url': 'http://en.wikipedia.org/wiki/BumpTop'},
#  {'description': 'A Chicago bus and train tracker for iOS.',
#   'name': 'Buster (iOS)',
#   'title': 'buster-ios',
#   'url': 'http://itunes.apple.com/us/app/buster-the-chicago-bus-train/id312109511'},
#  {'description': 'Advanced calendar software for OS X.',
#   'name': 'BusyCal',
#   'title': 'busycal',
#   'url': 'http://www.busymac.com/busycal/'},
#  {'description': 'An application to sync iCal and Google Calendar, for the Mac.',
#   'name': 'BusySync',
#   'title': 'busysync',
#   'url': 'http://www.busymac.com/busysync/'},
#  {'description': 'A Google Reader app for the iPhone',
#   'name': 'Byline (iOS)',
#   'title': 'byline-ios',
#   'url': 'http://www.phantomfish.com/byline.html'},
#  {'description': 'A wrapper tool for screen or tmux.',
#   'name': 'Byobu',
#   'title': 'byobu',
#   'url': 'https://launchpad.net/byobu'},
#  {'description': 'A Markdown text editor app.',
#   'name': 'Byword (iOS)',
#   'title': 'byword-ios',
#   'url': 'http://itunes.apple.com/us/app/byword/id482063361'},
#  {'description': 'A full-screen writing tool for the Mac.',
#   'name': 'Byword',
#   'title': 'byword',
#   'url': 'http://bywordapp.com/'},
#  {'description': 'A DNS library.',
#   'name': 'c-ares',
#   'title': 'c-ares',
#   'url': 'http://c-ares.haxx.se/'},
#  {'description': 'A compiled programming language.',
#   'name': 'C++',
#   'title': 'c-plusplus',
#   'url': 'http://en.wikipedia.org/wiki/C%2B%2B'},
#  {'description': 'A compiled programming language.',
#   'name': 'C#',
#   'title': 'c-sharp',
#   'url': 'http://msdn.microsoft.com/en-us/vcsharp/default.aspx'},
#  {'description': 'A compiled programming language.',
#   'name': 'C',
#   'title': 'c',
#   'url': 'http://en.wikipedia.org/wiki/C_(programming_language)'},
#  {'description': 'A packaging system for Haskell.',
#   'name': 'Cabal',
#   'title': 'cabal',
#   'url': 'http://www.haskell.org/cabal/'},
#  {'description': 'A Mac menubar application to keep your computer awake.',
#   'name': 'Caffeine',
#   'title': 'caffeine',
#   'url': 'http://lightheadsw.com/caffeine/'},
#  {'description': 'A music sequencer program.',
#   'name': 'Cakewalk',
#   'title': 'cakewalk',
#   'url': 'https://en.wikipedia.org/wiki/Cakewalk_(sequencer)'},
#  {'description': 'A calculator app for the iPhone.',
#   'name': 'Calcbot (iOS)',
#   'title': 'calcbot-ios',
#   'url': 'http://tapbots.com/software/calcbot/'},
#  {'description': 'The calendar app included with iOS.',
#   'name': 'Calendar (iOS)',
#   'title': 'calendar-ios',
#   'url': 'http://www.apple.com/iphone/built-in-apps/calendar.html'},
#  {'description': 'An ebook library management tool.',
#   'name': 'Calibre',
#   'title': 'calibre',
#   'url': 'http://calibre-ebook.com/'},
#  {'description': 'A WWII first person shooter.',
#   'name': 'Call of Duty: World at War',
#   'title': 'call-of-duty-world-at-war',
#   'url': 'https://en.wikipedia.org/wiki/Call_of_Duty:_World_at_War'},
#  {'description': 'Software for recording Skype conversations.',
#   'name': 'Call Recorder',
#   'title': 'call-recorder',
#   'url': 'http://www.ecamm.com/mac/callrecorder/'},
#  {'description': 'An alternate calendar app.',
#   'name': 'Calvetica (iOS)',
#   'title': 'calvetica-ios',
#   'url': 'http://mysterioustrousers.com/calvetica'},
#  {'description': 'A pro photo app for the iPhone.',
#   'name': 'Camera+ (iOS)',
#   'title': 'camera-plus-ios',
#   'url': 'http://campl.us/'},
#  {'description': 'An iPhone app for taking photos with various filters.',
#   'name': 'CameraBag (iOS)',
#   'title': 'camerabag-ios',
#   'url': 'http://www.nevercenter.com/camerabag/'},
#  {'description': 'An alternative Mac browser based on Gecko.',
#   'name': 'Camino',
#   'title': 'camino',
#   'url': 'http://caminobrowser.org/'},
#  {'description': 'Mac software for hiding the icons on the desktop.',
#   'name': 'Camouflage',
#   'title': 'camouflage',
#   'url': 'http://www.briksoftware.com/products/camouflage/'},
#  {'description': 'Web-based chat.',
#   'name': 'campfire',
#   'title': 'campfire',
#   'url': 'http://campfirenow.com/'},
#  {'description': 'Screencasting software.',
#   'name': 'Camtasia',
#   'title': 'camtasia',
#   'url': 'http://techsmith.com/camtasia.asp'},
#  {'description': 'A side-scrolling parkour game for the iPhone.',
#   'name': 'Canabalt (iOS)',
#   'title': 'canabalt-ios',
#   'url': 'http://www.canabalt.com/'},
#  {'description': 'Software for changing the default icons in OS X.',
#   'name': 'CandyBar',
#   'title': 'candybar',
#   'url': 'http://www.panic.com/candybar/'},
#  {'description': 'Web application deployment software.',
#   'name': 'Capistrano',
#   'title': 'capistrano',
#   'url': 'http://www.capify.org/index.php/Capistrano'},
#  {'description': 'An iPhone app for quickly capturing notes/ideas.',
#   'name': 'Captio (iOS)',
#   'title': 'captio-ios',
#   'url': 'http://www.boonbits.com/captio/'},
#  {'description': 'A screen capture and learning tool.',
#   'name': 'Captivate',
#   'title': 'captivate',
#   'url': 'http://www.adobe.com/products/captivate.html'},
#  {'description': 'A Mac-friendly version of GNU Emacs.',
#   'name': 'Emacs (Carbon)',
#   'title': 'carbon-emacs',
#   'url': 'http://homepage.mac.com/zenitani/emacs-e.html'},
#  {'description': 'An online backup service.',
#   'name': 'Carbonite',
#   'title': 'carbonite',
#   'url': 'http://www.carbonite.com/'},
#  {'description': 'The popular tile game, for the iPhone.',
#   'name': 'Carcassonne (iOS)',
#   'title': 'carcassonne-ios',
#   'url': 'http://carcassonneapp.com/'},
#  {'description': 'An Instagram client for Mac OS X.',
#   'name': 'Carousel',
#   'title': 'carousel',
#   'url': 'http://carousel.mobelux.com/'},
#  {'description': 'A distributed database system.',
#   'name': 'Cassandra',
#   'title': 'cassandra',
#   'url': 'https://cassandra.apache.org/'},
#  {'description': 'A note-taking app with cloud syncing.',
#   'name': 'Catch Notes (Android)',
#   'title': 'catch-notes-android',
#   'url': 'https://market.android.com/details?id=com.threebanana.notes'},
#  {'description': 'An game cum live music performance.',
#   'name': 'Cello Fortress',
#   'title': 'cello-fortress',
#   'url': 'http://www.cellofortress.com/'},
#  {'description': 'Handwrighting recognition software.',
#   'name': 'CellWriter',
#   'title': 'cellwriter',
#   'url': 'http://risujin.org/cellwriter/'},
#  {'description': 'A pre-production/script writing software suite.',
#   'name': 'Celtx',
#   'title': 'celtx',
#   'url': 'http://www.celtx.com/'},
#  {'description': 'A Linux distribution.',
#   'name': 'CentOS',
#   'title': 'centos',
#   'url': 'http://centos.org/'},
#  {'description': '8-bit sound creation tool, ported to the Mac.',
#   'name': 'cfxr',
#   'title': 'cfxr',
#   'url': 'http://thirdcog.eu/apps/cfxr'},
#  {'description': 'A Git repository viewer.',
#   'name': 'cgit',
#   'title': 'cgit',
#   'url': 'http://hjemli.net/git/cgit/'},
#  {'description': 'Self-organising software.',
#   'name': 'Chandler',
#   'title': 'chandler',
#   'url': 'http://chandlerproject.org/'},
#  {'description': 'A customer support web service.',
#   'name': 'Charm',
#   'title': 'charm',
#   'url': 'http://charmde.sk/'},
#  {'description': 'A real-time data tracking service.',
#   'name': 'Chartbeat',
#   'title': 'chartbeat',
#   'url': 'http://chartbeat.com/'},
#  {'description': 'A location-based to-do app.',
#   'name': 'Checkmark (iOS)',
#   'title': 'checkmark-ios',
#   'url': 'http://itunes.apple.com/app/checkmark/id524873453'},
#  {'description': 'Configuration management software.',
#   'name': 'Chef',
#   'title': 'chef',
#   'url': 'http://www.opscode.com/chef/'},
#  {'description': 'The game of chess for iOS.',
#   'name': 'Chess With Friends (iOS)',
#   'title': 'chess-with-friends-ios',
#   'url': 'http://itunes.apple.com/us/app/chess-with-friends-free/id295436227'},
#  {'description': 'An 8-bit sound-chip emulator.',
#   'name': 'chipsounds',
#   'title': 'chipsounds',
#   'url': 'http://www.plogue.com/products/chipsounds/'},
#  {'description': 'A text editor for the Mac.',
#   'name': 'Chocolat',
#   'title': 'chocolat',
#   'url': 'http://chocolatapp.com/'},
#  {'description': 'Mac software for selectivly picking a browser when clicking links.',
#   'name': 'Choosy',
#   'title': 'choosy',
#   'url': 'http://www.choosyosx.com/'},
#  {'description': 'A web broser app.',
#   'name': 'chrome-ios',
#   'title': 'chrome-ios',
#   'url': 'http://itunes.apple.com/us/app/chrome/id535886823'},
#  {'description': 'A Linux distribution for running web applications.',
#   'name': 'Chrome OS',
#   'title': 'chrome-os',
#   'url': 'https://en.wikipedia.org/wiki/Chrome_OS'},
#  {'description': 'A WebKit-based browser, where each tab runs in its own thread.',
#   'name': 'Chrome',
#   'title': 'chrome',
#   'url': 'http://google.com/chrome'},
#  {'description': 'Open-source builds of the Chrome web browser.',
#   'name': 'Chromium',
#   'title': 'chromium',
#   'url': 'http://code.google.com/chromium/'},
#  {'description': 'A synchronising and backup tool for the Mac.',
#   'name': 'ChronoSync',
#   'title': 'chronosync',
#   'url': 'http://www.econtechnologies.com/pages/cs/chrono_overview.html'},
#  {'description': 'A C++ framework for visual and audio projects.',
#   'name': 'Cinder',
#   'title': 'cinder',
#   'url': 'http://libcinder.org/'},
#  {'description': '3D rendering software.',
#   'name': 'Cinema 4D',
#   'title': 'cinema-4d',
#   'url': 'http://www.maxon.net/en/products/cinema-4d-prime/who-should-use-it.html'},
#  {'description': 'A service for managing scholarly references.',
#   'name': 'citeulike',
#   'title': 'citeulike',
#   'url': 'http://www.citeulike.org/'},
#  {'description': 'A GTK+ email client.',
#   'name': 'Claws Mail',
#   'title': 'claws-mail',
#   'url': 'http://www.claws-mail.org/'},
#  {'description': 'An archiving tool for the Mac.',
#   'name': 'CleanArchiver',
#   'title': 'cleanarchiver',
#   'url': 'http://sopht.jp/en/cleanarchiver/'},
#  {'description': 'A to do list app for the Mac and iOS.',
#   'name': 'Clear',
#   'title': 'clear',
#   'url': 'http://www.realmacsoftware.com/clear/'},
#  {'description': 'A browser plugin to require clicking before Flash content loads.',
#   'name': 'ClickToFlash',
#   'title': 'clicktoflash',
#   'url': 'http://clicktoflash.com/'},
#  {'description': 'A web analytics web service.',
#   'name': 'Clicky',
#   'title': 'clicky',
#   'url': 'http://getclicky.com/'},
#  {'description': 'A clipboard manager.',
#   'name': 'ClipMenu',
#   'title': 'clipmenu',
#   'url': 'http://www.clipmenu.com/'},
#  {'description': 'A Windows clipboard history manager.',
#   'name': 'ClipX',
#   'title': 'clipx',
#   'url': 'http://bluemars.org/clipx/'},
#  {'description': 'A VPN service for Macs.',
#   'name': 'Cloak',
#   'title': 'cloak',
#   'url': 'https://www.getcloak.com/'},
#  {'description': 'A dynamic programming language using the Java Virtual Machine.',
#   'name': 'Clojure',
#   'title': 'clojure',
#   'url': 'http://clojure.org/'},
#  {'description': 'A Clojure to Javascript compiler.',
#   'name': 'Clojurescript',
#   'title': 'clojurescript',
#   'url': 'http://www.clojurescript.net/'},
#  {'description': "Amazon's online music player.",
#   'name': 'Cloud Player',
#   'title': 'cloud-player',
#   'url': 'http://www.amazon.com/gp/help/customer/display.html/?nodeId=200593970'},
#  {'description': 'A CloudApp client app.',
#   'name': 'Cloud2go',
#   'title': 'cloud2go-ios',
#   'url': 'http://cloud2goapp.com/'},
#  {'description': 'A cloud-based file sharing menubar app for OS X.',
#   'name': 'CloudApp',
#   'title': 'cloudapp',
#   'url': 'http://www.getcloudapp.com/'},
#  {'description': 'A content delivery service.',
#   'name': 'CloudFront',
#   'title': 'cloudfront',
#   'url': 'http://aws.amazon.com/cloudfront/'},
#  {'description': 'A book and comic reading app.',
#   'name': 'Cloudreaders (iOS)',
#   'title': 'cloudreaders-ios',
#   'url': 'http://itunes.apple.com/us/app/cloudreaders-pdf-cbz-cbr/id363484920'},
#  {'description': 'A memory profiler for .NET programs.',
#   'name': 'CLR Profiler',
#   'title': 'clr-profiler',
#   'url': 'http://en.wikipedia.org/wiki/CLR_Profiler'},
#  {'description': 'An open-source cross-platform build tool.',
#   'name': 'CMake',
#   'title': 'cmake',
#   'url': 'http://www.cmake.org/'},
#  {'description': 'Free, open-source software for whiteboard collaboration.',
#   'name': 'Coccinella',
#   'title': 'coccinella',
#   'url': 'http://coccinella.im/'},
#  {'description': 'A maintenance and tweaking tool for OS X.',
#   'name': 'Cocktail',
#   'title': 'cocktail',
#   'url': 'http://www.maintain.se/cocktail/index.php'},
#  {'description': 'A framework for building 2D games and similar for the iPhone.',
#   'name': 'cocos2d',
#   'title': 'cocos2d',
#   'url': 'http://www.cocos2d-iphone.org/'},
#  {'description': 'A single-window HTML/web tool for the Mac.',
#   'name': 'Coda',
#   'title': 'coda',
#   'url': 'http://panic.com/coda/'},
#  {'description': 'Source code commits visualiser software.',
#   'name': 'code_swarm',
#   'title': 'code-swarm',
#   'url': 'http://code.google.com/p/codeswarm/'},
#  {'description': 'A C++ IDE.',
#   'name': 'Code::Blocks',
#   'title': 'codeblocks',
#   'url': 'http://www.codeblocks.org/'},
#  {'description': 'An open-source PHP web framework.',
#   'name': 'CodeIgniter',
#   'title': 'codeigniter',
#   'url': 'http://codeigniter.com/'},
#  {'description': 'A code editor and testing app for OS X.',
#   'name': 'CodeRunner',
#   'title': 'coderunner',
#   'url': 'http://krillapps.com/coderunner/'},
#  {'description': 'A development IDE primarily for embedded systems.',
#   'name': 'CodeWarrior',
#   'title': 'codewarrior',
#   'url': 'http://en.wikipedia.org/wiki/CodeWarrior'},
#  {'description': 'A CoffeeScript mode for Emacs.',
#   'name': 'coffee-mode',
#   'title': 'coffee-mode',
#   'url': 'https://github.com/defunkt/coffee-mode'},
#  {'description': 'A language that compiles into Javascript.',
#   'name': 'CoffeeScript',
#   'title': 'coffeescript',
#   'url': 'http://jashkenas.github.com/coffee-script/'},
#  {'description': 'A web application development system.',
#   'name': 'ColdFusion',
#   'title': 'coldfusion',
#   'url': 'http://www.adobe.com/products/coldfusion-family.html'},
#  {'description': 'An IRC client app.',
#   'name': 'Colloquy (iOS)',
#   'title': 'colloquy-ios',
#   'url': 'http://www.colloquy.mobi/'},
#  {'description': 'A popular IRC client for the Mac.',
#   'name': 'Colloquy',
#   'title': 'colloquy',
#   'url': 'http://www.colloquy.info/'},
#  {'description': 'A Flash-based colour palette tool.',
#   'name': 'color synthAxis',
#   'title': 'color-synthaxis',
#   'url': 'http://color.cranf.net/'},
#  {'description': 'A puzzle game.',
#   'name': 'Colorbind (iOS)',
#   'title': 'colorbind-ios',
#   'url': 'http://itunes.apple.com/us/app/colorbind/id356126423'},
#  {'description': 'A Flash-based colour palette tool.',
#   'name': 'Colorbrewer',
#   'title': 'colorbrewer',
#   'url': 'http://colorbrewer2.org/'},
#  {'description': 'A Mac tool for building colour palettes.',
#   'name': 'ColorSchemer Studio',
#   'title': 'colorschemer-studio',
#   'url': 'http://www.colorschemer.com/osx_info.php'},
#  {'description': 'A colour picker for the Mac.',
#   'name': 'ColorSnapper',
#   'title': 'colorsnapper',
#   'url': 'http://colorsnapper.com/'},
#  {'description': 'A web community for colour palettes.',
#   'name': 'Colour Lovers',
#   'title': 'colour-lovers',
#   'url': 'http://www.colourlovers.com/'},
#  {'description': 'A comic book reader app.',
#   'name': 'Comic Zeal (iOS)',
#   'title': 'comic-zeal-ios',
#   'url': 'http://www.comiczealapp.com/'},
#  {'description': 'A web-based comic book database.',
#   'name': 'comicbookdb',
#   'title': 'comicbookdb',
#   'url': 'http://www.comicbookdb.com/'},
#  {'description': 'A comic viewer and store app.',
#   'name': 'Comics (iOS)',
#   'title': 'comics-ios',
#   'url': 'http://itunes.apple.com/us/app/comics/id303491945'},
#  {'description': 'A Dropbox-backed text editor for the Mac.',
#   'name': 'Compositions',
#   'title': 'compositions',
#   'url': 'http://www.capparsa.com/Compositions/'},
#  {'description': 'Video compression software for the Mac.',
#   'name': 'Compressor',
#   'title': 'compressor',
#   'url': 'http://www.apple.com/finalcutpro/compressor/'},
#  {'description': 'A content management system.',
#   'name': 'concrete5',
#   'title': 'concrete5',
#   'url': 'http://www.concrete5.org/'},
#  {'description': 'A custom bootloader for the Wii.',
#   'name': 'Configurable USB Loader',
#   'title': 'configurable-usb-loader',
#   'url': 'http://gbatemp.net/index.php?showtopic=147638'},
#  {'description': 'Collaborative wiki software.',
#   'name': 'Confluence',
#   'title': 'confluence',
#   'url': 'http://www.atlassian.com/software/confluence/overview'},
#  {'description': 'A keyboard-driven web browser.',
#   'name': 'Conkeror',
#   'title': 'conkeror',
#   'url': 'http://conkeror.org/'},
#  {'description': 'Web conferencing software.',
#   'name': 'Adobe Connect',
#   'title': 'connect',
#   'url': 'http://www.adobe.com/products/acrobatconnectpro/'},
#  {'description': 'A secure shell for Android devices.',
#   'name': 'connectbot (Android)',
#   'title': 'connectbot-android',
#   'url': 'http://code.google.com/p/connectbot/'},
#  {'description': 'The log viewer included with Mac OS X.',
#   'name': 'Console',
#   'title': 'console',
#   'url': 'http://en.wikipedia.org/wiki/Console_(Mac_OS_X)'},
#  {'description': "A programmer's text editor for Windows.",
#   'name': 'ConTEXT',
#   'title': 'context',
#   'url': 'http://www.contexteditor.org/'},
#  {'description': 'A unit conversion and calculator app.',
#   'name': 'Convert (iOS)',
#   'title': 'convert-ios',
#   'url': 'http://www.taptaptap.com/#convert'},
#  {'description': 'A unit conversion app for the iPhone.',
#   'name': 'Convertbot (iOS)',
#   'title': 'convertbot-ios',
#   'url': 'http://tapbots.com/convertbot/'},
#  {'description': 'An iOS client for the group chat service.',
#   'name': 'Convore (iOS)',
#   'title': 'convore-ios',
#   'url': 'http://itunes.apple.com/us/app/convore/id424470699'},
#  {'description': 'A web service for group conversations.',
#   'name': 'Convore',
#   'title': 'convore',
#   'url': 'https://convore.com/'},
#  {'description': 'Digital audio creation software.',
#   'name': 'Cool Edit Pro',
#   'title': 'cool-edit-pro',
# ...
#   'title': 'webscarab',
#   'url': 'http://www.owasp.org/index.php/Category:OWASP_WebScarab_Project'},
#  {'description': 'An Android app for transfering files to a computer over WiFi.',
#   'name': 'WebSharing (Android)',
#   'title': 'websharing-android',
#   'url': 'https://market.android.com/details?id=nextapp.websharing.r1'},
#  {'description': 'A popular web-based strategy game.',
#   'name': 'Weewar',
#   'title': 'weewar',
#   'url': 'http://www.weewar.com/'},
#  {'description': 'A weight-tracking application for iOS.',
#   'name': 'WeightBot (iOS)',
#   'title': 'weightbot-ios',
#   'url': 'http://tapbots.com/software/weightbot/'},
#  {'description': 'Data mining software written in Java.',
#   'name': 'Weka',
#   'title': 'weka',
#   'url': 'http://www.cs.waikato.ac.nz/ml/weka/'},
#  {'description': 'Software to help you learn Chinese.',
#   'name': 'Wenlin',
#   'title': 'wenlin',
#   'url': 'http://www.wenlin.com/'},
#  {'description': 'A multi-protocol file downloading command-line tool.',
#   'name': 'wget',
#   'title': 'wget',
#   'url': 'http://www.gnu.org/s/wget/'},
#  {'description': 'A cross-platform chat client for iOS.',
#   'name': 'Whatsapp (iOS)',
#   'title': 'whatsapp-ios',
#   'url': 'http://itunes.apple.com/app/whatsapp-messenger/id310633997'},
#  {'description': 'A noise generating app.',
#   'name': 'White Noise Ambience (iOS)',
#   'title': 'white-noise-ambience-ios',
#   'url': 'http://itunes.apple.com/us/app/white-noise-ambience/id424832949'},
#  {'description': 'Software for full disk encryption.',
#   'name': 'Whole Disk Encryption',
#   'title': 'whole-disk-encryption',
#   'url': 'http://www.pgp.com/products/wholediskencryption/'},
#  {'description': 'A Wikipedia app for the iPhone.',
#   'name': 'Wikipanion (iOS)',
#   'title': 'wikipanion-ios',
#   'url': 'http://www.wikipanion.net/'},
#  {'description': "A virtual printer for Windows used to 'print' PDF files.",
#   'name': 'Win2PDF',
#   'title': 'win2pdf',
#   'url': 'http://www.win2pdf.com/'},
#  {'description': 'A media player.',
#   'name': 'Winamp',
#   'title': 'winamp',
#   'url': 'http://www.winamp.com/'},
#  {'description': 'Development tools for the AVR microprocessor family.',
#   'name': 'WinAVR',
#   'title': 'winavr',
#   'url': 'http://winavr.sourceforge.net/'},
#  {'description': "An X window manager inspired by NeXTStep's interface.",
#   'name': 'Window Maker',
#   'title': 'window-maker',
#   'url': 'http://windowmaker.org/'},
#  {'description': 'The upcoming revision of Windows.',
#   'name': 'Windows 7',
#   'title': 'windows-7',
#   'url': 'http://microsoft.com/windows/windows-7/'},
#  {'description': 'An operating system for PC and tablet computers.',
#   'name': 'Windows 8',
#   'title': 'windows-8',
#   'url': 'https://en.wikipedia.org/wiki/Windows_8'},
#  {'description': 'A PC operating system.',
#   'name': 'Windows 98',
#   'title': 'windows-98',
#   'url': 'https://en.wikipedia.org/wiki/Windows_98'},
#  {'description': 'A chat client for MSN.',
#   'name': 'Windows Live Messenger',
#   'title': 'windows-live-messenger',
#   'url': 'http://explore.live.com/windows-live-messenger'},
#  {'description': 'Audio/media jukebox software.',
#   'name': 'Windows Media Player',
#   'title': 'windows-media-player',
#   'url': 'http://www.microsoft.com/windows/windowsmedia/player/default.aspx'},
#  {'description': "Microsoft's mobile operating system.",
#   'name': 'Windows Phone',
#   'title': 'windows-phone',
#   'url': 'http://www.microsoft.com/windowsphone/en-us/default.aspx'},
#  {'description': 'A somewhat unpopular OS for x86 computers.',
#   'name': 'Windows Vista',
#   'title': 'windows-vista',
#   'url': 'http://microsoft.com/windows/windows-vista/'},
#  {'description': 'An operating system for x86 computers.',
#   'name': 'Windows XP',
#   'title': 'windows-xp',
#   'url': 'http://microsoft.com/windows/windows-xp/'},
#  {'description': 'A Mac haxie to customise window minimising.',
#   'name': 'Windowshade X',
#   'title': 'windowshade-x',
#   'url': 'http://unsanity.com/haxies/wsx'},
#  {'description': 'File compression software for Windows.',
#   'name': 'WinRAR',
#   'title': 'winrar',
#   'url': 'http://www.rarlab.com/'},
#  {'description': 'A free S/FTP and SCP client for Windows.',
#   'name': 'WinSCP',
#   'title': 'winscp',
#   'url': 'http://winscp.net/eng/index.php'},
#  {'description': 'File compression and encryption software for Windows.',
#   'name': 'WinZip',
#   'title': 'winzip',
#   'url': 'http://www.winzip.com/'},
#  {'description': 'The magazine as an app.',
#   'name': 'WIRED (iOS)',
#   'title': 'wired-ios',
#   'url': 'http://itunes.apple.com/us/app/wired-magazine/id373903654'},
#  {'description': 'A network protocol analyser.',
#   'name': 'Wireshark',
#   'title': 'wireshark',
#   'url': 'http://www.wireshark.org/'},
#  {'description': 'A personal metrics app for Withings products.',
#   'name': 'WiScale (iOS)',
#   'title': 'wiscale-ios',
#   'url': 'http://itunes.apple.com/us/app/wiscale/id319085928'},
#  {'description': 'An online knowledge engine.',
#   'name': 'Wolfram Alpha',
#   'title': 'wolfram-alpha',
#   'url': 'http://www.wolframalpha.com/'},
#  {'description': 'An experimental audio generating web tool.',
#   'name': 'Wolfram Tones',
#   'title': 'wolfram-tones',
#   'url': 'http://tones.wolfram.com/'},
#  {'description': 'A popular document editor.',
#   'name': 'MS Word',
#   'title': 'word',
#   'url': 'http://office.microsoft.com/en-us/word/'},
#  {'description': 'An iPhone app for creating, editing and managing WordPress posts and comments.',
#   'name': 'WordPress (iOS)',
#   'title': 'wordpress-ios',
#   'url': 'http://iphone.wordpress.org/'},
#  {'description': 'A multi-weblog, self-hosted publishing tool.',
#   'name': 'Wordpress MU',
#   'title': 'wordpress-mu',
#   'url': 'http://mu.wordpress.org/'},
#  {'description': 'Weblog publishing software.',
#   'name': 'Wordpress',
#   'title': 'wordpress',
#   'url': 'http://wordpress.com/'},
#  {'description': 'A word game for the iPhone.',
#   'name': 'Words With Friends (iOS)',
#   'title': 'words-with-friends-ios',
#   'url': 'http://itunes.apple.com/us/app/words-with-friends/id322852954'},
#  {'description': 'Engineering simulation software.',
#   'name': 'Workbench',
#   'title': 'workbench',
#   'url': 'http://www.ansys.com/Products/Workflow+Technology/ANSYS+Workbench+Platform'},
#  {'description': 'Windows software reminding you to take regular breaks.',
#   'name': 'Workrave',
#   'title': 'workrave',
#   'url': 'http://www.workrave.org/'},
#  {'description': 'A physics-based game.',
#   'name': 'World of Goo (iOS)',
#   'title': 'world-of-goo-ios',
#   'url': 'http://itunes.apple.com/us/app/world-of-goo-hd/id401301276'},
#  {'description': 'Virtual telescope software.',
#   'name': 'Worldwide Telescope',
#   'title': 'worldwide-telescope',
#   'url': 'http://www.worldwidetelescope.org/Home.aspx'},
#  {'description': 'A slightly popular fantasy MMORPG.',
#   'name': 'World of Warcraft',
#   'title': 'wow',
#   'url': 'http://www.worldofwarcraft.com/'},
#  {'description': 'Web-based sharable text document.',
#   'name': 'Writeboard',
#   'title': 'writeboard',
#   'url': 'http://writeboard.com/'},
#  {'description': 'A distraction-free writing app for the iPhone.',
#   'name': 'WriteRoom (iOS)',
#   'title': 'writeroom-ios',
#   'url': 'http://itunes.apple.com/us/app/writeroom/id288751446?mt=8'},
#  {'description': 'Full-screen writing software.',
#   'name': 'WriteRoom',
#   'title': 'writeroom',
#   'url': 'http://www.hogbaysoftware.com/products/writeroom'},
#  {'description': 'A Markdown-based text editor for iOS.',
#   'name': 'Writing Kit (iOS)',
#   'title': 'writing-kit-ios',
#   'url': 'http://getwritingkit.com/'},
#  {'description': 'FTP software for Windows.',
#   'name': 'WS_FTP Professional',
#   'title': 'ws-ftp-pro',
#   'url': 'http://www.ipswitchft.com/products/ws_ftp_pro/'},
#  {'description': 'A cloud-syncing to-do manager.',
#   'name': 'Wunderlist',
#   'title': 'wunderlist',
#   'url': 'http://www.6wunderkinder.com/wunderlist/'},
#  {'description': 'A word game for the iPhone.',
#   'name': 'wurdle (iOS)',
#   'title': 'wurdle-ios',
#   'url': 'http://www.semisecretsoftware.com/wurdle/'},
#  {'description': 'A GUI for designing wxWidgets apps.',
#   'name': 'wxFormBuilder',
#   'title': 'wxformbuilder',
#   'url': 'http://wxformbuilder.org/'},
#  {'description': 'Python bindings for wxWidgets.',
#   'name': 'wxPython',
#   'title': 'wxpython',
#   'url': 'http://www.wxpython.org/'},
#  {'description': 'A cross-platform GUI library.',
#   'name': 'wxWidgets',
#   'title': 'wxwidgets',
#   'url': 'http://www.wxwidgets.org/'},
#  {'description': 'An OS X version of the IRC client.',
#   'name': 'X-Chat Aqua',
#   'title': 'x-chat-aqua',
#   'url': 'http://sourceforge.net/projects/xchataqua/'},
#  {'description': 'A weblog platform.',
#   'name': 'Xanga',
#   'title': 'xanga',
#   'url': 'http://www.xanga.com/'},
#  {'description': 'A command-line tool to execute commands from standard input.',
#   'name': 'xargs',
#   'title': 'xargs',
#   'url': 'http://en.wikipedia.org/wiki/Xargs'},
#  {'description': 'A keyboard/mouse launcher tool for X11.',
#   'name': 'xbindkeys',
#   'title': 'xbindkeys',
#   'url': 'http://www.nongnu.org/xbindkeys/xbindkeys.html'},
#  {'description': 'Media center software.',
#   'name': 'XBMC',
#   'title': 'xbmc',
#   'url': 'http://xbmc.org/'},
#  {'description': 'An online service for the Xbox 360.',
#   'name': 'Xbox Live',
#   'title': 'xbox-live',
#   'url': 'http://www.xbox.com/en-US/live'},
#  {'description': 'A cross-platform IRC client.',
#   'name': 'XChat',
#   'title': 'xchat',
#   'url': 'http://www.xchat.org/'},
#  {'description': 'An IDE for Mac developers.',
#   'name': 'XCode',
#   'title': 'xcode',
#   'url': 'http://developer.apple.com/technology/tools.html'},
#  {'description': 'A version of Emacs.',
#   'name': 'XEmacs',
#   'title': 'xemacs',
#   'url': 'http://www.xemacs.org/'},
#  {'description': 'Virtualisation software.',
#   'name': 'Xen',
#   'title': 'xen',
#   'url': 'http://xen.org/'},
#  {'description': 'A lightweight UNIX-like desktop environment.',
#   'name': 'XFCE',
#   'title': 'xfce',
#   'url': 'http://www.xfce.org/'},
#  {'description': 'An open-source window system.',
#   'name': 'XFree86',
#   'title': 'xfree86',
#   'url': 'http://www.xfree86.org/'},
#  {'description': 'Distributed protocol/software.',
#   'name': 'XGrid',
#   'title': 'xgrid',
#   'url': 'https://en.wikipedia.org/wiki/Xgrid'},
#  {'description': 'A bookmark syncing service.',
#   'name': 'Xmarks',
#   'title': 'xmarks',
#   'url': 'http://www.xmarks.com/'},
#  {'description': 'An R package for working with XML.',
#   'name': 'XML',
#   'title': 'xml',
#   'url': 'http://cran.r-project.org/web/packages/XML/'},
#  {'description': 'A tiling window manager for X11.',
#   'name': 'xmonad',
#   'title': 'xmonad',
#   'url': 'http://xmonad.org/'},
#  {'description': 'A 3D displacement map generator.',
#   'name': 'XNormal',
#   'title': 'xnormal',
#   'url': 'http://www.xnormal.net/'},
#  {'description': 'A sketching and note-taking application for stylus-based computers.',
#   'name': 'Xournal',
#   'title': 'xournal',
#   'url': 'http://xournal.sourceforge.net/'},
#  {'description': 'A flexible notepad for the Mac.',
#   'name': 'xPad',
#   'title': 'xpad',
#   'url': 'http://www.getxpad.com/'},
#  {'description': 'An open source PDF viewer.',
#   'name': 'Xpdf',
#   'title': 'xpdf',
#   'url': 'http://foolabs.com/xpdf/about.html'},
#  {'description': 'A Mac tool for on-screen measuring and aligning.',
#   'name': 'xScope',
#   'title': 'xscope',
#   'url': 'http://iconfactory.com/software/xscope'},
#  {'description': 'Terminal software for the X Window System.',
#   'name': 'xterm',
#   'title': 'xterm',
#   'url': 'http://en.wikipedia.org/wiki/Xterm'},
#  {'description': 'A lightweight version of the Ubuntu distribution.',
#   'name': 'Xubuntu',
#   'title': 'xubuntu',
#   'url': 'http://xubuntu.com/'},
#  {'description': 'An old word processor for DOS and Windows.',
#   'name': 'XyWrite',
#   'title': 'xywrite',
#   'url': 'http://en.wikipedia.org/wiki/XyWrite'},
#  {'description': 'A service for mixing up web content.',
#   'name': 'Yahoo! Pipes',
#   'title': 'yahoo-pipes',
#   'url': 'http://pipes.yahoo.com/'},
#  {'description': 'An enterprise messaging platform.',
#   'name': 'Yammer',
#   'title': 'yammer',
#   'url': 'https://www.yammer.com/'},
#  {'description': 'An iPhone app for accessing Yelp reviews.',
#   'name': 'Yelp (iOS)',
#   'title': 'yelp-ios',
#   'url': 'http://phobos.apple.com/WebObjects/MZStore.woa/wa/viewSoftware?id=284910350&mt=8'},
#  {'description': 'A Mac application for storing your PDF documents.',
#   'name': 'Yep',
#   'title': 'yep',
#   'url': 'http://yepthat.com/yep/'},
#  {'description': "Data 'bucket' software for the Mac.",
#   'name': 'Yojimbo',
#   'title': 'yojimbo',
#   'url': 'http://barebones.com/products/Yojimbo/'},
#  {'description': 'A Twitter client for the Mac.',
#   'name': 'YoruFukurou',
#   'title': 'yorufukurou',
#   'url': 'http://sites.google.com/site/yorufukurou/'},
#  {'description': 'An iPhone app that will call your elected favourite contact.',
#   'name': "You're #1 (iOS)",
#   'title': 'youre-number-one-ios',
#   'url': 'http://www.utilitouch.com/app/you-are-number-1/index.html'},
#  {'description': 'A profiler system for Java and .NET.',
#   'name': 'YourKit',
#   'title': 'yourkit',
#   'url': 'http://www.yourkit.com/'},
#  {'description': 'A command-line tool for downloading videos from YouTube etc.',
#   'name': 'youtube-dl',
#   'title': 'youtube-dl',
#   'url': 'http://rg3.github.com/youtube-dl/'},
#  {'description': "A web site for watching 80's TV commercials and bad mashups.",
#   'name': 'YouTube',
#   'title': 'youtube',
#   'url': 'http://youtube.com/'},
#  {'description': 'A static site generator.',
#   'name': 'yst',
#   'title': 'yst',
#   'url': 'https://github.com/jgm/yst'},
#  {'description': 'A Windows word processor.',
#   'name': 'yWriter',
#   'title': 'ywriter',
#   'url': 'http://www.spacejock.com/yWriter5.html'},
#  {'description': 'Analog-style synthesizer software.',
#   'name': 'Z3TA+',
#   'title': 'z3ta',
#   'url': 'http://www.cakewalk.com/Products/Z3TA/Default.asp'},
#  {'description': '3D digital painting and sculpture software.',
#   'name': 'ZBrush',
#   'title': 'zbrush',
#   'url': 'http://www.pixologic.com/zbrush/'},
#  {'description': 'A modular synthesiser.',
#   'name': 'Zebra',
#   'title': 'zebra',
#   'url': 'http://www.u-he.com/zebra/'},
#  {'description': 'Distraction-free writing software for Windows.',
#   'name': 'ZenWriter',
#   'title': 'zenwriter',
#   'url': 'http://www.beenokle.com/zenwriter.html'},
#  {'description': 'A .NET resource editor.',
#   'name': 'Zeta Resource Editor',
#   'title': 'zeta-resource-editor',
#   'url': 'http://www.zeta-resource-editor.com/index.html'},
#  {'description': "A developer's text editor.",
#   'name': 'ZeusEdit',
#   'title': 'zeusedit',
#   'url': 'http://www.zeusedit.com/'},
#  {'description': 'An integrated mail, calendar, contact and document solution.',
#   'name': 'Zimbra',
#   'title': 'zimbra',
#   'url': 'http://www.zimbra.com/'},
#  {'description': 'A personal magazine app.',
#   'name': 'Zite (iOS)',
#   'title': 'zite-ios',
#   'url': 'http://itunes.apple.com/us/app/zite-personalized-magazine/id419752338'},
#  {'description': 'An IRC bouncer.',
#   'name': 'znc',
#   'title': 'znc',
#   'url': 'https://github.com/technomancy/znc'},
#  {'description': 'A Mac app to play interactive fiction.',
#   'name': 'Zoom',
#   'title': 'zoom',
#   'url': 'http://www.logicalshift.demon.co.uk/mac/zoom.html'},
#  {'description': 'A window resizer/mover tool for the Mac.',
#   'name': 'Zooom',
#   'title': 'zooom',
#   'url': 'http://coderage-software.com/zooom/'},
#  {'description': 'A visual bookmarking service.',
#   'name': 'Zootool',
#   'title': 'zootool',
#   'url': 'http://zootool.com/'},
#  {'description': 'A Python-based web application framework.',
#   'name': 'Zope',
#   'title': 'zope',
#   'url': 'http://zope.org/'},
#  {'description': 'A research tool.',
#   'name': 'Zotero',
#   'title': 'zotero',
#   'url': 'http://www.zotero.org/'},
#  {'description': 'An interactive shell and scripting language.',
#   'name': 'zsh',
#   'title': 'zsh',
#   'url': 'http://www.zsh.org/'},
#  {'description': 'A service to share your media via the cloud.',
#   'name': 'ZumoDrive',
#   'title': 'zumodrive',
#   'url': 'http://www.zumodrive.com/'},
#  {'description': 'A 2D sprite-packing tool.',
#   'name': 'Zwoptex',
#   'title': 'zwoptex',
#   'url': 'http://zwoptexapp.com/'}]

# %%
for el in software:
    el['type'] = 'software'

# %%
for el in hardware:
    el['type'] = 'hardware'

# %%
ware = hardware+software

# %%
ware
# Out:
# [{'description': 'A very powerful scanner.',
#   'name': '10000XL',
#   'title': '10000xl',
#   'type': 'hardware',
#   'url': 'http://www.epson.com/cgi-bin/Store/jsp/Product.do?sku=E10000XL-PH'},
#  {'description': 'Old speakers.',
#   'name': '104aB',
#   'title': '104ab',
#   'type': 'hardware',
#   'url': 'http://www.kef.com/html/us/explore/about_kef/museum/1970s/104aBKIT_CantataKIT/index.html'},
#  {'description': 'A subwoofer.',
#   'name': '10S',
#   'title': '10s',
#   'type': 'hardware',
#   'url': 'http://www.shopping.com/KRK-KRK-10S-Subwoofer/info?sb=1'},
#  {'description': 'A macro lens for SLRs.',
#   'name': '10x High Definition II',
#   'title': '10x-high-definition-ii',
#   'type': 'hardware',
#   'url': 'http://opteka.com/10x.aspx'},
#  {'description': 'A chair.',
#   'name': '111 Navy',
#   'title': '111-navy',
#   'type': 'hardware',
#   'url': 'http://www.emeco.net/product/111navychair.html'},
#  {'description': 'A basic mobile phone.',
#   'name': '1208',
#   'title': '1208',
#   'type': 'hardware',
#   'url': 'http://mobile.softpedia.com/phones/Nokia/Nokia-1208.shtml'},
#  {'description': 'A mic preamp.',
#   'name': '12AY7',
#   'title': '12ay7',
#   'type': 'hardware',
#   'url': 'http://www.ehx.com/products/12ay7-mic-pre'},
#  {'description': 'A fancy watch.',
#   'name': '150 Series',
#   'title': '150-series',
#   'type': 'hardware',
#   'url': 'http://www.uniformwares.com/150-series-pvd-rose-gold-or-antique-brown-leather'},
#  {'description': 'A solid camera case that meets airline standards for carry-on luggage.',
#   'name': '1510 Carry On Case',
#   'title': '1510-carry-on-case',
#   'type': 'hardware',
#   'url': 'http://www.pelican.com/cases_detail.php?Case=1510'},
#  {'description': 'A DC power supply.',
#   'name': '1621A',
#   'title': '1621a',
#   'type': 'hardware',
#   'url': 'http://www.bkprecision.com/products/power-supplies/1621A-0-to-18v-0-to-5a-digital-display-dc-power-supply.html'},
#  {'description': 'A 19 inch LCD monitor.',
#   'name': '1905FP',
#   'title': '1905fp',
#   'type': 'hardware',
#   'url': 'http://support.dell.com/support/edocs/monitors/r83546/EN/'},
#  {'description': 'A 7x zoom loupe.',
#   'name': '#1975 Scale Loupe 7x',
#   'title': '1975-scale-loupe-7x',
#   'type': 'hardware',
#   'url': 'http://www.peakoptics.com/index.php?main_page=product_info&cPath=66&products_id=10'},
#  {'description': 'A KVM for sharing monitors, PS/2 mice and keyboards between two computers.',
#   'name': '2-port PS/2 KVM',
#   'title': '2-port-ps-2-kvm',
#   'type': 'hardware',
#   'url': 'http://www.belkin.com/IWCatProductPage.process?Product_Id=262915'},
#  {'description': 'A cordless presenter.',
#   'name': '2.4 GHz Cordless Presenter',
#   'title': '2.4-ghz-cordless-presenter',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Logitech-2-4-Cordless-Presenter-Black/dp/B0007KVK8E'},
#  {'description': 'Field monitor speakers.',
#   'name': '20-20',
#   'title': '20-20',
#   'type': 'hardware',
#   'url': 'http://reviews.cnet.com/separate-speakers/event-20-20-left/1707-7869_7-30455233.html'},
#  {'description': 'A digital multimeter.',
#   'name': '2000 DMM',
#   'title': '2000-dmm',
#   'type': 'hardware',
#   'url': 'http://www.keithley.com/products/dcac/dmm/broadpurpose/?mn=2000'},
#  {'description': 'A fountain pen.',
#   'name': '2000',
#   'title': '2000',
#   'type': 'hardware',
#   'url': 'http://www.lamyusa.com/lamy_fountain_L01_2000.php'},
#  {'description': 'A 20.1 inch LCD screen.',
#   'name': '2001FP',
#   'title': '2001fp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/PopupProductDetail.aspx?cs=19&l=en&c=us&sku=320-1578'},
#  {'description': 'A 20 inch LCD monitor.',
#   'name': 'UltraSharp 2007fp',
#   'title': '2007fp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/products/Displays/productdetail.aspx?c=us&l=en&s=dhs&cs=19&sku=320-4687'},
#  {'description': 'An industrial sewing machine.',
#   'name': '206RB-5',
#   'title': '206rb-5',
#   'type': 'hardware',
#   'url': 'http://www.consew.com/View/Consew-Model-206RB-5'},
#  {'description': "A limited-edition Macintosh celebrating Apple's 20th birthday.",
#   'name': 'Twentieth Anniversary Macintosh',
#   'title': '20th-anniversary-macintosh',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Twentieth_Anniversary_Macintosh'},
#  {'description': 'A digital multimeter.',
#   'name': '22-802',
#   'title': '22-802',
#   'type': 'hardware',
#   'url': 'http://support.radioshack.com/productinfo/DocumentResults.asp?sku_id=22-802&Name=Meters%20and%20Scopes&Reuse=N'},
#  {'description': 'A 24 inch LCD monitor.',
#   'name': 'UltraSharp 2407WFP',
#   'title': '2407wfp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/productdetail.aspx?sku=320-4335'},
#  {'description': 'A 24 inch LCD screen.',
#   'name': 'UltraSharp 2408WFP',
#   'title': '2408wfp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/productdetail.aspx?c=us&l=en&s=gen&sku=320-6272'},
#  {'description': 'A 24 inch widescreen LCD screen.',
#   'name': '2443BW',
#   'title': '2443bw',
#   'type': 'hardware',
#   'url': 'http://www.samsung.com/ca/consumer/office/monitors/lcd/LS24MYKRBQ/XAA'},
#  {'description': 'A 25 inch LCD screen.',
#   'name': '2510i',
#   'title': '2510i',
#   'type': 'hardware',
#   'url': 'http://gdgt.com/hp/2510i/'},
#  {'description': 'A soldering station.',
#   'name': '2738',
#   'title': '2738',
#   'type': 'hardware',
#   'url': 'http://www.gsmsp.com/products/Repair_Tools/Soldering_Tools/Solder_Station/AOYUE_Int_2738_Lead_Free_Soldering_Station__220V__344_7233.html'},
#  {'description': 'A 27 inch LCD monitor.',
#   'name': 'SyncMaster 275T+',
#   'title': '275t-plus',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Samsung-SyncMaster-275T-27-inch-Monitor/dp/B0013PVRQM'},
#  {'description': 'A 27 inch LCD screen.',
#   'name': '27Q',
#   'title': '27q',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/CROSSOVER-27Q-LED-P-2560X1440-Monitor/dp/B008B6I5UW'},
#  {'description': 'A 2-bay RAID system.',
#   'name': '2big Quadra',
#   'title': '2big-quadra',
#   'type': 'hardware',
#   'url': 'http://www.lacie.com/us/products/product.htm?pid=11140'},
#  {'description': 'A hifi cartridge.',
#   'name': '2M Red',
#   'title': '2m-red',
#   'type': 'hardware',
#   'url': 'http://www.ortofon.com/products/cartridges/cartridges-2m-series/2m-red'},
#  {'description': 'A dual-link DVI KVM.',
#   'name': '2x1 DVIKVM DL',
#   'title': '2x1-dvikvm-dl',
#   'type': 'hardware',
#   'url': 'http://www.gefen.com/kvm/dproduct.jsp?prod_id=4511'},
#  {'description': "Dell's 30 inch widescreen LCD monitor.",
#   'name': '3007WFP',
#   'title': '3007wfp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/products/Monitors/productdetail.aspx?sku=222-7175'},
#  {'description': 'A 30 inch LCD screen.',
#   'name': '3008WFP',
#   'title': '3008wfp',
#   'type': 'hardware',
#   'url': 'http://accessories.us.dell.com/sna/products/Monitors/productdetail.aspx?c=us&l=en&s=dhs&cs=19&sku=223-4890'},
#  {'description': 'A 30 inch LCD monitor.',
#   'name': '3090wqxi',
#   'title': '3090wqxi',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/NEC-LCD3090WQXi-BK-30-Inch-Widescreen-Resolution/dp/B0013DJ31A/'},
#  {'description': 'A sewing machine.',
#   'name': '3160QDC',
#   'title': '3160qdc',
#   'type': 'hardware',
#   'url': 'http://content.janome.com/index.cfm/Machines/Sewing-Quilting/3160QDC'},
#  {'description': 'A 24 inch LCD screen.',
#   'name': '324i',
#   'title': '324i',
#   'type': 'hardware',
#   'url': 'http://www.lacie.com/products/product.htm?id=10524'},
#  {'description': 'A digital multimeter.',
#   'name': '33XR',
#   'title': '33xr',
#   'type': 'hardware',
#   'url': 'http://www.tequipment.net/Wavetek33XR.html'},
#  {'description': 'A guitar amp.',
#   'name': '370',
#   'title': '370',
#   'type': 'hardware',
#   'url': 'http://acoustic.homeunix.net/twiki/bin/view/Acoustic/BassHead370'},
#  {'description': 'A channel strip processor.',
#   'name': '376 Tube Channel processor',
#   'title': '376',
#   'type': 'hardware',
#   'url': 'http://dbxpro.com/376/376.php'},
#  {'description': 'A DC power supply.',
#   'name': '382213',
#   'title': '382213',
#   'type': 'hardware',
#   'url': 'http://www.extech.com/instruments/product.asp?catid=39&prodid=212'},
#  {'description': 'A portable gaming console with a 3D screen.',
#   'name': '3DS',
#   'title': '3ds',
#   'type': 'hardware',
#   'url': 'http://www.nintendo.com/3ds/'},
#  {'description': 'A personal 3G mini cell tower.',
#   'name': '3g Microcell',
#   'title': '3g-microcell',
#   'type': 'hardware',
#   'url': 'http://www.wireless.att.com/learn/why/3gmicrocell/'},
#  {'description': 'A four colour pen.',
#   'name': '4-COLOR',
#   'title': '4-color',
#   'type': 'hardware',
#   'url': 'http://www.bicworld.com/en/products/details/18/4-color'},
#  {'description': 'A zester.',
#   'name': '40001 Zester',
#   'title': '40001-zester',
#   'type': 'hardware',
#   'url': 'http://us.microplane.com/40001zester.aspx'},
#  {'description': 'An omnidirectional microphone.',
#   'name': '4060',
#   'title': '4060',
#   'type': 'hardware',
#   'url': 'http://www.dpamicrophones.com/en/products.aspx?c=Item&item=24035'},
#  {'description': 'A microphone.',
#   'name': "4104 Commentator's Ribbon Microphone",
#   'title': '4104-commentators',
#   'type': 'hardware',
#   'url': 'http://www.coleselectroacoustics.com/miccommentators.shtml'},
#  {'description': 'A portable recorder/mixer.',
#   'name': '424 MKII',
#   'title': '424-mkii',
#   'type': 'hardware',
#   'url': 'http://homerecording.com/tas424.html'},
#  {'description': 'A thermoforming machine.',
#   'name': '450',
#   'title': '450',
#   'type': 'hardware',
#   'url': 'http://www.youtube.com/watch?v=GF0Bm3Uf94M'},
#  {'description': 'An old film camera.',
#   'name': '500 C/M',
#   'title': '500-cm',
#   'type': 'hardware',
#   'url': 'http://camerapedia.wikia.com/wiki/Hasselblad_500_C/M'},
#  {'description': 'A canvas zipper bag.',
#   'name': '5139',
#   'title': '5139',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Klein-5139-2-Inch-Canvas-Zipper/dp/B000BQRCKY'},
#  {'description': 'A thermometer gun.',
#   'name': '62 Mini Infrared',
#   'title': '62-mini-infrared',
#   'type': 'hardware',
#   'url': 'http://www.fluke.com/fluke/usen/Electrical-Test-Tools/Thermometers/Fluke-62.htm?PID=56096'},
#  {'description': 'A handheld interview microphone.',
#   'name': '635A',
#   'title': '635a',
#   'type': 'hardware',
#   'url': 'http://www.electrovoice.com/product.php?id=100'},
#  {'description': 'A 35mm film camera.',
#   'name': '645 Pro-TL',
#   'title': '645-pro-tl',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Mamiya-645-Pro-TL-camera-medium/dp/B0001JZW8K'},
#  {'description': 'A medium format film camera.',
#   'name': 'Mamiya 645AF',
#   'title': '645af',
#   'type': 'hardware',
#   'url': 'http://www.butkus.org/chinon/mamiya/mamiya_645af/mamiya_645af.htm'},
#  {'description': 'A telephoto zoom lens.',
#   'name': '70-200mm F2.8 EX DG APOMacro HSM II',
#   'title': '70-200mm-ex-dg',
#   'type': 'hardware',
#   'url': 'http://www.sigmaphoto.com/shop/70-200mm-f28-ex-dg-apomacro-hsm-ii-sigma'},
#  {'description': 'Subwoofers.',
#   'name': '7070A',
#   'title': '7070a',
#   'type': 'hardware',
#   'url': 'http://www.genelec.com/products/subwoofers/7070a/'},
#  {'description': 'A four-channel recorder.',
#   'name': '744T',
#   'title': '744t',
#   'type': 'hardware',
#   'url': 'http://www.sounddevices.com/products/744t/'},
#  {'description': 'A gasmask.',
#   'name': '7700 Half Mask',
#   'title': '7700-half-mask',
#   'type': 'hardware',
#   'url': 'http://www.approvedgasmasks.com/north-7700.htm'},
#  {'description': 'A medium format film camera.',
#   'name': '7II',
#   'title': '7ii',
#   'type': 'hardware',
#   'url': 'http://olegnovikov.com/technical/mamiya7ii/mamiya7ii.shtml'},
#  {'description': 'A mechanical pencil.',
#   'name': '800',
#   'title': '800',
#   'type': 'hardware',
#   'url': 'http://www.jetpens.com/Rotring-800-Drafting-Pencil-0.5-mm-Black-Body/pd/6767'},
#  {'description': 'Monitor speakers.',
#   'name': '8020A',
#   'title': '8020a',
#   'type': 'hardware',
#   'url': 'http://www.genelec.com/products/previous-models/8020a/'},
#  {'description': 'A FireWire/USB audio interface.',
#   'name': '828mk3 Hybrid',
#   'title': '828mk3-hybrid',
#   'type': 'hardware',
#   'url': 'http://www.motu.com/products/motuaudio/828mk3'},
#  {'description': 'A soldering station.',
#   'name': '850B',
#   'title': '850b',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/850B-SMT-REWORK-STATION-SOLDER/dp/B000E14FJW'},
#  {'description': 'A DSLR lens.',
#   'name': '85M-P 85mm F1.4',
#   'title': '85m-p-85mm-f1.4',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Rokinon-85M-P-Aspherical-Pentax-Black/dp/B0025F4AWW'},
#  {'description': 'A hot air soldering station.',
#   'name': '906',
#   'title': '906',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Aoyue-Soldering-Rework-Station-Bonus/dp/B002NZYP38'},
#  {'description': 'A reel to reel machine.',
#   'name': 'A-2340R',
#   'title': 'a-2340r',
#   'type': 'hardware',
#   'url': 'http://www.youtube.com/watch?v=CGR4QvPbdA8'},
#  {'description': 'Street/gaming headphones.',
#   'name': 'A30',
#   'title': 'a30',
#   'type': 'hardware',
#   'url': 'http://www.astrogaming.com/headsets/a30-headsets'},
#  {'description': 'Gamer headphones.',
#   'name': 'A40',
#   'title': 'a40',
#   'type': 'hardware',
#   'url': 'http://www.astrogaming.com/a40'},
#  {'description': 'Tiny but powerful speakers.',
#   'name': 'A5',
#   'title': 'a5',
#   'type': 'hardware',
#   'url': 'http://www.audioengineusa.com/a5_home.php'},
#  {'description': 'A phone.',
#   'name': 'Accolade VX5600',
#   'title': 'accolade-vx5600',
#   'type': 'hardware',
#   'url': 'http://www.lg.com/us/cell-phones/lg-VX5600-accolade'},
#  {'description': 'A digital plotter.',
#   'name': 'AccuPlot 320',
#   'title': 'accuplot-320',
#   'type': 'hardware',
#   'url': 'http://www.gerbertechnology.ru/eng/accuplot_100.php'},
#  {'description': 'A co-branded PC laptop.',
#   'name': 'Acer Ferrari 5000-5832',
#   'title': 'acer-ferrari-5000',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Acer-Ferrari-5000-5832-Processor-Ultimate/dp/B000LO8ZPM'},
#  {'description': 'A film camera that takes 4 photos per shot.',
#   'name': 'ActionSampler',
#   'title': 'actionsampler',
#   'type': 'hardware',
#   'url': 'http://microsites.lomography.com/actionsampler/main/'},
#  {'description': 'A PC laptop with a 3D screen.',
#   'name': 'Actius RD3D',
#   'title': 'actius-rd3d',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/Sharp_Actius_RD3D_Notebook'},
#  {'description': 'A fancy ergonomic keyboard.',
#   'name': 'Advantage Pro USB',
#   'title': 'advantage-pro-usb',
#   'type': 'hardware',
#   'url': 'http://www.kinesis-ergo.com/advantage_pro.htm'},
#  {'description': 'A fancy ergonomic keyboard.',
#   'name': 'Advantage USB',
#   'title': 'advantage-usb',
#   'type': 'hardware',
#   'url': 'http://www.kinesis-ergo.com/advantage.htm'},
#  {'description': 'Around-the-ear headphones.',
#   'name': 'AE2',
#   'title': 'ae2',
#   'type': 'hardware',
#   'url': 'http://www.bose.com/controller?url=/shop_online/headphones/audio_headphones/around_ear_headphones/'},
#  {'description': 'Computer speakers.',
#   'name': 'Aego M',
#   'title': 'aego-m',
#   'type': 'hardware',
#   'url': 'http://www.macworld.com/reviews/product/413477/review/aego_m.html'},
#  {'description': 'A gaming cabinet.',
#   'name': 'Aero City',
#   'title': 'aero-city',
#   'type': 'hardware',
#   'url': 'http://home.insightbb.com/~ecousticforkris/aero.htm'},
#  {'description': 'A very very popular work chair.',
#   'name': 'Aeron',
#   'title': 'aeron',
#   'type': 'hardware',
#   'url': 'http://www.hermanmiller.com/Products/Aeron-Chairs'},
#  {'description': 'An ultra-wide fisheye lens.',
#   'name': 'AF DX Fisheye-Nikkor 10.5mm f/2.8G ED',
#   'title': 'af-dx-nikkor-10.5mm-f2.8g-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2148/AF-DX-Fisheye-NIKKOR-10.5mm-f%252F2.8G-ED.html'},
#  {'description': 'A camera lens.',
#   'name': 'AF Nikkor 14mm f/2.8D ED',
#   'title': 'af-nikkor-14mm-f2.8d-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1925/AF-NIKKOR-14mm-f%252F2.8D-ED.html'},
#  {'description': 'A camera lens.',
#   'name': 'AF Fisheye-Nikkor 16mm f/2.8D',
#   'title': 'af-nikkor-16mm-f2.8d',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1910/AF-Fisheye-NIKKOR-16mm-f%252F2.8D.html'},
#  {'description': 'A lens for SLR cameras.',
#   'name': 'AF NIKKOR 28mm f/2.8D',
#   'title': 'af-nikkor-28mm-f2.8d',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1922/AF-NIKKOR-28mm-f%252F2.8D.html'},
#  {'description': 'A camera lens.',
#   'name': 'AF NIKKOR 50mm f/1.4D',
#   'title': 'af-nikkor-50mm-f1.4d',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1902/AF-NIKKOR-50mm-f%252F1.4D.html'},
#  {'description': 'A lens for SLR cameras.',
#   'name': 'AF NIKKOR 50mm f/1.8D',
#   'title': 'af-nikkor-50mm-f1.8d',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2137/AF-NIKKOR-50mm-f%252F1.8D.html'},
#  {'description': 'A camera lens.',
#   'name': 'AF Nikkor 85mm f/1.8D',
#   'title': 'af-nikkor-85mm-f1.8d',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1931/AF-NIKKOR-85mm-f%252F1.8D.html'},
#  {'description': 'An ultra wide-angle zoom lens.',
#   'name': 'AF-S DX Zoom-Nikkor 12-24mm f/4G IF-ED',
#   'title': 'af-s-dx-nikkor-12-24mm-f4g-if-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2144/AF-S-DX-Zoom-NIKKOR-12-24mm-f%252F4G-IF-ED.html'},
#  {'description': 'A lens for DSLR cameras.',
#   'name': 'AF-S DX NIKKOR 18-200mm f/3.5-5.6G ED VR II',
#   'title': 'af-s-dx-nikkor-18-200mm-f3.5-5.6g-ed-vr-ii',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2192/AF-S-DX-NIKKOR-18-200mm-f%252F3.5-5.6G-ED-VR-II.html'},
#  {'description': 'A DSLR lens.',
#   'name': 'AF-S NIKKOR 16-35mm f/4G ED VR',
#   'title': 'af-s-nikkor-16-35mm-f4g-ed-vr',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2182/AF-S-NIKKOR-16-35mm-f%252F4G-ED-VR.html'},
#  {'description': 'A zoom lens.',
#   'name': 'AF-S VR Zoom-NIKKOR 24-120mm f/3.5-5.6G IF-ED',
#   'title': 'af-s-nikkor-24-120mm-f3.5-5.6g-if-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2145/AF-S-VR-Zoom-NIKKOR-24-120mm-f%252F3.5-5.6G-IF-ED.html'},
#  {'description': 'A wide-angel zoom lens.',
#   'name': 'AF-S NIKKOR 24-70mm f/2.8G ED',
#   'title': 'af-s-nikkor-24-70mm-f2.8g-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2164/AF-S-NIKKOR-24-70mm-f%252F2.8G-ED.html'},
#  {'description': 'A camera lens.',
#   'name': 'AF-S NIKKOR 24mm f/1.4G ED',
#   'title': 'af-s-nikkor-24mm-f1.4g-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/2184/AF-S-NIKKOR-24mm-f%252F1.4G-ED.html'},
#  {'description': 'An macro lens.',
#   'name': 'AF-S VR Micro-Nikkor 105mm f/2.8G IF-ED',
#   'title': 'af-vr-micro-nikkor-105mm-f-2.8g-if-ed',
#   'type': 'hardware',
#   'url': 'http://imaging.nikon.com/lineup/lens/specoalpurpose/micro/af-s_vr_micro-nikkor_105mmf_28_if/'},
#  {'description': 'A zoom lens.',
#   'name': 'AF VR Zoom-Nikkor 80-400mm f/4.5-5.6D ED',
#   'title': 'af-vr-nikkor-80-400mm-f4.5-5.6d-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Camera-Lenses/1996/AF-VR-Zoom-NIKKOR-80-400mm-f%252F4.5-5.6D-ED.html'},
#  {'description': 'A wide angle zoom lens.',
#   'name': 'AF Zoom-Nikkor 18-35mm f/3.5-4.5D IF-ED',
#   'title': 'af-zoom-nikkor-18-35mm-f3.5-4.5d-if-ed',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/en/Nikon-Products/Product-Archive/Camera-Lenses/1998/AF-Zoom-NIKKOR-18-35mm-f%252F3.5-4.5D-IF-ED.html'},
#  {'description': 'An HD handheld camcorder.',
#   'name': 'AG-HPX170',
#   'title': 'ag-hpx170',
#   'type': 'hardware',
#   'url': 'http://www.panasonic.com/business/provideo/AG-HPX170PJ.asp'},
#  {'description': 'An HD video camera.',
#   'name': 'AG-HVX200A',
#   'title': 'ag-hvx200a',
#   'type': 'hardware',
#   'url': 'http://catalog2.panasonic.com/webapp/wcs/stores/servlet/ModelDetail?storeId=11201&amp;catalogId=13051&amp;itemId=243668&amp;surfModel=AG-HVX200A'},
#  {'description': 'A USB modem.',
#   'name': 'AirCard 598',
#   'title': 'aircard-598',
#   'type': 'hardware',
#   'url': 'http://www.sierrawireless.com/en/productsandservices/AirCard/USBModems/aircard_usb598.aspx'},
#  {'description': 'A small wireless access point.',
#   'name': 'Airport Express',
#   'title': 'airport-express',
#   'type': 'hardware',
#   'url': 'http://www.apple.com/airportexpress/'},
#  {'description': 'A wireless access point.',
#   'name': 'Airport Extreme',
#   'title': 'airport-extreme',
#   'type': 'hardware',
#   'url': 'http://www.apple.com/airportextreme/'},
#  {'description': 'A super high-quality HD video camera.',
#   'name': 'Alexa',
#   'title': 'alexa',
#   'type': 'hardware',
#   'url': 'http://www.arri.com/camera/digital_cameras/cameras/camera_details.html?product=9'},
#  {'description': 'A bag.',
#   'name': 'Alpha flap',
#   'title': 'alpha-flap',
#   'type': 'hardware',
#   'url': 'http://www.tumi.com/product/index.jsp?productId=4210119'},
#  {'description': 'A laptop stands with a USB hub.',
#   'name': 'Alto Connect',
#   'title': 'alto-connect',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Logitech-Connect-Notebook-4-Port-Notebooks/dp/B00171377E'},
#  {'description': 'An iPad/iPhone stylus.',
#   'name': 'AluPen',
#   'title': 'alupen',
#   'type': 'hardware',
#   'url': 'http://www.just-mobile.com/ipad/alupen.html'},
#  {'description': 'A controller for Ableton Live.',
#   'name': 'APC20',
#   'title': 'apc20',
#   'type': 'hardware',
#   'url': 'http://www.akaipro.com/apc20'},
#  {'description': 'A knife sharpening system.',
#   'name': 'Apex Model Edge Pro System',
#   'title': 'apex-model-edge-pro-system',
#   'type': 'hardware',
#   'url': 'http://www.edgeproinc.com/Apex-Model-Edge-Pro-System-c3/'},
#  {'description': 'A Firewire/Thunderbolt audio interface.',
#   'name': 'Apollo',
#   'title': 'apollo',
#   'type': 'hardware',
#   'url': 'http://www.uaudio.com/interfaces/apollo.html'},
#  {'description': 'The media station device.',
#   'name': 'Apple TV',
#   'title': 'apple-tv',
#   'type': 'hardware',
#   'url': 'http://www.apple.com/appletv/'},
#  {'description': 'A set of powered speakers released with the PowerCD.',
#   'name': 'AppleDesign Powered Speakers',
#   'title': 'appledesign-powered-speakers',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/PowerCD#AppleDesign_Powered_Speakers'},
#  {'description': 'An audio device with two knobs.',
#   'name': 'arc',
#   'title': 'arc',
#   'type': 'hardware',
#   'url': 'http://monome.org/articles/2011/01/21/arc-details/'},
#  {'description': 'Open-source prototyping hardware.',
#   'name': 'Arduino',
#   'title': 'arduino',
#   'type': 'hardware',
#   'url': 'http://arduino.cc/'},
#  {'description': 'A souped-up gaming PC computer.',
#   'name': 'Alienware Area-51 Desktop',
#   'title': 'area-51',
#   'type': 'hardware',
#   'url': 'http://www.alienware.com/products/area-51-desktop.aspx'},
#  {'description': 'A set of scales with tracking.',
#   'name': 'Aria',
#   'title': 'aria',
#   'type': 'hardware',
#   'url': 'http://www.fitbit.com/product/aria/features'},
#  {'description': 'An electric guitar.',
#   'name': 'Classic S',
#   'title': 'asat-classic-s',
#   'type': 'hardware',
#   'url': 'http://www.glguitars.com/instruments/USA/customcreations/ASAT_Classic_S/index.asp'},
#  {'description': 'A 10.1 inch netbook computer.',
#   'name': 'Aspire One D250',
#   'title': 'aspire-one-d250',
#   'type': 'hardware',
#   'url': 'http://us.acer.com/acer/productv.do?LanguageISOCtxParam=en&kcond61e.c2att101=58051&sp=page16e&ctx2.c2att1=25&link=ln438e&CountryISOCtxParam=US&ctx1g.c2att92=843&ctx1.att21k=1&CRC=127634522'},
#  {'description': 'A small 8.9 inch PC laptop.',
#   'name': 'Aspire One ZG5',
#   'title': 'aspire-one-zg5',
#   'type': 'hardware',
#   'url': 'http://www.aspireoneuser.com/2008/11/20/review-acer-aspire-one-zg5/'},
#  {'description': "A 'nettop' PC.",
#   'name': 'Aspire Revo',
#   'title': 'aspire-revo',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Acer_Aspire_Revo'},
#  {'description': 'A USB digital microphone.',
#   'name': 'AT2020 Cardioid Condenser Microphone',
#   'title': 'at2020',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/wired_mics/c75c5918ed57a8d0/index.html'},
#  {'description': 'A condenser microphone.',
#   'name': 'AT4040',
#   'title': 'at4040',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/wired_mics/9b6aac05c5aca887/'},
#  {'description': 'A condenser microphone.',
#   'name': 'AT4050/CM5',
#   'title': 'at4050-cm5',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/wired_mics/0380b2cd58766334/index.html'},
#  {'description': 'Noise-cancelling headphones.',
#   'name': 'ATH-ANC7b QuietPoint Active',
#   'title': 'ath-anc7b',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/headphones/1c7efaa15727a938/index.html'},
#  {'description': 'Studio headphones.',
#   'name': 'ATH-M50',
#   'title': 'ath-m50',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/headphones/0edf909675b1be4d/index.html'},
#  {'description': 'A lathe.',
#   'name': 'ATL-618EVS',
#   'title': 'atl-618evs',
#   'type': 'hardware',
#   'url': 'http://www.acramachinery.com/Manual_Machines/ATL-618EVS.htm'},
#  {'description': "A traveller's backpack.",
#   'name': 'Atmos 50',
#   'title': 'atmos-50',
#   'type': 'hardware',
#   'url': 'http://www.ospreypacks.com/en/product/mens/atmos_50'},
#  {'description': 'Speakers.',
#   'name': 'Atom Monitor',
#   'title': 'atom-monitor',
#   'type': 'hardware',
#   'url': 'http://www.paradigm.com/en/paradigm/speaker_only-specification-1-1-2-4.paradigm'},
#  {'description': 'A hardware implementation of Auto-Tune.',
#   'name': 'ATR-1a',
#   'title': 'atr-1a',
#   'type': 'hardware',
#   'url': 'http://www.gearsource.com/catalog/stockItem/atr-1a-auto-tune-intonation-processor'},
#  {'description': 'An omnidirectional microphone.',
#   'name': 'ATR-3350',
#   'title': 'atr-3350',
#   'type': 'hardware',
#   'url': 'http://www.audio-technica.com/cms/wired_mics/9c6eca17168eef6f/index.html'},
#  {'description': 'A USB-based headset.',
#   'name': 'Audio 470 USB',
#   'title': 'audio-470-usb',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Plantronics-Foldable-USB-Optimized-470/dp/B000VVXO7E/'},
#  {'description': 'A high-end audio interface.',
#   'name': 'AUDIO KONTROL 1',
#   'title': 'audio-kontrol-1',
#   'type': 'hardware',
#   'url': 'http://native-instruments.com/?id=audiokontrol1'},
#  {'description': 'FireWire-based hardware device for recording audio.',
#   'name': 'AudioFire8',
#   'title': 'audiofire8',
#   'type': 'hardware',
#   'url': 'http://www.echoaudio.com/Products/FireWire/AudioFire8/'},
#  {'description': 'A set of scales.',
#   'name': 'AWS Scale',
#   'title': 'aws-scale',
#   'type': 'hardware',
#   'url': 'http://store.bluebottlecoffee.net/detail.bok?no=105'},
#  {'description': 'A USB MIDI controller.',
#   'name': 'Axiom 25',
#   'title': 'axiom-25',
#   'type': 'hardware',
#   'url': 'http://www.m-audio.com/products/en_us/Axiom25.html'},
#  {'description': 'A 49-key USB-based MIDI controller.',
#   'name': 'Axiom 49',
#   'title': 'axiom-49',
#   'type': 'hardware',
#   'url': 'http://www.m-audio.com/products/en_us/Axiom49.html'},
#  {'description': 'A USB MIDI controller.',
#   'name': 'Axiom 61',
#   'title': 'axiom-61',
#   'type': 'hardware',
#   'url': 'http://www.m-audio.com/products/en_us/Axiom61.html'},
#  {'description': 'A 49-Key USB MIDI controller.',
#   'name': 'Axiom Pro 49',
#   'title': 'axiom-pro-49',
#   'type': 'hardware',
#   'url': 'http://www.m-audio.com/products/en_us/AxiomPro49.html'},
#  {'description': 'A 22 inch LCD screen.',
#   'name': 'B2230',
#   'title': 'b2230',
#   'type': 'hardware',
#   'url': 'http://www.samsung.com/us/computer/monitors/LS22PUZKFVHZA'},
#  {'description': 'A guitar amp.',
#   'name': 'B25B',
#   'title': 'b25b',
#   'type': 'hardware',
#   'url': 'http://www.vintageguitaramplifiers.net/for-sale/vintage-ampeg-b25b-speaker-cabinet/18519/'},
#  {'description': 'Bags for the sides of the back wheel of a bike.',
#   'name': 'Back-Roller Classic',
#   'title': 'back-roller-classic',
#   'type': 'hardware',
#   'url': 'http://www.ortliebusa.com/prod-31.htm'},
#  {'description': 'Bags for the sides of the back wheel of a bike.',
#   'name': 'Back-Roller Plus',
#   'title': 'back-roller-plus',
#   'type': 'hardware',
#   'url': 'http://www.ortliebusa.com/CartGenie/prod-29.htm'},
#  {'description': 'A 650VA uninterruptable power supply unit.',
#   'name': 'Back-UPS Pro 650VA',
#   'title': 'back-ups-pro-650va',
#   'type': 'hardware',
#   'url': 'http://www.apc.com/resource/include/techspec_index.cfm?base_sku=BP650S'},
#  {'description': 'A microphone.',
#   'name': 'Ball',
#   'title': 'ball',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Blue-Microphones-Dynamic-Instrument-Microphone/dp/B0002F7FS8'},
#  {'description': 'Smaller pen/multi-touch tablets.',
#   'name': 'Bamboo',
#   'title': 'bamboo',
#   'type': 'hardware',
#   'url': 'http://wacom.com/bamboo/'},
#  {'description': 'A guitar amp.',
#   'name': 'Bass Terror 1000',
#   'title': 'bass-terror-1000',
#   'type': 'hardware',
#   'url': 'http://www.orangeamps.com/bass-terror-1000/'},
#  {'description': 'An electric guitar.',
#   'name': 'Bass VI',
#   'title': 'bass-vi',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Fender_Bass_VI'},
#  {'description': 'A USB protocol analyser.',
#   'name': 'Beagle USB 480',
#   'title': 'beagle-usb-480',
#   'type': 'hardware',
#   'url': 'http://www.totalphase.com/products/beagle_usb480/'},
#  {'description': 'An open development hardware board.',
#   'name': 'BeagleBoard',
#   'title': 'beagleboard',
#   'type': 'hardware',
#   'url': 'http://beagleboard.org/'},
#  {'description': 'An abrasive blaster system.',
#   'name': 'Benchtop Blaster',
#   'title': 'benchtop-blast',
#   'type': 'hardware',
#   'url': 'http://www.cycloneblasters.com/benchtop.htm'},
#  {'description': 'Swanky speakers.',
#   'name': 'BeoLab 4000',
#   'title': 'beolab-4000',
#   'type': 'hardware',
#   'url': 'http://www.bang-olufsen.com/beolab4000'},
#  {'description': 'A folding medium format camera.',
#   'name': 'Bessa',
#   'title': 'bessa',
#   'type': 'hardware',
#   'url': 'http://www.photoethnography.com/ClassicCameras/VoigtlanderBessa.html'},
#  {'description': 'A kick drum microphone.',
#   'name': 'Beta 52A',
#   'title': 'beta-52a',
#   'type': 'hardware',
#   'url': 'http://www.shure.com/americas/products/microphones/beta/beta-52a-kick-drum-microphone'},
#  {'description': 'A semiconductor microscope.',
#   'name': 'BHM-JL',
#   'title': 'bhm-jl',
#   'type': 'hardware',
#   'url': 'http://www.bmius.com/servlet/-strse-7334/Olympus-BHM-dsh-JL-6x6-inch/Detail'},
#  {'description': 'An audio control center.',
#   'name': 'Big Knob',
#   'title': 'big-knob',
#   'type': 'hardware',
#   'url': 'http://www.mackie.com/products/bigknob/'},
#  {'description': 'A guitar distortion pedal.',
#   'name': 'Big Muff',
#   'title': 'big-muff',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/Big_Muff'},
#  {'description': 'A bike.',
#   'name': 'Big Sky SLT',
#   'title': 'big-sky-slt',
#   'type': 'hardware',
#   'url': 'http://www.bikepedia.com/QuickBike/BikeSpecs.aspx?Year=2005&Brand=LeMond&Model=Big+Sky+SLT&Type=bike'},
#  {'description': 'A skin for the Apple Keyboard.',
#   'name': 'Black KB Covers cover (Apple Keyboard)',
#   'title': 'black-kbcover-apple-keyboard',
#   'type': 'hardware',
#   'url': 'http://www.kbcovers.com/servlet/Detail?no=99'},
#  {'description': 'A popular, discontinued pencil',
#   'name': 'Blackwing 602',
#   'title': 'blackwing-602',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/Blackwing_602'},
#  {'description': 'A pencil',
#   'name': 'Blackwing',
#   'title': 'blackwing',
#   'type': 'hardware',
#   'url': 'http://www.pencils.com/palomino-blackwing-12-pk'},
#  {'description': 'A hard drive dock for external drives.',
#   'name': 'BlacX',
#   'title': 'blacx',
#   'type': 'hardware',
#   'url': 'http://www.thermaltakeusa.com/Product.aspx?S=1268&ID=1642'},
#  {'description': 'A blood pressure monitor that connects to your iDevice.',
#   'name': 'Blood Pressure Monitor',
#   'title': 'blood-pressure-monitor',
#   'type': 'hardware',
#   'url': 'http://www.withings.com/en/bloodpressuremonitor'},
#  {'description': 'An iPhone case with a built-in sliding keyboard.',
#   'name': 'Bluetooth Sliding Keyboard Case',
#   'title': 'bluetooth-sliding-keyboard-case',
#   'type': 'hardware',
#   'url': 'http://www.thinkgeek.com/gadgets/cellphone/ea6d/'},
#  {'description': 'Studio speakers.',
#   'name': 'BM5A MKII',
#   'title': 'bm5a-mkii',
#   'type': 'hardware',
#   'url': 'http://dynaudioprofessional.com/bm-series/monitors/bm5a-mkii/'},
#  {'description': 'A laptop bag.',
#   'name': 'Boa squeeze',
#   'title': 'boa-squeeze',
#   'type': 'hardware',
#   'url': 'http://www.booqbags.com/us/backpacks/boa-squeeze/BSQ-BLR'},
#  {'description': 'A smartphone.',
#   'name': 'Bold',
#   'title': 'bold',
#   'type': 'hardware',
#   'url': 'http://worldwide.blackberry.com/blackberrybold/'},
#  {'description': 'An iPad docking station.',
#   'name': 'BookArc for iPad',
#   'title': 'bookarc-ipad',
#   'type': 'hardware',
#   'url': 'http://twelvesouth.com/products/bookarc_ipad/'},
#  {'description': 'A laptop case that looks like a book.',
#   'name': 'BookBook',
#   'title': 'bookbook',
#   'type': 'hardware',
#   'url': 'http://twelvesouth.com/products/bookbook/'},
#  {'description': 'A phrase sampler for guitars.',
#   'name': 'Boomerang III',
#   'title': 'boomerang-iii',
#   'type': 'hardware',
#   'url': 'http://www.boomerangmusic.com/Rang%20III.html'},
#  {'description': 'A connected device for watching your media.',
#   'name': 'Boxee Box',
#   'title': 'boxee-box',
#   'type': 'hardware',
#   'url': 'http://www.boxee.tv/buy/'},
#  {'description': 'An assistive computing device for the blind.',
#   'name': 'BrainPort V100',
#   'title': 'brainport-v100',
#   'type': 'hardware',
#   'url': 'http://www.wicab.com/en_us/'},
#  {'description': 'A USB oscilloscope.',
#   'name': 'BS100U',
#   'title': 'bs100u',
#   'type': 'hardware',
#   'url': 'http://www.brilldea.com/product_BS100U.html'},
#  {'description': 'A messager bag.',
#   'name': 'Buran',
#   'title': 'buran',
#   'type': 'hardware',
#   'url': 'https://www.chromebagsstore.com/bags/laptop-bags/buran.html'},
#  {'description': 'A USB display adapter.',
#   'name': 'BVU160',
#   'title': 'bvu160',
#   'type': 'hardware',
#   'url': 'http://www.diamondmm.com/BVU160.php'},
#  {'description': 'A recording microphone.',
#   'name': 'C 2000 B',
#   'title': 'c-2000-b',
#   'type': 'hardware',
#   'url': 'http://www.akg.com/site/products/powerslave,id,221,nodeid,2,_language,EN.html'},
#  {'description': 'A 6 megapixel digital compact camera.',
#   'name': 'C-LUX 1',
#   'title': 'c-lux-1',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Leica-Digital-Camera-Optical-Stabilized/dp/B000FAPQHM'},
#  {'description': 'A 7.2 megapixel digital camera.',
#   'name': 'C-LUX 2',
#   'title': 'c-lux-2',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Leica-Digital-Camera-Optical-Stabilized/dp/B000OCEKDM'},
#  {'description': 'A 10.1 megapixel camera.',
#   'name': 'C-LUX 3',
#   'title': 'c-lux-3',
#   'type': 'hardware',
#   'url': 'http://en.leica-camera.com/photography/compact_cameras/c-lux_3/'},
#  {'description': 'A studio condenser microphone.',
#   'name': 'C01U',
#   'title': 'c01u',
#   'type': 'hardware',
#   'url': 'http://www.samsontech.com/products/productpage.cfm?prodid=1810'},
#  {'description': 'A USB condenser microphone.',
#   'name': 'C03U',
#   'title': 'c03u',
#   'type': 'hardware',
#   'url': 'http://www.samsontech.com/products/productpage.cfm?prodID=1878'},
#  {'description': 'A hi-fi amplifier.',
#   'name': 'C325BEE',
#   'title': 'c325bee',
#   'type': 'hardware',
#   'url': 'http://nadelectronics.com/products/hifi-amplifiers/C325BEE-Stereo-Integrated-Amplifier'},
#  {'description': '2.0 computer speakers.',
#   'name': 'CA-2022R',
#   'title': 'ca-2022r',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Cyber-Acoustics-CA-2022-Computer-Speakers/dp/B00006B9W3'},
#  {'description': 'A mini audio mixer.',
#   'name': 'CAM-3',
#   'title': 'cam-3',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/AZDEN-CAM-3-On-Camcorder-Audio-Mixer/dp/B00006JPD1'},
#  {'description': 'A hand-cranked coffee mill.',
#   'name': 'Camano',
#   'title': 'camano',
#   'type': 'hardware',
#   'url': 'http://www.redroostertradingcompany.com/coffee.html'},
#  {'description': 'A film and negative scanner.',
#   'name': 'CanoScan 8800F',
#   'title': 'canoscan-8800f',
#   'type': 'hardware',
#   'url': 'http://www.usa.canon.com/consumer/controller?act=ModelInfoAct&fcategoryid=235&modelid=15561'},
#  {'description': 'A film and negatives scanner.',
#   'name': 'CanoScan 9000F',
#   'title': 'canoscan-9000f',
#   'type': 'hardware',
#   'url': 'http://usa.canon.com/cusa/consumer/products/scanners/film_negative_scanners/canoscan_9000f'},
#  {'description': 'A film and negative scanner.',
#   'name': 'CanoScan LiDE 700F',
#   'title': 'canoscan-lide-700f',
#   'type': 'hardware',
#   'url': 'http://www.usa.canon.com/cusa/consumer/products/scanners/film_negative_scanners/canoscan_lide_700f'},
#  {'description': 'A touch stylus.',
#   'name': 'Capacitive Stylus',
#   'title': 'capacitive-stylus',
#   'type': 'hardware',
#   'url': 'http://www.boxwave.com/stylus/capacitive-stylus/bwpds/tgz/'},
#  {'description': 'A gaming headset.',
#   'name': 'Carcharias',
#   'title': 'carcharias',
#   'type': 'hardware',
#   'url': 'http://store.razerzone.com/store/razerusa/en_US/pd/productID.169415800'},
#  {'description': 'A large laptop bag with many pockets.',
#   'name': 'Cargo bag',
#   'title': 'cargo-bag',
#   'type': 'hardware',
#   'url': 'http://www.sfbags.com/products/cargo/cargo.htm'},
#  {'description': 'An electric guitar.',
#   'name': 'Casino',
#   'title': 'casino',
#   'type': 'hardware',
#   'url': 'http://www.epiphone.com/products/electrics/archtop/casino.aspx'},
#  {'description': 'An internal hard disk for desktop machines.',
#   'name': 'Caviar Black',
#   'title': 'caviar-black',
#   'type': 'hardware',
#   'url': 'http://www.wdc.com/en/products/products.aspx?id=100'},
#  {'description': 'A CD turntable.',
#   'name': 'CDJ-1000',
#   'title': 'cdj-1000',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/CDJ#CDJ-1000'},
#  {'description': 'A coffee dripper.',
#   'name': 'Ceramic Dripper',
#   'title': 'ceramic-dripper',
#   'type': 'hardware',
#   'url': 'http://store.bluebottlecoffee.net/detail.bok?no=54'},
#  {'description': 'A guitar amp.',
#   'name': 'Champ',
#   'title': 'champ',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Fender_Champ'},
#  {'description': 'A multi-tool.',
#   'name': 'Charge TTi',
#   'title': 'charge-tti',
#   'type': 'hardware',
#   'url': 'http://www.leatherman.com/product/Charge_TTi'},
#  {'description': 'A coffee maker.',
#   'name': 'Chemex 6-cup',
#   'title': 'chemex-6-cup',
#   'type': 'hardware',
#   'url': 'http://www.williams-sonoma.com/products/chemex-6-cup-glass-coffee-maker/'},
#  {'description': 'A Japanese waterstone for sharpening knives.',
#   'name': 'Chosera',
#   'title': 'chosera',
#   'type': 'hardware',
#   'url': 'http://www.toolsforworkingwood.com/indextool.mvc?prodid=MS-CHOSERA.XX'},
#  {'description': 'A laptop built for only running Web apps.',
#   'name': 'Chromebook',
#   'title': 'chromebook',
#   'type': 'hardware',
#   'url': 'http://www.google.com/chromebook/'},
#  {'description': 'A little device that runs Flash applications.',
#   'name': 'Chumby',
#   'title': 'chumby',
#   'type': 'hardware',
#   'url': 'http://www.chumby.com/'},
#  {'description': 'The LCD display line.',
#   'name': 'Cinema Display',
#   'title': 'cinema-display',
#   'type': 'hardware',
#   'url': 'http://www.apple.com/displays/cinema/'},
#  {'description': 'The computer screen you can draw on.',
#   'name': 'Cintiq',
#   'title': 'cintiq',
#   'type': 'hardware',
#   'url': 'http://wacom.com/cintiq/'},
#  {'description': 'A fancy equaliser.',
#   'name': 'Clariphonic',
#   'title': 'clariphonic',
#   'type': 'hardware',
#   'url': 'http://www.kushaudio.com/kush/clariphonic/'},
#  {'description': 'A guitar amp.',
#   'name': 'Classic 30 112',
#   'title': 'classic-30-112',
#   'type': 'hardware',
#   'url': 'http://www.peavey.com/products/index.cfm/item/801/116335/'},
#  {'description': 'A guitar amp.',
#   'name': 'Classic 50',
#   'title': 'classic-50',
#   'type': 'hardware',
#   'url': 'http://www.peavey.com/products/instamplifiers/guitaramps/classic/index.cfm/item/116331/Classic%26reg%3B50%2F212.cfm'},
#  {'description': 'A guitar.',
#   'name': 'Classic S',
#   'title': 'classic-s',
#   'type': 'hardware',
#   'url': 'http://www.glguitars.com/instruments/USA/customcreations/ASAT_Classic_S/index.asp'},
#  {'description': 'Silicone-tipped tools for sculpting and modelling.',
#   'name': 'Clay Shapers',
#   'title': 'clay-shapers',
#   'type': 'hardware',
#   'url': 'http://www.sculpt.com/catalog_98/CLAYTOOLS/clayshapers.htm'},
#  {'description': 'Noise-cancelling headphones.',
#   'name': 'Clear Harmony',
#   'title': 'clear-harmony',
#   'type': 'hardware',
#   'url': 'http://www.ableplanet.com/catalog/product_info.php?products_id=136'},
#  {'description': 'Speakers.',
#   'name': 'CM5',
#   'title': 'cm5',
#   'type': 'hardware',
#   'url': 'http://www.bowers-wilkins.com/Speakers/Home_Audio/CM_Series/CM5.html'},
#  {'description': 'A microphone amplifier.',
#   'name': 'CMC 5 Ug',
#   'title': 'cmc-5-ug',
#   'type': 'hardware',
#   'url': 'http://schoeps.de/en/products/cmc5'},
#  {'description': 'A centrifugal magnetic finisher.',
#   'name': 'CMF-1200',
#   'title': 'cmf-1200',
#   'type': 'hardware',
#   'url': 'http://www.riogrande.com/Product/Raytech-CMF-1200-Centrifugal-Magnetic-Finisher/202184?pos=4'},
#  {'description': 'A bag.',
#   'name': 'Coated Canvas Shoulder Bag',
#   'title': 'coated-canvas-shoulder-bag',
#   'type': 'hardware',
#   'url': 'http://goincase.com/products/detail/coated-canvas-shoulder-bag-cl57592'},
#  {'description': 'A chair with a built-in sleeping bag.',
#   'name': 'Cocon',
#   'title': 'cocon',
#   'type': 'hardware',
#   'url': 'http://www.super-ette.com/produits/cocon.php?lang=en'},
#  {'description': 'Erasable coloured pencils.',
#   'name': 'Col-Erase',
#   'title': 'col-erase',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Prismacolor-Col-Erase-Erasable-Colored-24-Color/dp/B000089DCH'},
#  {'description': 'A laser printer.',
#   'name': 'Color LaserJet CP2025',
#   'title': 'color-laserjet-cp2025',
#   'type': 'hardware',
#   'url': 'http://reviews.cnet.com/laser-printers/hp-color-laserjet-cp2025/1707-3159_7-33946922.html'},
#  {'description': 'A colour calibration device.',
#   'name': 'ColorMunki Photo',
#   'title': 'colormunki-photo',
#   'type': 'hardware',
#   'url': 'http://www.xritephoto.com/ph_product_overview.aspx?id=1115'},
#  {'description': 'A laser reflectometer for coffee beans.',
#   'name': 'ColorTrack',
#   'title': 'colortrack',
#   'type': 'hardware',
#   'url': 'http://www.coffeelabequipment.com/COLORTRACK.html'},
#  {'description': 'An electric guitar.',
#   'name': 'Comanche',
#   'title': 'comanche',
#   'type': 'hardware',
#   'url': 'http://www.glguitars.com/instruments/USA/guitars/comanche/index.asp'},
#  {'description': 'An 8-bit computer.',
#   'name': 'Commodore 128',
#   'title': 'commodore-128',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/Commodore_128'},
#  {'description': 'A very popular old 8-bit computer.',
#   'name': 'Commodore 64',
#   'title': 'commodore-64',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Commodore_64'},
#  {'description': 'Three-piece stereo speakers for computers.',
#   'name': 'Companion 3',
#   'title': 'companion-3',
#   'type': 'hardware',
#   'url': 'http://www.bose.com/controller?url=/shop_online/speakers/computer_speakers/companion_3/index.jsp'},
#  {'description': 'Three-piece 5.1 stereo speakers for computers.',
#   'name': 'Companion 5',
#   'title': 'companion-5',
#   'type': 'hardware',
#   'url': 'http://www.bose.com/controller?url=/shop_online/digital_music_systems/computer_speakers/companion_5/index.jsp'},
#  {'description': 'A 12.1 inch PC laptop.',
#   'name': 'Compaq 2510p',
#   'title': 'compaq-2510p',
#   'type': 'hardware',
#   'url': 'http://h18000.www1.hp.com/products/quickspecs/12717_div/12717_div.HTML'},
#  {'description': 'A 14.1 inch PC laptop.',
#   'name': 'Compaq 6535b',
#   'title': 'compaq-6535b',
#   'type': 'hardware',
#   'url': 'http://www.lapspecs.com/detail/HP-Compaq+6535b'},
#  {'description': 'A USB device for EVDO access.',
#   'name': 'Compass 597 EVDO',
#   'title': 'compass-597',
#   'type': 'hardware',
#   'url': 'http://www.sierrawireless.com/product/compass_597.aspx'},
#  {'description': 'A backpack designed for photographers.',
#   'name': 'CompuPrimus AW',
#   'title': 'compuprimus-aw',
#   'type': 'hardware',
#   'url': 'http://products.lowepro.com/product/CompuPrimus-AW,2110,19.htm'},
#  {'description': 'A fancy piano.',
#   'name': 'Concert Grand Model D',
#   'title': 'concert-grand-model-d',
#   'type': 'hardware',
#   'url': 'http://www.steinway.com/pianos/steinway/grand/model-d/'},
#  {'description': 'An SD card that can upload to photo sites for you.',
#   'name': 'Connect X2',
#   'title': 'connect-x2',
#   'type': 'hardware',
#   'url': 'http://www.eye.fi/products/connectx2'},
#  {'description': 'An audio streaming system.',
#   'name': 'Connect',
#   'title': 'connect.2',
#   'type': 'hardware',
#   'url': 'http://www.sonos.com/shop/products/connect'},
#  {'description': 'A compact film camera.',
#   'name': 'Contax T2',
#   'title': 'contax-t2',
#   'type': 'hardware',
#   'url': 'http://en.wikipedia.org/wiki/Contax#Contax_T-series_compact_cameras'},
#  {'description': 'A 16 megapixel rugged digital camera.',
#   'name': 'COOLPIX AW100',
#   'title': 'coolpix-aw100',
#   'type': 'hardware',
#   'url': 'http://www.nikonusa.com/Nikon-Products/Product/Compact-Digital-Cameras/26293/COOLPIX-AW100.html'},
#  {'description': 'A gaming mouse.',
#   'name': 'Copperhead',
#   'title': 'copperhead',
#   'type': 'hardware',
#   'url': 'http://store.razerzone.com/store/razerusa/en_US/pd/productID.169415900'},
#  {'description': 'A wide-grip stylus.',
#   'name': 'Cosmonaut',
#   'title': 'cosmonaut',
#   'type': 'hardware',
#   'url': 'http://www.studioneat.com/products/cosmonaut'},
#  {'description': 'A fountain pen.',
#   'name': 'cp 1',
#   'title': 'cp-1',
#   'type': 'hardware',
#   'url': 'http://www.lamy.com/eng/b2c/cp_1/056'},
#  {'description': 'An old stereo receiver.',
#   'name': 'CR-1020',
#   'title': 'cr-1020',
#   'type': 'hardware',
#   'url': 'http://www.vintageaudioonline.com/yamaha-cr-1020-receiver/'},
#  {'description': "Google's first Chrome OS netbook.",
#   'name': 'Cr-48',
#   'title': 'cr-48',
#   'type': 'hardware',
#   'url': 'http://www.google.com/chromeos/pilot-program-cr48.html'},
#  {'description': 'A ballpoint pen.',
#   'name': 'Cristal',
#   'title': 'cristal',
#   'type': 'hardware',
#   'url': 'https://en.wikipedia.org/wiki/Bic_Cristal'},
#  {'description': 'A bike.',
#   'name': 'Cross Check Complete',
#   'title': 'cross-check-complete',
#   'type': 'hardware',
#   'url': 'http://www.surlybikes.com/bikes/cross_check_complete/'},
#  {'description': 'A portable USB flash drive.',
#   'name': 'Cruzer',
#   'title': 'cruzer',
#   'type': 'hardware',
#   'url': 'http://www.sandisk.com/Products/ProductDetails.aspx?productID=&CatID=1437'},
#  {'description': 'A four-channel mixer.',
#   'name': 'CS 104',
#   'title': 'cs-104',
#   'type': 'hardware',
#   'url': 'http://www.coopersound.com/cs104.htm'},
#  {'description': 'A boundary microphone.',
#   'name': 'CUB-01',
#   'title': 'cub-01',
#   'type': 'hardware',
#   'url': 'http://www.sanken-mic.com/en/product/product.cfm/1.1005000'},
#  {'description': 'A laptop lap stand.',
#   'name': 'CushTop',
#   'title': 'cushtop',
#   'type': 'hardware',
#   'url': 'http://www.amazon.com/Belkin-F8N044-ORG-CushTop-Notebook-Stand/dp/B000J4MOU6'},
#  {'description': 'A bike bag.',
#   'name': 'Custom Citizen',
#   'title': 'custom-citizen',
#   'type': 'hardware',
#   'url': 'http://www.chromebagsstore.com/bags/messenger-bags/custom-citizen.html'},
#  {'description': 'A keyboard in the style of the old Model M keyboards.',
#   'name': 'Customizer 104/105',
#   'title': 'customizer-104-105',
#   'type': 'hardware',
#   'url': 'http://pckeyboards.stores.yahoo.net/customizer.html'},
#  {'description': 'In-ear headphones.',
#   'name': 'CX 300-II',
#   'title': 'cx-300-ii',
#   'type': 'hardware',
#   'url': 'http://www.sennheiser.com/sennheiser/home_en.nsf/root/private_headphones_classic-line_cxseries-in-ear-earphones-cx-300-ii'},
# ...
#   'url': 'http://www.winamp.com/'},
#  {'description': 'Development tools for the AVR microprocessor family.',
#   'name': 'WinAVR',
#   'title': 'winavr',
#   'type': 'software',
#   'url': 'http://winavr.sourceforge.net/'},
#  {'description': "An X window manager inspired by NeXTStep's interface.",
#   'name': 'Window Maker',
#   'title': 'window-maker',
#   'type': 'software',
#   'url': 'http://windowmaker.org/'},
#  {'description': 'The upcoming revision of Windows.',
#   'name': 'Windows 7',
#   'title': 'windows-7',
#   'type': 'software',
#   'url': 'http://microsoft.com/windows/windows-7/'},
#  {'description': 'An operating system for PC and tablet computers.',
#   'name': 'Windows 8',
#   'title': 'windows-8',
#   'type': 'software',
#   'url': 'https://en.wikipedia.org/wiki/Windows_8'},
#  {'description': 'A PC operating system.',
#   'name': 'Windows 98',
#   'title': 'windows-98',
#   'type': 'software',
#   'url': 'https://en.wikipedia.org/wiki/Windows_98'},
#  {'description': 'A chat client for MSN.',
#   'name': 'Windows Live Messenger',
#   'title': 'windows-live-messenger',
#   'type': 'software',
#   'url': 'http://explore.live.com/windows-live-messenger'},
#  {'description': 'Audio/media jukebox software.',
#   'name': 'Windows Media Player',
#   'title': 'windows-media-player',
#   'type': 'software',
#   'url': 'http://www.microsoft.com/windows/windowsmedia/player/default.aspx'},
#  {'description': "Microsoft's mobile operating system.",
#   'name': 'Windows Phone',
#   'title': 'windows-phone',
#   'type': 'software',
#   'url': 'http://www.microsoft.com/windowsphone/en-us/default.aspx'},
#  {'description': 'A somewhat unpopular OS for x86 computers.',
#   'name': 'Windows Vista',
#   'title': 'windows-vista',
#   'type': 'software',
#   'url': 'http://microsoft.com/windows/windows-vista/'},
#  {'description': 'An operating system for x86 computers.',
#   'name': 'Windows XP',
#   'title': 'windows-xp',
#   'type': 'software',
#   'url': 'http://microsoft.com/windows/windows-xp/'},
#  {'description': 'A Mac haxie to customise window minimising.',
#   'name': 'Windowshade X',
#   'title': 'windowshade-x',
#   'type': 'software',
#   'url': 'http://unsanity.com/haxies/wsx'},
#  {'description': 'File compression software for Windows.',
#   'name': 'WinRAR',
#   'title': 'winrar',
#   'type': 'software',
#   'url': 'http://www.rarlab.com/'},
#  {'description': 'A free S/FTP and SCP client for Windows.',
#   'name': 'WinSCP',
#   'title': 'winscp',
#   'type': 'software',
#   'url': 'http://winscp.net/eng/index.php'},
#  {'description': 'File compression and encryption software for Windows.',
#   'name': 'WinZip',
#   'title': 'winzip',
#   'type': 'software',
#   'url': 'http://www.winzip.com/'},
#  {'description': 'The magazine as an app.',
#   'name': 'WIRED (iOS)',
#   'title': 'wired-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/wired-magazine/id373903654'},
#  {'description': 'A network protocol analyser.',
#   'name': 'Wireshark',
#   'title': 'wireshark',
#   'type': 'software',
#   'url': 'http://www.wireshark.org/'},
#  {'description': 'A personal metrics app for Withings products.',
#   'name': 'WiScale (iOS)',
#   'title': 'wiscale-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/wiscale/id319085928'},
#  {'description': 'An online knowledge engine.',
#   'name': 'Wolfram Alpha',
#   'title': 'wolfram-alpha',
#   'type': 'software',
#   'url': 'http://www.wolframalpha.com/'},
#  {'description': 'An experimental audio generating web tool.',
#   'name': 'Wolfram Tones',
#   'title': 'wolfram-tones',
#   'type': 'software',
#   'url': 'http://tones.wolfram.com/'},
#  {'description': 'A popular document editor.',
#   'name': 'MS Word',
#   'title': 'word',
#   'type': 'software',
#   'url': 'http://office.microsoft.com/en-us/word/'},
#  {'description': 'An iPhone app for creating, editing and managing WordPress posts and comments.',
#   'name': 'WordPress (iOS)',
#   'title': 'wordpress-ios',
#   'type': 'software',
#   'url': 'http://iphone.wordpress.org/'},
#  {'description': 'A multi-weblog, self-hosted publishing tool.',
#   'name': 'Wordpress MU',
#   'title': 'wordpress-mu',
#   'type': 'software',
#   'url': 'http://mu.wordpress.org/'},
#  {'description': 'Weblog publishing software.',
#   'name': 'Wordpress',
#   'title': 'wordpress',
#   'type': 'software',
#   'url': 'http://wordpress.com/'},
#  {'description': 'A word game for the iPhone.',
#   'name': 'Words With Friends (iOS)',
#   'title': 'words-with-friends-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/words-with-friends/id322852954'},
#  {'description': 'Engineering simulation software.',
#   'name': 'Workbench',
#   'title': 'workbench',
#   'type': 'software',
#   'url': 'http://www.ansys.com/Products/Workflow+Technology/ANSYS+Workbench+Platform'},
#  {'description': 'Windows software reminding you to take regular breaks.',
#   'name': 'Workrave',
#   'title': 'workrave',
#   'type': 'software',
#   'url': 'http://www.workrave.org/'},
#  {'description': 'A physics-based game.',
#   'name': 'World of Goo (iOS)',
#   'title': 'world-of-goo-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/world-of-goo-hd/id401301276'},
#  {'description': 'Virtual telescope software.',
#   'name': 'Worldwide Telescope',
#   'title': 'worldwide-telescope',
#   'type': 'software',
#   'url': 'http://www.worldwidetelescope.org/Home.aspx'},
#  {'description': 'A slightly popular fantasy MMORPG.',
#   'name': 'World of Warcraft',
#   'title': 'wow',
#   'type': 'software',
#   'url': 'http://www.worldofwarcraft.com/'},
#  {'description': 'Web-based sharable text document.',
#   'name': 'Writeboard',
#   'title': 'writeboard',
#   'type': 'software',
#   'url': 'http://writeboard.com/'},
#  {'description': 'A distraction-free writing app for the iPhone.',
#   'name': 'WriteRoom (iOS)',
#   'title': 'writeroom-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/writeroom/id288751446?mt=8'},
#  {'description': 'Full-screen writing software.',
#   'name': 'WriteRoom',
#   'title': 'writeroom',
#   'type': 'software',
#   'url': 'http://www.hogbaysoftware.com/products/writeroom'},
#  {'description': 'A Markdown-based text editor for iOS.',
#   'name': 'Writing Kit (iOS)',
#   'title': 'writing-kit-ios',
#   'type': 'software',
#   'url': 'http://getwritingkit.com/'},
#  {'description': 'FTP software for Windows.',
#   'name': 'WS_FTP Professional',
#   'title': 'ws-ftp-pro',
#   'type': 'software',
#   'url': 'http://www.ipswitchft.com/products/ws_ftp_pro/'},
#  {'description': 'A cloud-syncing to-do manager.',
#   'name': 'Wunderlist',
#   'title': 'wunderlist',
#   'type': 'software',
#   'url': 'http://www.6wunderkinder.com/wunderlist/'},
#  {'description': 'A word game for the iPhone.',
#   'name': 'wurdle (iOS)',
#   'title': 'wurdle-ios',
#   'type': 'software',
#   'url': 'http://www.semisecretsoftware.com/wurdle/'},
#  {'description': 'A GUI for designing wxWidgets apps.',
#   'name': 'wxFormBuilder',
#   'title': 'wxformbuilder',
#   'type': 'software',
#   'url': 'http://wxformbuilder.org/'},
#  {'description': 'Python bindings for wxWidgets.',
#   'name': 'wxPython',
#   'title': 'wxpython',
#   'type': 'software',
#   'url': 'http://www.wxpython.org/'},
#  {'description': 'A cross-platform GUI library.',
#   'name': 'wxWidgets',
#   'title': 'wxwidgets',
#   'type': 'software',
#   'url': 'http://www.wxwidgets.org/'},
#  {'description': 'An OS X version of the IRC client.',
#   'name': 'X-Chat Aqua',
#   'title': 'x-chat-aqua',
#   'type': 'software',
#   'url': 'http://sourceforge.net/projects/xchataqua/'},
#  {'description': 'A weblog platform.',
#   'name': 'Xanga',
#   'title': 'xanga',
#   'type': 'software',
#   'url': 'http://www.xanga.com/'},
#  {'description': 'A command-line tool to execute commands from standard input.',
#   'name': 'xargs',
#   'title': 'xargs',
#   'type': 'software',
#   'url': 'http://en.wikipedia.org/wiki/Xargs'},
#  {'description': 'A keyboard/mouse launcher tool for X11.',
#   'name': 'xbindkeys',
#   'title': 'xbindkeys',
#   'type': 'software',
#   'url': 'http://www.nongnu.org/xbindkeys/xbindkeys.html'},
#  {'description': 'Media center software.',
#   'name': 'XBMC',
#   'title': 'xbmc',
#   'type': 'software',
#   'url': 'http://xbmc.org/'},
#  {'description': 'An online service for the Xbox 360.',
#   'name': 'Xbox Live',
#   'title': 'xbox-live',
#   'type': 'software',
#   'url': 'http://www.xbox.com/en-US/live'},
#  {'description': 'A cross-platform IRC client.',
#   'name': 'XChat',
#   'title': 'xchat',
#   'type': 'software',
#   'url': 'http://www.xchat.org/'},
#  {'description': 'An IDE for Mac developers.',
#   'name': 'XCode',
#   'title': 'xcode',
#   'type': 'software',
#   'url': 'http://developer.apple.com/technology/tools.html'},
#  {'description': 'A version of Emacs.',
#   'name': 'XEmacs',
#   'title': 'xemacs',
#   'type': 'software',
#   'url': 'http://www.xemacs.org/'},
#  {'description': 'Virtualisation software.',
#   'name': 'Xen',
#   'title': 'xen',
#   'type': 'software',
#   'url': 'http://xen.org/'},
#  {'description': 'A lightweight UNIX-like desktop environment.',
#   'name': 'XFCE',
#   'title': 'xfce',
#   'type': 'software',
#   'url': 'http://www.xfce.org/'},
#  {'description': 'An open-source window system.',
#   'name': 'XFree86',
#   'title': 'xfree86',
#   'type': 'software',
#   'url': 'http://www.xfree86.org/'},
#  {'description': 'Distributed protocol/software.',
#   'name': 'XGrid',
#   'title': 'xgrid',
#   'type': 'software',
#   'url': 'https://en.wikipedia.org/wiki/Xgrid'},
#  {'description': 'A bookmark syncing service.',
#   'name': 'Xmarks',
#   'title': 'xmarks',
#   'type': 'software',
#   'url': 'http://www.xmarks.com/'},
#  {'description': 'An R package for working with XML.',
#   'name': 'XML',
#   'title': 'xml',
#   'type': 'software',
#   'url': 'http://cran.r-project.org/web/packages/XML/'},
#  {'description': 'A tiling window manager for X11.',
#   'name': 'xmonad',
#   'title': 'xmonad',
#   'type': 'software',
#   'url': 'http://xmonad.org/'},
#  {'description': 'A 3D displacement map generator.',
#   'name': 'XNormal',
#   'title': 'xnormal',
#   'type': 'software',
#   'url': 'http://www.xnormal.net/'},
#  {'description': 'A sketching and note-taking application for stylus-based computers.',
#   'name': 'Xournal',
#   'title': 'xournal',
#   'type': 'software',
#   'url': 'http://xournal.sourceforge.net/'},
#  {'description': 'A flexible notepad for the Mac.',
#   'name': 'xPad',
#   'title': 'xpad',
#   'type': 'software',
#   'url': 'http://www.getxpad.com/'},
#  {'description': 'An open source PDF viewer.',
#   'name': 'Xpdf',
#   'title': 'xpdf',
#   'type': 'software',
#   'url': 'http://foolabs.com/xpdf/about.html'},
#  {'description': 'A Mac tool for on-screen measuring and aligning.',
#   'name': 'xScope',
#   'title': 'xscope',
#   'type': 'software',
#   'url': 'http://iconfactory.com/software/xscope'},
#  {'description': 'Terminal software for the X Window System.',
#   'name': 'xterm',
#   'title': 'xterm',
#   'type': 'software',
#   'url': 'http://en.wikipedia.org/wiki/Xterm'},
#  {'description': 'A lightweight version of the Ubuntu distribution.',
#   'name': 'Xubuntu',
#   'title': 'xubuntu',
#   'type': 'software',
#   'url': 'http://xubuntu.com/'},
#  {'description': 'An old word processor for DOS and Windows.',
#   'name': 'XyWrite',
#   'title': 'xywrite',
#   'type': 'software',
#   'url': 'http://en.wikipedia.org/wiki/XyWrite'},
#  {'description': 'A service for mixing up web content.',
#   'name': 'Yahoo! Pipes',
#   'title': 'yahoo-pipes',
#   'type': 'software',
#   'url': 'http://pipes.yahoo.com/'},
#  {'description': 'An enterprise messaging platform.',
#   'name': 'Yammer',
#   'title': 'yammer',
#   'type': 'software',
#   'url': 'https://www.yammer.com/'},
#  {'description': 'An iPhone app for accessing Yelp reviews.',
#   'name': 'Yelp (iOS)',
#   'title': 'yelp-ios',
#   'type': 'software',
#   'url': 'http://phobos.apple.com/WebObjects/MZStore.woa/wa/viewSoftware?id=284910350&mt=8'},
#  {'description': 'A Mac application for storing your PDF documents.',
#   'name': 'Yep',
#   'title': 'yep',
#   'type': 'software',
#   'url': 'http://yepthat.com/yep/'},
#  {'description': "Data 'bucket' software for the Mac.",
#   'name': 'Yojimbo',
#   'title': 'yojimbo',
#   'type': 'software',
#   'url': 'http://barebones.com/products/Yojimbo/'},
#  {'description': 'A Twitter client for the Mac.',
#   'name': 'YoruFukurou',
#   'title': 'yorufukurou',
#   'type': 'software',
#   'url': 'http://sites.google.com/site/yorufukurou/'},
#  {'description': 'An iPhone app that will call your elected favourite contact.',
#   'name': "You're #1 (iOS)",
#   'title': 'youre-number-one-ios',
#   'type': 'software',
#   'url': 'http://www.utilitouch.com/app/you-are-number-1/index.html'},
#  {'description': 'A profiler system for Java and .NET.',
#   'name': 'YourKit',
#   'title': 'yourkit',
#   'type': 'software',
#   'url': 'http://www.yourkit.com/'},
#  {'description': 'A command-line tool for downloading videos from YouTube etc.',
#   'name': 'youtube-dl',
#   'title': 'youtube-dl',
#   'type': 'software',
#   'url': 'http://rg3.github.com/youtube-dl/'},
#  {'description': "A web site for watching 80's TV commercials and bad mashups.",
#   'name': 'YouTube',
#   'title': 'youtube',
#   'type': 'software',
#   'url': 'http://youtube.com/'},
#  {'description': 'A static site generator.',
#   'name': 'yst',
#   'title': 'yst',
#   'type': 'software',
#   'url': 'https://github.com/jgm/yst'},
#  {'description': 'A Windows word processor.',
#   'name': 'yWriter',
#   'title': 'ywriter',
#   'type': 'software',
#   'url': 'http://www.spacejock.com/yWriter5.html'},
#  {'description': 'Analog-style synthesizer software.',
#   'name': 'Z3TA+',
#   'title': 'z3ta',
#   'type': 'software',
#   'url': 'http://www.cakewalk.com/Products/Z3TA/Default.asp'},
#  {'description': '3D digital painting and sculpture software.',
#   'name': 'ZBrush',
#   'title': 'zbrush',
#   'type': 'software',
#   'url': 'http://www.pixologic.com/zbrush/'},
#  {'description': 'A modular synthesiser.',
#   'name': 'Zebra',
#   'title': 'zebra',
#   'type': 'software',
#   'url': 'http://www.u-he.com/zebra/'},
#  {'description': 'Distraction-free writing software for Windows.',
#   'name': 'ZenWriter',
#   'title': 'zenwriter',
#   'type': 'software',
#   'url': 'http://www.beenokle.com/zenwriter.html'},
#  {'description': 'A .NET resource editor.',
#   'name': 'Zeta Resource Editor',
#   'title': 'zeta-resource-editor',
#   'type': 'software',
#   'url': 'http://www.zeta-resource-editor.com/index.html'},
#  {'description': "A developer's text editor.",
#   'name': 'ZeusEdit',
#   'title': 'zeusedit',
#   'type': 'software',
#   'url': 'http://www.zeusedit.com/'},
#  {'description': 'An integrated mail, calendar, contact and document solution.',
#   'name': 'Zimbra',
#   'title': 'zimbra',
#   'type': 'software',
#   'url': 'http://www.zimbra.com/'},
#  {'description': 'A personal magazine app.',
#   'name': 'Zite (iOS)',
#   'title': 'zite-ios',
#   'type': 'software',
#   'url': 'http://itunes.apple.com/us/app/zite-personalized-magazine/id419752338'},
#  {'description': 'An IRC bouncer.',
#   'name': 'znc',
#   'title': 'znc',
#   'type': 'software',
#   'url': 'https://github.com/technomancy/znc'},
#  {'description': 'A Mac app to play interactive fiction.',
#   'name': 'Zoom',
#   'title': 'zoom',
#   'type': 'software',
#   'url': 'http://www.logicalshift.demon.co.uk/mac/zoom.html'},
#  {'description': 'A window resizer/mover tool for the Mac.',
#   'name': 'Zooom',
#   'title': 'zooom',
#   'type': 'software',
#   'url': 'http://coderage-software.com/zooom/'},
#  {'description': 'A visual bookmarking service.',
#   'name': 'Zootool',
#   'title': 'zootool',
#   'type': 'software',
#   'url': 'http://zootool.com/'},
#  {'description': 'A Python-based web application framework.',
#   'name': 'Zope',
#   'title': 'zope',
#   'type': 'software',
#   'url': 'http://zope.org/'},
#  {'description': 'A research tool.',
#   'name': 'Zotero',
#   'title': 'zotero',
#   'type': 'software',
#   'url': 'http://www.zotero.org/'},
#  {'description': 'An interactive shell and scripting language.',
#   'name': 'zsh',
#   'title': 'zsh',
#   'type': 'software',
#   'url': 'http://www.zsh.org/'},
#  {'description': 'A service to share your media via the cloud.',
#   'name': 'ZumoDrive',
#   'title': 'zumodrive',
#   'type': 'software',
#   'url': 'http://www.zumodrive.com/'},
#  {'description': 'A 2D sprite-packing tool.',
#   'name': 'Zwoptex',
#   'title': 'zwoptex',
#   'type': 'software',
#   'url': 'http://zwoptexapp.com/'}]

# %%
len(ware)
# Out:
# 3326

# %%
len(hardware)
# Out:
# 1373

# %%
len(software)
# Out:
# 1953

# %%
1953+1373
# Out:
# 3326

# %%
extracted_ware = pd.DataFrame(ware)

# %%
extracted_ware
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3326 entries, 0 to 3325
# Data columns (total 5 columns):
# description    3326  non-null values
# name           3326  non-null values
# title          3326  non-null values
# type           3326  non-null values
# url            3326  non-null values
# dtypes: object(5)

# %%
extracted_ware[:20]
# Out:
#                                           description                        name                       title      type                                                url
# 0                            A very powerful scanner.                     10000XL                     10000xl  hardware  http://www.epson.com/cgi-bin/Store/jsp/Product...
# 1                                       Old speakers.                       104aB                       104ab  hardware  http://www.kef.com/html/us/explore/about_kef/m...
# 2                                        A subwoofer.                         10S                         10s  hardware  http://www.shopping.com/KRK-KRK-10S-Subwoofer/...
# 3                              A macro lens for SLRs.      10x High Definition II      10x-high-definition-ii  hardware                         http://opteka.com/10x.aspx
# 4                                            A chair.                    111 Navy                    111-navy  hardware     http://www.emeco.net/product/111navychair.html
# 5                               A basic mobile phone.                        1208                        1208  hardware  http://mobile.softpedia.com/phones/Nokia/Nokia...
# 6                                       A mic preamp.                       12AY7                       12ay7  hardware          http://www.ehx.com/products/12ay7-mic-pre
# 7                                      A fancy watch.                  150 Series                  150-series  hardware  http://www.uniformwares.com/150-series-pvd-ros...
# 8   A solid camera case that meets airline standar...          1510 Carry On Case          1510-carry-on-case  hardware  http://www.pelican.com/cases_detail.php?Case=1510
# 9                                  A DC power supply.                       1621A                       1621a  hardware  http://www.bkprecision.com/products/power-supp...
# 10                             A 19 inch LCD monitor.                      1905FP                      1905fp  hardware  http://support.dell.com/support/edocs/monitors...
# 11                                   A 7x zoom loupe.        #1975 Scale Loupe 7x         1975-scale-loupe-7x  hardware  http://www.peakoptics.com/index.php?main_page=...
# 12  A KVM for sharing monitors, PS/2 mice and keyb...             2-port PS/2 KVM             2-port-ps-2-kvm  hardware  http://www.belkin.com/IWCatProductPage.process...
# 13                              A cordless presenter.  2.4 GHz Cordless Presenter  2.4-ghz-cordless-presenter  hardware  http://www.amazon.com/Logitech-2-4-Cordless-Pr...
# 14                            Field monitor speakers.                       20-20                       20-20  hardware  http://reviews.cnet.com/separate-speakers/even...
# 15                              A digital multimeter.                    2000 DMM                    2000-dmm  hardware  http://www.keithley.com/products/dcac/dmm/broa...
# 16                                    A fountain pen.                        2000                        2000  hardware  http://www.lamyusa.com/lamy_fountain_L01_2000.php
# 17                            A 20.1 inch LCD screen.                      2001FP                      2001fp  hardware  http://accessories.us.dell.com/sna/PopupProduc...
# 18                             A 20 inch LCD monitor.           UltraSharp 2007fp                      2007fp  hardware  http://accessories.us.dell.com/sna/products/Di...
# 19                      An industrial sewing machine.                     206RB-5                     206rb-5  hardware    http://www.consew.com/View/Consew-Model-206RB-5

# %%
extracted_ware[-20:]
# Out:
#                                             description                  name                 title      type                                                url
# 3306  A web site for watching 80's TV commercials an...               YouTube               youtube  software                                http://youtube.com/
# 3307                           A static site generator.                   yst                   yst  software                         https://github.com/jgm/yst
# 3308                          A Windows word processor.               yWriter               ywriter  software             http://www.spacejock.com/yWriter5.html
# 3309                 Analog-style synthesizer software.                 Z3TA+                  z3ta  software  http://www.cakewalk.com/Products/Z3TA/Default.asp
# 3310        3D digital painting and sculpture software.                ZBrush                zbrush  software                   http://www.pixologic.com/zbrush/
# 3311                             A modular synthesiser.                 Zebra                 zebra  software                         http://www.u-he.com/zebra/
# 3312     Distraction-free writing software for Windows.             ZenWriter             zenwriter  software             http://www.beenokle.com/zenwriter.html
# 3313                            A .NET resource editor.  Zeta Resource Editor  zeta-resource-editor  software     http://www.zeta-resource-editor.com/index.html
# 3314                         A developer's text editor.              ZeusEdit              zeusedit  software                           http://www.zeusedit.com/
# 3315  An integrated mail, calendar, contact and docu...                Zimbra                zimbra  software                             http://www.zimbra.com/
# 3316                           A personal magazine app.            Zite (iOS)              zite-ios  software  http://itunes.apple.com/us/app/zite-personaliz...
# 3317                                    An IRC bouncer.                   znc                   znc  software                 https://github.com/technomancy/znc
# 3318             A Mac app to play interactive fiction.                  Zoom                  zoom  software  http://www.logicalshift.demon.co.uk/mac/zoom.html
# 3319           A window resizer/mover tool for the Mac.                 Zooom                 zooom  software                http://coderage-software.com/zooom/
# 3320                      A visual bookmarking service.               Zootool               zootool  software                                http://zootool.com/
# 3321          A Python-based web application framework.                  Zope                  zope  software                                   http://zope.org/
# 3322                                   A research tool.                Zotero                zotero  software                             http://www.zotero.org/
# 3323       An interactive shell and scripting language.                   zsh                   zsh  software                                http://www.zsh.org/
# 3324       A service to share your media via the cloud.             ZumoDrive             zumodrive  software                          http://www.zumodrive.com/
# 3325                          A 2D sprite-packing tool.               Zwoptex               zwoptex  software                             http://zwoptexapp.com/

# %%
user_wares = pf_used_ware.merge(extracted_ware,on='title',how='inner')

# %%
user_wares[:20]
# Out:
#           title                          description         name      type                               url
# 0   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 1   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 2   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 3   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 4   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 5   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 6   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 7   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 8   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 9   macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 10  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 11  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 12  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 13  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 14  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 15  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 16  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 17  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 18  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/
# 19  macbook-pro  The popular Intel-based Mac laptop.  MacBook Pro  hardware  http://www.apple.com/macbookpro/

# %%
user_wares.ix[user_wares.type=='hardware'].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.type=='software'].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.description.str.contains('headphone')].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.description.str.contains('keyboard')].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.description.str.contains('display')].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.description.str.contains('phone')].title.value_counts()[:10].plot(kind='barh')

# %%
user_wares.ix[user_wares.description.str.contains('text')].title.value_counts()[:10].plot(kind='barh')
